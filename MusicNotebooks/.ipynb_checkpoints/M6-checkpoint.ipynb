# %%
import librosa
import IPython
import music21 as mu
from midi2audio import FluidSynth
import pandas as pd

# update music21 environment so it can find MuseScore
mu.environment.set('musescoreDirectPNGPath', '/usr/bin/musescore')

# utility function for sound playback
def create_sound_file_from_midi(m21_data, file_name):
    m21_data.write('midi', fp = file_name + ".mid")
    fs = FluidSynth()
    fs.midi_to_audio('./' + file_name + ".mid", file_name + '.mp3')
    return(IPython.display.Audio("./" + file_name + ".mp3"))

# %%
# get hold of some data
mahler_ex = mu.converter.parse("./MidiFiles/MahlerSymphonies/symphony1/1st-movement-Langsam-Schleppend-Immer-sehr-gemachlich.mxl")

# %%
# Generate some basic summary info about thiws music

print(len(mahler_ex.getElementsByClass(mu.stream.Part)))
print(len(mahler_ex.getElementsByClass(mu.stream.Part)[29].getElementsByClass(mu.stream.Measure)))
# Out:
# 30
# 551

# %%
# examine the list of parts
partList = mahler_ex.getElementsByClass(mu.stream.Part)

# %%
pList = []
for i in range(0, len(partList)):
    print(i, partList[i].getInstrument())
    pList.append(partList[i])
# Out:
# 0 P1: Flute, Fl�ten I II III IV: Flute
# 1 P2: Piccolo, Piccolo: Piccolo
# 2 P3: Oboe, Oboen I II III IV: Oboe
# 3 P4: English Horn, English Horn: English Horn
# 4 P5: B♭ Clarinet, Clarinetti in B I II: B♭ Clarinet
# 5 P6: B♭ Clarinet, Klarinetten in C I II: B♭ Clarinet
# 6 P7: B♭ Clarinet, Klarinette in Eb: B♭ Clarinet
# 7 P8: B♭ Bass Clarinet, Bassklarinette in B: B♭ Bass Clarinet
# 8 P9: Bassoon, Fagotte I II III: Bassoon
# 9 P10: Contrabassoon, Kontrafagott: Contrabassoon
# 10 P11: Brass, H�rner in F I II: Brass
# 11 P12: Horn in F, H�rner in F III IV: Horn in F
# 12 P13: Horn in F, H�rner in F V VI: Horn in F
# 13 P14: Horn in F, H�rner in F VII: Horn in F
# 14 P15: B♭ Trumpet, Trompetten in F I II: B♭ Trumpet
# 15 P16: B♭ Trumpet, Trompetten in B III IV: B♭ Trumpet
# 16 P17: Trombone, Pausonen I II III: Trombone
# 17 P18: Trombone, Pausonen I II III: Trombone
# 18 P19: Tuba, Tuba: Tuba
# 19 P20: Timpani, Pauken: Timpani
# 20 P21: Drumset, Becken: Acoustic Bass Drum
# 21 P22: Drumset, Triangel: Acoustic Bass Drum
# 22 P23: Timpani, Grosse trommel: Timpani
# 23 P24: Harp, Harfe: Harp
# 24 P24: Harp, Harfe: Harp
# 25 P25: Strings, Violine I: Strings
# 26 P26: Strings, Violine II: Strings
# 27 P27: Strings, Viola: Strings
# 28 P28: Strings, Violoncelle: Strings
# 29 P29: Contrabasses, Contrabasse: Contrabasses

# %%
# Look at contents

l = []

singlePart = pList[5]

for el in singlePart.flatten():

    l.append(type(el))

set(l)
# Out:
# {music21.bar.Barline,
#  music21.clef.TrebleClef,
#  music21.instrument.Clarinet,
#  music21.key.KeySignature,
#  music21.layout.PageLayout,
#  music21.layout.StaffLayout,
#  music21.layout.SystemLayout,
#  music21.meter.base.TimeSignature,
#  music21.note.Note,
#  music21.note.Rest}

# %%
# Render a data frame 
events = []

currentNumerator = None
currentDenominator = None
currentInstrument = None
currentInstrumentName = None
currentPartName = None

for el in singlePart.flatten():
 
    eventDictionary = {}
    eventDictionary['offset'] = el.offset
    eventDictionary['quarterLengthDuration'] = el.duration.quarterLength
    eventDictionary['measureNumber'] = el.measureNumber
    eventDictionary['currentNumerator'] = currentNumerator
    eventDictionary['currentDenominator'] = currentDenominator
    eventDictionary['instrument'] = currentInstrumentName
    eventDictionary['part'] = currentPartName
    
    
    currentType = str(type(el))
    
    if currentType == "<class 'music21.meter.base.TimeSignature'>":

        currentNumerator = el.numerator
        currentDenominator = el.denominator

    if "instrument" in currentType:
        print("EHHJDDD")
        currentInstrumentName = el.instrumentName
        currentPartName = el.partName
    
#     if currentType == "<class 'music21.instrument.StringInstrument'>":

#         currentInstrumentName = el.instrumentName
#         currentPartName = el.partName
        
    if currentType == "<class 'music21.note.Note'>":
        eventDictionary['nameWithOctave'] = el.nameWithOctave
        eventDictionary['midiNumber'] = el.pitches[0].midi
        eventDictionary['fullName'] = el.pitches[0].fullName
        eventDictionary['name'] = el.pitches[0].name
        eventDictionary['octave'] = el.pitches[0].octave
        events.append(eventDictionary)
        
    elif currentType == "<class 'music21.chord.Chord'>":

        for eachNote in el:
            eventDictionary['nameWithOctave'] = eachNote.nameWithOctave
            eventDictionary['midiNumber'] = eachNote.pitches[0].midi
            eventDictionary['fullName'] = eachNote.pitches[0].fullName
            eventDictionary['name'] = eachNote.pitches[0].name
            eventDictionary['octave'] = eachNote.pitches[0].octave
            events.append(eventDictionary)
# Out:
# EHHJDDD

# %%
# examine different types of objects
x = pd.DataFrame(events)

# %%
x.head(10)
# Out:
#    offset quarterLengthDuration  measureNumber  currentNumerator  \
# 0  3385/3                   1/3            283                 4
# 1  3386/3                   1/3            283                 4
# 2  3391/3                   1/3            283                 4
# 3  3392/3                   1/3            283                 4
# 4  1140.0                   1/3            286                 4
# 5  3421/3                   1/3            286                 4
# 6  1142.0                   1/3            286                 4
# 7  3427/3                   1/3            286                 4
# 8  1156.0                   2.0            290                 4
# 9  1158.0                   2.0            290                 4
#
#    currentDenominator   instrument                                part  \
# 0                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 1                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 2                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 3                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 4                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 5                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 6                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 7                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 8                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
# 9                   4  B♭ Clarinet  B♭ Clarinet, Klarinetten in C I II
#
#   nameWithOctave  midiNumber            fullName name  octave
# 0            G-6          90  G-flat in octave 6   G-       6
# 1            C-6          83  C-flat in octave 6   C-       6
# 2            G-6          90  G-flat in octave 6   G-       6
# 3            C-6          83  C-flat in octave 6   C-       6
# 4            F-5          76  F-flat in octave 5   F-       5
# 5            C-5          71  C-flat in octave 5   C-       5
# 6            F-5          76  F-flat in octave 5   F-       5
# 7            C-5          71  C-flat in octave 5   C-       5
# 8            C-5          71  C-flat in octave 5   C-       5
# 9            G-4          66  G-flat in octave 4   G-       4

# %%
flat = pList[28].measures(1, 120).flatten()

for el in flat:
    print(el.offset, el, el.activeSite)
# Out:
# 0.0 P28: Strings, Violoncelle: Strings <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.key.KeySignature of 5 flats> <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.meter.TimeSignature 4/4> <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.layout.SystemLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.layout.StaffLayout distance 73.6, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 0.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 4.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 4.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 8.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 8.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 12.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 12.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 13.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 14.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 16.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 16.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 20.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 20.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 24.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 24.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 28.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 28.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 28.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 28.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 32.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 32.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 36.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 40.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 40.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 40.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 44.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 48.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 48.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 48.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 52.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 56.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 60.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 64.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 68.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 72.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 72.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 72.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 76.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 80.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 84.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 88.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 92.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 96.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 96.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 96.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 100.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 100.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 104.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 104.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 104.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 104.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 108.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 108.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 112.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 112.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 112.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 114.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 116.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 116.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 116.0 <music21.note.Note F> <music21.stream.Part Strings, Violoncelle_flat>
# 118.0 <music21.note.Note C> <music21.stream.Part Strings, Violoncelle_flat>
# 120.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 120.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 120.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 124.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 124.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 124.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 128.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 128.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 128.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 128.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 128.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 129.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 130.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 132.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 136.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 140.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 144.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 144.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 144.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 148.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 152.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 156.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 156.0 <music21.layout.StaffLayout distance 129.86, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 156.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 160.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 164.0 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 164.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 164.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 168.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 168.0 <music21.layout.StaffLayout distance 129.86, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 168.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 168.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 172.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 172.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 176.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 176.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 180.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 180.0 <music21.layout.StaffLayout distance 91.83, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 180.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 180.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 184.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 184.0 <music21.chord.Chord A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 188.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 188.0 <music21.layout.StaffLayout distance 100.25, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 188.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 188.0 <music21.chord.Chord A2 A4 A5> <music21.stream.Part Strings, Violoncelle_flat>
# 189.0 <music21.chord.Chord B-2 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 190.0 <music21.chord.Chord B-2 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 30423/160 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 15223/80 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 30583/160 <music21.chord.Chord C3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 45943/240 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 92023/480 <music21.chord.Chord A2 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 192.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 192.0 <music21.layout.StaffLayout distance 100.25, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 192.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 192.0 <music21.chord.Chord B-2 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 193.0 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 194.0 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 31063/160 <music21.chord.Chord C3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 15543/80 <music21.chord.Chord C3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 31223/160 <music21.chord.Chord D-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 46903/240 <music21.chord.Chord C-3 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 93943/480 <music21.chord.Chord A2 A4> <music21.stream.Part Strings, Violoncelle_flat>
# 196.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 196.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 196.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 196.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 196.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 197.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 197.0 <music21.note.Note C> <music21.stream.Part Strings, Violoncelle_flat>
# 198.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 198.0 <music21.note.Note C> <music21.stream.Part Strings, Violoncelle_flat>
# 31703/160 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 15863/80 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 31863/160 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 47863/240 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 95863/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 200.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 200.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 200.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 200.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 200.0 <music21.note.Note C> <music21.stream.Part Strings, Violoncelle_flat>
# 201.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 202.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 32343/160 <music21.note.Note E-> <music21.stream.Part Strings, Violoncelle_flat>
# 16183/80 <music21.note.Note E-> <music21.stream.Part Strings, Violoncelle_flat>
# 32503/160 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 48823/240 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 97783/480 <music21.note.Note C> <music21.stream.Part Strings, Violoncelle_flat>
# 204.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 204.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 204.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 204.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 204.0 <music21.chord.Chord D2 D3> <music21.stream.Part Strings, Violoncelle_flat>
# 205.0 <music21.chord.Chord F-2 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 206.0 <music21.chord.Chord F-2 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 32983/160 <music21.chord.Chord F2 F3> <music21.stream.Part Strings, Violoncelle_flat>
# 16503/80 <music21.chord.Chord F2 F3> <music21.stream.Part Strings, Violoncelle_flat>
# 33143/160 <music21.chord.Chord G2 G3> <music21.stream.Part Strings, Violoncelle_flat>
# 49783/240 <music21.chord.Chord F2 F3> <music21.stream.Part Strings, Violoncelle_flat>
# 99703/480 <music21.chord.Chord F-2 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 208.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 208.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 208.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 208.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 208.0 <music21.chord.Chord F2 F3> <music21.stream.Part Strings, Violoncelle_flat>
# 209.0 <music21.chord.Chord G2 G3> <music21.stream.Part Strings, Violoncelle_flat>
# 210.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 210.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 210.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 211.0 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 211.0 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 634/3 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 211.5 <music21.note.Rest 16th> <music21.stream.Part Strings, Violoncelle_flat>
# 635/3 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 211.75 <music21.chord.Chord G2 G3> <music21.stream.Part Strings, Violoncelle_flat>
# 212.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 212.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 212.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 212.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 212.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 213.0 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 213.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 214.0 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 214.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 34263/160 <music21.chord.Chord C-3 C-4> <music21.stream.Part Strings, Violoncelle_flat>
# 17143/80 <music21.chord.Chord C-3 C-4> <music21.stream.Part Strings, Violoncelle_flat>
# 34423/160 <music21.chord.Chord C3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 51703/240 <music21.chord.Chord C-3 C-4> <music21.stream.Part Strings, Violoncelle_flat>
# 103543/480 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 216.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 216.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 216.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 216.0 <music21.chord.Chord C-3 A3 C-4> <music21.stream.Part Strings, Violoncelle_flat>
# 217.0 <music21.chord.Chord C3 A3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 218.0 <music21.chord.Chord C3 A3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 34903/160 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 17463/80 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 35063/160 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 52663/240 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 105463/480 <music21.chord.Chord C3 A3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 220.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 220.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 220.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 220.0 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 221.0 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 222.0 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 35543/160 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 17783/80 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 35703/160 <music21.chord.Chord G3 A3 G4> <music21.stream.Part Strings, Violoncelle_flat>
# 53623/240 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 107383/480 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 224.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 224.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 224.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 224.0 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 35863/160 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 17943/80 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 36023/160 <music21.chord.Chord G3 A3 G4> <music21.stream.Part Strings, Violoncelle_flat>
# 54103/240 <music21.chord.Chord F3 A3 F4> <music21.stream.Part Strings, Violoncelle_flat>
# 108343/480 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 226.0 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 36183/160 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 18103/80 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 36343/160 <music21.chord.Chord F-3 A3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 54583/240 <music21.chord.Chord D3 A3 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 109303/480 <music21.chord.Chord C3 A3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 228.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 228.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 228.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 228.0 <music21.chord.Chord C3 A3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 36503/160 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 18263/80 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 36663/160 <music21.chord.Chord C3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 55063/240 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 110263/480 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 230.0 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 36823/160 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 18423/80 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 36983/160 <music21.chord.Chord C3 C4> <music21.stream.Part Strings, Violoncelle_flat>
# 55543/240 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 111223/480 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 232.0 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 233.0 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 234.0 <music21.chord.Chord B-2 B-3> <music21.stream.Part Strings, Violoncelle_flat>
# 235.0 <music21.chord.Chord A2 A3> <music21.stream.Part Strings, Violoncelle_flat>
# 236.0 <music21.meter.TimeSignature 2/2> <music21.stream.Part Strings, Violoncelle_flat>
# 236.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 240.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 240.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 240.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 244.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 248.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 250.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 251.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 252.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 253.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 254.0 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 255.0 <music21.note.Note G> <music21.stream.Part Strings, Violoncelle_flat>
# 256.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 258.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 259.0 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 259.0 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 259.5 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 260.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 260.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 260.0 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 261.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 262.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 263.0 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 263.0 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 264.0 <music21.note.Note G> <music21.stream.Part Strings, Violoncelle_flat>
# 266.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 267.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 267.5 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 268.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 269.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 270.0 <music21.note.Note G> <music21.stream.Part Strings, Violoncelle_flat>
# 271.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 272.0 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 274.0 <music21.note.Note G> <music21.stream.Part Strings, Violoncelle_flat>
# 275.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 275.5 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 276.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 276.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 276.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 278.0 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 279.0 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 279.0 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 279.5 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 280.0 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 282.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 283.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 283.5 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 284.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 288.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 288.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 288.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 292.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 296.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 300.0 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 304.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 304.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 304.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 306.0 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 306.0 <music21.chord.Chord F-3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 308.0 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 310.0 <music21.chord.Chord F-3 F-4> <music21.stream.Part Strings, Violoncelle_flat>
# 312.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 313.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 314.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 315.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 316.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 316.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 316.0 <music21.note.Rest quarter> <music21.stream.Part Strings, Violoncelle_flat>
# 317.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 318.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 319.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 320.0 <music21.chord.Chord A2 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 321.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 322.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 323.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 324.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 324.0 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 324.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 325.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 326.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 327.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 328.0 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 329.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 330.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 331.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 332.0 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 332.0 <music21.layout.StaffLayout distance 65.25, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 332.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 333.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 334.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 335.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 336.0 <music21.chord.Chord A2 D4> <music21.stream.Part Strings, Violoncelle_flat>
# 337.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 338.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 339.0 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 340.0 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 340.0 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 341.5 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 342.0 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 54743/160 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 32887/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 54903/160 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 16471/48 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 16471/48 <music21.note.Rest 41/96ql> <music21.stream.Part Strings, Violoncelle_flat>
# 32983/96 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 165121/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 165121/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 165121/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 167041/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 167521/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 168001/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 168481/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 168961/480 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 168961/480 <music21.chord.Chord F-3 F-5> <music21.stream.Part Strings, Violoncelle_flat>
# 169921/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 170881/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 170881/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 171361/480 <music21.chord.Chord F-3 F-5> <music21.stream.Part Strings, Violoncelle_flat>
# 171841/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 171841/480 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 172321/480 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 172321/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 172801/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 172801/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 172801/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 172801/480 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 173761/480 <music21.chord.Chord A2 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 173761/480 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 174721/480 <music21.chord.Chord C-3 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 175681/480 <music21.chord.Chord D-3 F-3> <music21.stream.Part Strings, Violoncelle_flat>
# 176641/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 177121/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 177601/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 178081/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 178561/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 178561/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 178561/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 179041/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 179521/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 180001/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 180481/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 180961/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 181441/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 181921/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 182401/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 182881/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 183361/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 183841/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 184321/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 184321/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 184321/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 184801/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 185281/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 185761/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 186241/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 186721/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 187201/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 187681/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 188161/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 188641/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 189121/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 189601/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 190081/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 190081/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 190081/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 190561/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 191041/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 191521/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 192001/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 192481/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 192961/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 193441/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 193921/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 193921/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 193921/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 194401/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 194881/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 195361/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 195841/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 196321/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 196801/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 197281/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 197761/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 198241/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 198721/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 199201/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 199681/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 199681/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 199681/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 200161/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 200641/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 201121/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 201601/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 202081/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 202561/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 203041/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 203521/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 204001/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 204481/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 204961/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 205441/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 205441/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 205441/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 206401/480 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 207361/480 <music21.note.Rest whole> <music21.stream.Part Strings, Violoncelle_flat>
# 209281/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 209281/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 209281/480 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 210241/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 210721/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 211201/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 211201/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 211201/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 211681/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 212161/480 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 212641/480 <music21.clef.TrebleClef> <music21.stream.Part Strings, Violoncelle_flat>
# 212641/480 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 213121/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 213121/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 213121/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 214081/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 214561/480 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 214801/480 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 215041/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 215041/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 215041/480 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 215521/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 216001/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 216481/480 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 216961/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 216961/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 216961/480 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 217921/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 218401/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 218641/480 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 218881/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 218881/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 218881/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 219361/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 219841/480 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 220321/480 <music21.note.Note C-> <music21.stream.Part Strings, Violoncelle_flat>
# 220801/480 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 220801/480 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 220801/480 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 221281/480 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 221761/480 <music21.note.Note D> <music21.stream.Part Strings, Violoncelle_flat>
# 44359/96 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 27733/60 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 221933/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 73989/160 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 18503/40 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 462.71875 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 37029/80 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 74081/160 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 222277/480 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 111173/240 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 44483/96 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 222449/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 111259/240 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 222587/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 6958/15 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44545/96 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 44545/96 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 44545/96 <music21.note.Rest 1/12ql> <music21.stream.Part Strings, Violoncelle_flat>
# 44545/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 464.09375 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44561/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 464.34375 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44593/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 464.59375 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44609/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 464.84375 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44641/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 74413/160 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 18609/40 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 74459/160 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 223411/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 5587/12 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 223549/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 111809/240 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44737/96 <music21.note.Rest half> <music21.stream.Part Strings, Violoncelle_flat>
# 223687/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 466.125 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 223793/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 111923/240 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 74633/160 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 13997/30 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44801/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 37343/80 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 224111/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 112109/240 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 74757/160 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 56081/120 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 224377/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 467.5625 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 224483/480 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 28067/60 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 44929/96 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 44929/96 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 44929/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 44941/96 <music21.clef.BassClef> <music21.stream.Part Strings, Violoncelle_flat>
# 44941/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 44977/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 45025/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45037/96 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 45073/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 45121/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 45217/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45229/96 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 45265/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 45313/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 45409/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 45505/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45517/96 <music21.note.Note D-> <music21.stream.Part Strings, Violoncelle_flat>
# 45553/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 45601/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45613/96 <music21.note.Note F-> <music21.stream.Part Strings, Violoncelle_flat>
# 45649/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 45697/96 <music21.layout.PageLayout> <music21.stream.Part Strings, Violoncelle_flat>
# 45697/96 <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None> <music21.stream.Part Strings, Violoncelle_flat>
# 45697/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 45793/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45805/96 <music21.note.Note G-> <music21.stream.Part Strings, Violoncelle_flat>
# 45841/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>
# 45889/96 <music21.note.Note A> <music21.stream.Part Strings, Violoncelle_flat>
# 45985/96 <music21.note.Rest 32nd> <music21.stream.Part Strings, Violoncelle_flat>
# 45997/96 <music21.note.Note A-> <music21.stream.Part Strings, Violoncelle_flat>
# 46033/96 <music21.note.Rest eighth> <music21.stream.Part Strings, Violoncelle_flat>

# %%
voice = mahler_ex.parts[28]
voice.measures(1, 10).plot()
# Out:
# <music21.graph.plot.HorizontalBarPitchSpaceOffset for <music21.stream.Part Strings, Violoncelle>>

# %%
partList[24].measures(100,102).show()

# %%
alto = mahler_ex.parts[28]

# %%
excerpt = alto.measures(300, 330)
excerpt.show('text')
# Out:
# {0.0} <music21.instrument.StringInstrument 'P28: Strings, Violoncelle: Strings'>
# {0.0} <music21.clef.TrebleClef>
# {0.0} <music21.key.KeySignature of 5 flats>
# {0.0} <music21.meter.TimeSignature 4/4>
# {0.0} <music21.stream.Measure 300 offset=0.0>
#     {0.0} <music21.note.Note F>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note F>
# {4.0} <music21.stream.Measure 301 offset=4.0>
#     {0.0} <music21.note.Note F->
#     {2.0} <music21.clef.BassClef>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note F->
# {8.0} <music21.stream.Measure 302 offset=8.0>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note A>
# {12.0} <music21.stream.Measure 303 offset=12.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Rest quarter>
# {16.0} <music21.stream.Measure 304 offset=16.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note F>
# {20.0} <music21.stream.Measure 305 offset=20.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note F>
# {24.0} <music21.stream.Measure 306 offset=24.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note F>
# {28.0} <music21.stream.Measure 307 offset=28.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note F>
#     {2.0} <music21.note.Note E->
# {32.0} <music21.stream.Measure 308 offset=32.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.meter.TimeSignature 2/2>
#     {0.0} <music21.note.Note D>
# {36.0} <music21.stream.Measure 309 offset=36.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {40.0} <music21.stream.Measure 310 offset=40.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest whole>
# {44.0} <music21.stream.Measure 311 offset=44.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {48.0} <music21.stream.Measure 312 offset=48.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest whole>
# {52.0} <music21.stream.Measure 313 offset=52.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {56.0} <music21.stream.Measure 314 offset=56.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest whole>
# {60.0} <music21.stream.Measure 315 offset=60.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {64.0} <music21.stream.Measure 316 offset=64.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest whole>
# {68.0} <music21.stream.Measure 317 offset=68.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {72.0} <music21.stream.Measure 318 offset=72.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {76.0} <music21.stream.Measure 319 offset=76.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Rest half>
# {80.0} <music21.stream.Measure 320 offset=80.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest whole>
# {84.0} <music21.stream.Measure 321 offset=84.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Rest half>
#     {2.0} <music21.note.Rest quarter>
#     {3.0} <music21.clef.TrebleClef>
#     {3.0} <music21.note.Note D>
# {88.0} <music21.stream.Measure 322 offset=88.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note F->
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note F->
# {92.0} <music21.stream.Measure 323 offset=92.0>
#     {0.0} <music21.note.Note G->
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note G->
# {96.0} <music21.stream.Measure 324 offset=96.0>
#     {0.0} <music21.note.Note G>
#     {1.0} <music21.note.Note G->
#     {2.0} <music21.note.Note G>
#     {3.0} <music21.note.Note F->
# {100.0} <music21.stream.Measure 325 offset=100.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note D>
# {104.0} <music21.stream.Measure 326 offset=104.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D->
#     {1.0} <music21.note.Note A>
#     {2.0} <music21.note.Note C->
#     {3.0} <music21.note.Note D->
# {108.0} <music21.stream.Measure 327 offset=108.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.note.Note D>
#     {2.0} <music21.note.Note A>
#     {3.0} <music21.note.Note A>
# {112.0} <music21.stream.Measure 328 offset=112.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest half>
#         {2.0} <music21.note.Note A>
#     {0.0} <music21.stream.Voice 2>
#         {0.0} <music21.chord.Chord D-3 F-4>
#         {2.0} <music21.note.Note D>
# {116.0} <music21.stream.Measure 329 offset=116.0>
#     {0.0} <music21.layout.PageLayout>
#     {0.0} <music21.layout.StaffLayout distance 65, staffNumber 1, staffSize None, staffLines None>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Rest half>
#     {0.0} <music21.stream.Voice 2>
#         {0.0} <music21.note.Note F->
# {120.0} <music21.stream.Measure 330 offset=120.0>
#     {0.0} <music21.note.Note A>
#     {2.0} <music21.note.Rest half>

# %%
measureStack = mahler_ex.measures(2, 3)
measureStack.show('text')
# Out:
# {0.0} <music21.stream.Part Flute, Fl�ten I II III IV>
#     {0.0} <music21.instrument.Flute 'P1: Flute, Fl�ten I II III IV: Flute'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.tempo.MetronomeMark larghetto Quarter=62.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Piccolo, Piccolo>
#     {0.0} <music21.instrument.Piccolo 'P2: Piccolo, Piccolo: Piccolo'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Oboe, Oboen I II III IV>
#     {0.0} <music21.instrument.Oboe 'P3: Oboe, Oboen I II III IV: Oboe'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part English Horn, English Horn>
#     {0.0} <music21.instrument.EnglishHorn 'P4: English Horn, English Horn: English Horn'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Clarinet, Clarinetti in B I II>
#     {0.0} <music21.instrument.Clarinet 'P5: B♭ Clarinet, Clarinetti in B I II: B♭ Clarinet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Clarinet, Klarinetten in C I II>
#     {0.0} <music21.instrument.Clarinet 'P6: B♭ Clarinet, Klarinetten in C I II: B♭ Clarinet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Clarinet, Klarinette in Eb>
#     {0.0} <music21.instrument.Clarinet 'P7: B♭ Clarinet, Klarinette in Eb: B♭ Clarinet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Bass Clarinet, Bassklarinette in B>
#     {0.0} <music21.instrument.BassClarinet 'P8: B♭ Bass Clarinet, Bassklarinette in B: B♭ Bass Clarinet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Bassoon, Fagotte I II III>
#     {0.0} <music21.instrument.Bassoon 'P9: Bassoon, Fagotte I II III: Bassoon'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Contrabassoon, Kontrafagott>
#     {0.0} <music21.instrument.Contrabassoon 'P10: Contrabassoon, Kontrafagott: Contrabassoon'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Brass, H�rner in F I II>
#     {0.0} <music21.instrument.BrassInstrument 'P11: Brass, H�rner in F I II: Brass'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Horn in F, H�rner in F III IV>
#     {0.0} <music21.instrument.Horn 'P12: Horn in F, H�rner in F III IV: Horn in F'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Horn in F, H�rner in F V VI>
#     {0.0} <music21.instrument.Horn 'P13: Horn in F, H�rner in F V VI: Horn in F'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Horn in F, H�rner in F VII>
#     {0.0} <music21.instrument.Horn 'P14: Horn in F, H�rner in F VII: Horn in F'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Trumpet, Trompetten in F I II>
#     {0.0} <music21.instrument.Trumpet 'P15: B♭ Trumpet, Trompetten in F I II: B♭ Trumpet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part B♭ Trumpet, Trompetten in B III IV>
#     {0.0} <music21.instrument.Trumpet 'P16: B♭ Trumpet, Trompetten in B III IV: B♭ Trumpet'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Trombone, Pausonen I II III>
#     {0.0} <music21.instrument.Trombone 'P17: Trombone, Pausonen I II III: Trombone'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Trombone, Pausonen I II III>
#     {0.0} <music21.instrument.Trombone 'P18: Trombone, Pausonen I II III: Trombone'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Tuba, Tuba>
#     {0.0} <music21.instrument.Tuba 'P19: Tuba, Tuba: Tuba'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Timpani, Pauken>
#     {0.0} <music21.instrument.Timpani 'P20: Timpani, Pauken: Timpani'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Drumset, Becken>
#     {0.0} <music21.instrument.BassDrum 'P21: Drumset, Becken: Acoustic Bass Drum'>
#     {0.0} <music21.clef.PercussionClef>
#     {0.0} <music21.key.KeySignature of no sharps or flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Drumset, Triangel>
#     {0.0} <music21.instrument.BassDrum 'P22: Drumset, Triangel: Acoustic Bass Drum'>
#     {0.0} <music21.clef.PercussionClef>
#     {0.0} <music21.key.KeySignature of no sharps or flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Timpani, Grosse trommel>
#     {0.0} <music21.instrument.Timpani 'P23: Timpani, Grosse trommel: Timpani'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.PartStaff P24-Staff1>
#     {0.0} <music21.instrument.Harp 'P24: Harp, Harfe: Harp'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.PartStaff P24-Staff2>
#     {0.0} <music21.instrument.Harp 'P24: Harp, Harfe: Harp'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Rest whole>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Rest whole>
# {0.0} <music21.stream.Part Strings, Violine I>
#     {0.0} <music21.instrument.StringInstrument 'P25: Strings, Violine I: Strings'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Note A>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Note A>
# {0.0} <music21.stream.Part Strings, Violine II>
#     {0.0} <music21.instrument.StringInstrument 'P26: Strings, Violine II: Strings'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Note A>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Note A>
# {0.0} <music21.stream.Part Strings, Viola>
#     {0.0} <music21.instrument.StringInstrument 'P27: Strings, Viola: Strings'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.note.Note A>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.note.Note A>
# {0.0} <music21.stream.Part Strings, Violoncelle>
#     {0.0} <music21.instrument.StringInstrument 'P28: Strings, Violoncelle: Strings'>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.chord.Chord A4 A5>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.chord.Chord A4 A5>
# {0.0} <music21.stream.Part Contrabasses, Contrabasse>
#     {0.0} <music21.instrument.StringInstrument 'P29: Contrabasses, Contrabasse: Contrabasses'>
#     {0.0} <music21.clef.BassClef>
#     {0.0} <music21.key.KeySignature of 5 flats>
#     {0.0} <music21.meter.TimeSignature 4/4>
#     {0.0} <music21.stream.Measure 2 offset=0.0>
#         {0.0} <music21.chord.Chord A2 A3 A4>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.chord.Chord A2 A3 A4>
# {0.0} <music21.layout.StaffGroup <music21.stream.PartStaff P24-Staff1><music21.stream.PartStaff P24-Staff2>>
