# %% [markdown]
# <i>STATUS: Draft<i>

# %%
import numpy as np
import sympy as sp
from IPython.display import HTML
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.patches import Rectangle, Circle, ConnectionPatch
from IPython.display import Image
import sys
import pandas as pd
import HTM_Code as hc
import colorsys
import time as timer

# %% [markdown]
# We are now starting a get a handle on the basics, and have made quite a bit of progress: we  know how to create SDRS; we have mechanimsms to compare SDRs and we have started to think about fault tolerence and noise; we have some rudimentary strategies to deal with fault tolerance and add noise to SDRs. We also have an Encoder which allows us to take an multiple inputs, and find a way to keep their semantic meaning (at least in a numerical sense). We also have developed the idea of of multiple Encoder that allows to join a number of Encoders together so we can more complex imports. And finally, we have some nice visualisation functions.
#
# Our slowly growing code base, <code>HTM_Code.py</code> is probably due for a refactor soon, but for the purpose of developing our understanding, its fine for now.
#
# <h4>Spatial Pooler</h4>
#
# The important component we need to deal with in HTM is the Spatial Pooler (SP). We can look to the literature to get an initial definition for this:

# %% [markdown]
# <div style="padding-left: 150px; padding-right: 150px; ">
#
# <i>The [Spatial Pooler] models how neurons learn feedforward connections and form efficient representations of the input. It converts arbitrary binary input patterns into sparse distributed representations (SDRs) using a combination of competitive Hebbian learnig rules and homeostatic exciteability control</i>
#     <br/>
#     <br/>
#     -- Spatial Pooling, Biological & Machine Intelligence
# </div>

# %% [markdown]
# There is quite a bit in that sentence. Don't worry, by the time we work through the next couple of notebooks, it will make a lot more sense.
#
# In terms of resources for learning about the Spatial Pooler, the best place is to start with relevant HTM School episodes, which are quite intuitive but I found them I needed to watch them a few times to really get a handle on. There are also a couple of key papers to be aware of (but note they are a little more dense). In any case, we will draw resources from all of these.
#
# * HTM Spatial Pooler - Neocortical Algorthm for Online Sparse Distributed Encoding (Yuwei Cui, Subutai Ahmad and Jeff Hawkins)<br/>
# <i>https://www.frontiersin.org/articles/10.3389/fncom.2017.00111/full#:~:text=The%20HTM%20Spatial%20Pooler%E2%80%94A%20Neocortical%20Algorithm%20for%20Online%20Sparse%20Distributed%20Coding,-Yuwei%20Cui%2C%20Subutai&text=Hierarchical%20temporal%20memory%20(HTM)%20provides,computational%20principles%20of%20the%20neocortex.&text=We%20then%20demonstrate%20the%20value,end%20real%2Dworld%20HTM%20system. </i>
#
# * Biological and Machine Intelligence (BAMI) chapter on Spatial Pooling (Numenta)<br/>
# <i>https://numenta.com/resources/biological-and-machine-intelligence/spatial-pooling-algorithm/</i>

# %%
ep7 = '<iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
ep8 = '<iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
table = '<table style="width:100%"><tr><td>' + ep7 + '</td><td>' + ep8 + '</td></tr>'
HTML(table)
# Out:
# <table style="width:100%"><tr><td><iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td><td><iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td></tr>

# %% [markdown]
# <b>Episodes 7 & 8 </b>
#
# A couple of caveats: I found it easier to detail with episodes 7 and 8 at the same time as when you are doing some kind of implementation (even the simple one we are doing), you need to go between them a little. Secondly, there is a working example which from measurements of the power consumption in a gym over different dates and times. I will spend some more time in this notebook just getting to an understanding of the Spatial Pooler, and then in the notebook we will introduce the gym data as our working example

# %% [markdown]
# In these
#
# - An SDR arrives at the neocortex through the thalumus
# - Neocortex is structuced into regions and in each of these regions is columns of cells (montcastle)
# - each column has associated dendritic segment which is the connection to the input space
# - each dendrectic segment has potential synapses representing a random subset of input bits

# %% [markdown]
# spatial pooling.....
#
# biology of neocorext
#
# heiracty of regions....gets input from sensory etc.
#
# input space is figure optics, whether neuron is on or off
#
# cortex needs to normalise input in order to learn....
#
# size of input space variable - look at it in different ways
#
# SP - gets input vector.....translates into output vector with a sparse number of active bits
#
# Output vector of SP represents minicolumns...which are col of pyramidal neorons in the neorcrotex....important
#
# 2 goals of spatial pooling...
# - maintain fixed sparsity - as it sees input SP will maintain sparsity
# - maintain overlap properties
#
# ...need to recognise overlaps in input etc....
#
# spatial pooler is learning algorithm.... today we talk about input space
#
#
# SP input space - is multi encoder from gym example
# - each data points represented in input space
#
# Aim one - iterate through all dat and encode...
#
# This data set has certain signatures......could be random input or not....semantic meaning remains...
#
# Step 1 - feed data into multiencoder
#
# Step 2.....inititalise
# LEFT - SOME INPUT SPACE
# RIGHT - SP COLUMNS
# so each SP columsn is connected to subset of input spacte
#
# Every column has potential pool that it might be connected to - randomly potentially connected - here to 85%, we can reset..... SP has initial settings
# each of the 85% of potential connections has permanence connected...heat map shows connections - which has no connection in red, then heat map connections
#
# white cells - no connection to
# all others have a permance value that may be below threshold
#
# each col has relationship to every cel in input space
# - some will never connect
# - others will have different levels of connectivity
# - blue circle means there is a connection from columm to cell in input space, and
# - blue circles are an outomce of of if permance threshold is met, they can have a connection - so all squares have either no, connectino, connection below threshold, or connection above threshold, and those above are blue dots apppear
#
# - can change to .4 - map to only 40%, and then blue dots appear only above connection threshold of that 40% -
# - POTENTIAL POOL - all possible connections set to 85%, then 40%
# - CONNECTINO THRESHOLD - set heatmap, and blue dots - randominly initialise heatmap settings I think
# - in setting up  permance valus randomly, this happens around the threshold.....so number of connections still kind of works - set up  as normal distribution around connection threshold
#
# Now.....we can look at input.. we get random SDR coming in....
#
# Eeach column mapped to input space
#
# We can consider if col mapped to input space, some overlapping with data, some don't
#
# Idea is that cols learn, through reinforcement (see input on connection) or don't see anything
#
# Also - idea of input / cell overlap
#
# use overlap to "activate cols" -

# %% [markdown]
# So this tells us we need 4 numerical encoders: 1 for consumption, one for time of day, 1 for weekend. We need to think about paramaters

# %% [markdown]
# <div style="padding-left: 150px; padding-right: 150px; ">
#
# <i>First, the values are chosen to be in a small range around connectedPerm, the minimum permanence value at which a synapse is considered “connected”. This enables potential synapses to become connected (or disconnected) after a small number of training iterations. Second, each column has a natural center over the input region, and the permanence values have a bias towards this center, so that they have higher values near the center.</i>
#     <br/>
#     <br/>
#     -- Spatial Pooling, Biological & Machine Intelligence
# </div>

# %% [markdown]
# We are going to create a vew different versions of our Spatial Pooler, and move foward slowly to become more sophisticated. Here is a first version with a couple of features:

# %%
class SpatialPoolerV1:
    def __init__(self):
        self.input_space_size = 400
        self.potential_pool = .85
        self.connection_threshold = 0.1
        self.connection_threshold_sd = 0.01
        self.columns = {}
        self.connected_columns = None
        self.non_connected_columns = None
        self.connected_columns_permanence_values = None
        self.columns_initialised = False
        
    def get_summary(self):
        print("----------------- SUMMARY -------------------------")
        print("|L1| Capacity of mini-columns in spatial pooler:", self.input_space_size)
        print("|L2| Potential pool of each minicolumn:", self.potential_pool * 100, "%")
        print("|L2| Connection threshold:", self.connection_threshold)
        print("|L2| Connection threshold standard deviation:", self.connection_threshold_sd)
        print("|L4| Columns initialised:", self.columns_initialised)
        
        
    def initialise_columns_to_input_space(self):
        potential_pool_size = int(self.potential_pool * self.input_space_size)

        for i in range(self.input_space_size):
           

            potential_connections = hc.create_randomised_sdr(self.input_space_size, potential_pool_size)
            non_connected_columns = [x for x in range(0, self.input_space_size) if x not in potential_connections]
            potential_connections_permanence_values = np.random.normal(self.connection_threshold, 0.01, potential_pool_size)
            connected_columns = []
            for j in range(0, len(potential_connections)):
                if potential_connections_permanence_values[j] > 0.1:
                    connected_columns.append(potential_connections[j])
                    
        
            self.columns[i] = {'potential_connections': potential_connections,
                              'non_connected_columns': non_connected_columns,
                               'potential_connections_permanence_values': potential_connections_permanence_values,
                               'connected_columns': connected_columns
                              }
        print("Each of the", self.input_space_size, "mini-columns in this Spatial Pooler has now each randomonly connected to", self.potential_pool, 
              "of bits in the input space. The connection strength is approximately between", min(self.columns[0]['potential_connections_permanence_values']),
             "and", max(self.columns[0]['potential_connections_permanence_values']), "with a mean of", self.connection_threshold, 
             "There are" , len(self.columns[0]['connected_columns']), "connected")

# %% [markdown]
# Now let's create our first spatial pooler:

# %%
bit_space_size_choice = 400
number_of_bits_used_to_encode_value_choice = 8

s1 = SpatialPoolerV1()
s1.get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Capacity of mini-columns in spatial pooler: 400
# |L2| Potential pool of each minicolumn: 85.0 %
# |L2| Connection threshold: 0.1
# |L2| Connection threshold standard deviation: 0.01
# |L4| Columns initialised: False

# %% [markdown]
# What is this telling us. We set the number of columns to 400, each of these can connect to a potential pool of .85% of 400. We will also set a connection threshold. Let's now initialise the columns

# %%
s1.initialise_columns_to_input_space()
# Out:
# Each of the 400 mini-columns in this Spatial Pooler has now each randomonly connected to 0.85 of bits in the input space. The connection strength is approximately between 0.0707712832298926 and 0.12619046932375716 with a mean of 0.1 There are 167 connected

# %% [markdown]
# Nothing of much interest has happened so far, but its worth visualising it to get a better intuition for what is happening here. For this, I am going to use the visualisation functions I have already set up, just adding a couple small things to visualise the the differet thresholds as a color, and a functino to offset coordinate to make it easy to draw things circles and lines between graphs.

# %%
def compute_color(c, min_in_range, max_in_range):
    ival = np.interp(c,[min_in_range,max_in_range],[0,1])
    rgb = colorsys.hsv_to_rgb(0, ival,  1)
    return(rgb)

def offset_coords_for_visualisation(c, offset_amount):
    coords = np.array(c)
    coords = coords + offset_amount
    return(tuple(coords))

# %% [markdown]
# For our 400 mini-columns that are now initialised, let's just choose one at random and see what is connected to:

# %%
mini_column_choice = np.random.randint(0, s1.input_space_size)
print(mini_column_choice)
# Out:
# 160

# %% [markdown]
# And now visualise:

# %%
column_of_interest = s1.columns[mini_column_choice ]
min_permanence_value = min(s1.columns[mini_column_choice ]['potential_connections_permanence_values'])
max_permanence_value = max(s1.columns[mini_column_choice ]['potential_connections_permanence_values'])
column_coords = hc.convert_sdr_to_tuple_for_visualisation([mini_column_choice ], bit_space_size_choice)[0]


fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(18, 4))

ax1 = hc.create_axis_for_sdr(ax1, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, number_of_bits_used_to_encode_value_choice, "Potential pool")
ax2 = hc.create_axis_for_sdr(ax2, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, number_of_bits_used_to_encode_value_choice, "Permanence values")
ax3 = hc.create_axis_for_sdr(ax3, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, number_of_bits_used_to_encode_value_choice, "Connections")
ax4 = hc.create_axis_for_sdr(ax4, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, number_of_bits_used_to_encode_value_choice, "Connected mini-column")

coords1 = hc.convert_sdr_to_tuple_for_visualisation(column_of_interest['potential_connections'], bit_space_size_choice)
coords2 = hc.convert_sdr_to_tuple_for_visualisation(column_of_interest['connected_columns'], bit_space_size_choice)

p1 = [ax1.add_patch(Rectangle(coords1[i], 1, 1, color = "lightgray")) for i in range(len(coords1))]
p1 = [ax2.add_patch(Rectangle(coords1[i], 1, 1, color = compute_color(column_of_interest['potential_connections_permanence_values'][i], min_permanence_value, max_permanence_value))) for i in range(len(coords1))]
p1 = [ax3.add_patch(Rectangle(coords1[i], 1, 1, color = compute_color(column_of_interest['potential_connections_permanence_values'][i], min_permanence_value, max_permanence_value))) for i in range(len(coords1))]
p3 = [ax3.add_patch(Circle(offset_coords_for_visualisation(coords2[i], .5), .2, color = "blue")) for i in range(len(coords2))]


p3 = ax4.add_patch(Rectangle(column_coords, 1, 1, color = "blue"))
p3 = [ax4.add_artist(ConnectionPatch(xyA=offset_coords_for_visualisation(column_coords, .2), xyB=coords2[i], coordsA="data", coordsB="data",
                       axesA=ax4, axesB=ax3, color="blue", linewidth = 0.3)) for i in range(len(coords2))]

plt.savefig("./Images/spatial_pooler_columns.svg", dpi = 300)

# %% [markdown]
# <div style="background:#99ddff; color:black; padding: 10px">
# <b>Add to these notes:</b>
#     <br/>
# <div>I love matplotlib, but sometimes rendering really high quality images directly is difficulty NOte that can also write image svg files. Just an aside to say this quite I created one with the last line of code
#     </div>
#     <img src = "Images/spatial_pooler_columns.svg"></img>
# </div>

# %% [markdown]
# So far we have set this up, so its mini-column is connected a potential pool. Another way to visualise this is, for any bit in the input space, which columsn is it connected to?

# %% [markdown]
# Now let's look at some input. Before I do this however, I am going to create an SDR class as well. The reason for this, is that SDR is really not just the following function:

# %%
np.array(hc.create_randomised_sdr(400, 20))
# Out:
# array([128, 258, 142, 275, 284, 184,  56, 315,  69,  75, 334, 212, 217,
#        222, 354, 357, 107, 371, 115, 120])

# %% [markdown]
# But an SDR is not just 20 random inputs, it is something a little more nuanced. For instnace, SDR knows about its toal input space, and its sparsity, so its like an array with certain attributes. This is a small thing, but as we go forward it will help us
#
# Let's just create an object to manage an SDR

# %%
class SDR:
    def __init__(self, input_space_size, number_of_active_bits, label):
        self.input_space_size = input_space_size
        self.number_of_active_bits= number_of_active_bits
        self.active_bits = hc.create_randomised_sdr(self.input_space_size, self.number_of_active_bits)
        self.label = label
    def get_summary(self):
        print("----------------- SUMMARY -------------------------")
        print("|L1| Label:", self.label)
        print("|L1| Input space size of SDR:", self.input_space_size)
        print("|L2| Number of active bits in SDR:", self.number_of_active_bits)
        print("|L3| Percentage of active bits:", (self.number_of_active_bits / self.input_space_size) * 100, "%")
        print("|L3| Active bits:", self.active_bits)

# %%
sd1 = SDR(400, 20, "some_label")
sd1.get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Label: some_label
# |L1| Input space size of SDR: 400
# |L2| Number of active bits in SDR: 20
# |L3| Percentage of active bits: 5.0 %
# |L3| Active bits: [147, 185, 63, 330, 333, 336, 83, 213, 217, 354, 99, 356, 98, 359, 361, 236, 365, 366, 244, 377]

# %% [markdown]
# Now back to the Spatial Pooler. Let's create a version 2 and this version will allow us to pass an input in and see which columns that it is connected to. We will also add a few more features to it to bring out other properties:

# %%
input_space_size = 1024
bit_space_size_choice = 1024
active_bits_in_inputs = 32

class SpatialPoolerV2:
    def __init__(self):
        self.input_space_size = 1024
        self.potential_pool = .45
        self.connection_threshold = 0.1
        self.connection_threshold_sd = 0.01
        self.columns = {}
        self.connected_columns = None
        self.non_connected_columns = None
        self.connected_columns_permanence_values = None
        self.columns_initialised = False
        self.inputs  = []
        self.input_active_bits = None
        self.log_file = []
        self.inputs_connected_to_columns = None
        
    def add_inputs(self, inputs, multiple = True):
        self.inputs = inputs
        
        
    def compare_inputs_to_connected_columns(self, log=True):
        for i in range(len(self.inputs)):
            for key, value in self.columns.items():
                overlap = list(set(value['connected_columns']).intersection(self.inputs[i].active_bits))
                if log:
                    self.log_file.append(("The input at",self.inputs[i].label, "has an overlap score of", len(overlap), "with mini-column", str(key)))
        
    def get_summary(self):
        print("----------------- SUMMARY -------------------------")
        print("|L1| Capacity of mini-columns in spatial pooler:", self.input_space_size)
        print("|L2| Potential pool of each minicolumn:", self.potential_pool * 100, "%")
        print("|L2| Connection threshold:", self.connection_threshold)
        print("|L2| Connection threshold standard deviation:", self.connection_threshold_sd)
        print("|L4| Columns initialised:", self.columns_initialised)
        print("|L5| Current number of inputs:", len(self.inputs))
        
    
        
    def initialise_columns_to_input_space(self):
        start_time = timer.perf_counter()
        potential_pool_size = int(self.potential_pool * self.input_space_size)

        for i in range(self.input_space_size):
        
            potential_connections = hc.create_randomised_sdr(self.input_space_size, potential_pool_size)
            non_connected_columns = [x for x in range(0, self.input_space_size) if x not in potential_connections]
            potential_connections_permanence_values = np.random.normal(self.connection_threshold, 0.01, potential_pool_size)
            connected_columns = []
            for j in range(0, len(potential_connections)):
                if potential_connections_permanence_values[j] > 0.1:
                    connected_columns.append(potential_connections[j])
                    
            self.columns[i] = {'potential_connections': potential_connections,
                              'non_connected_columns': non_connected_columns,
                               'potential_connections_permanence_values': potential_connections_permanence_values,
                               'connected_columns': connected_columns
                              }
            self.columns_initialised = True
            end_time = timer.perf_counter()
        print("---------------------SUMMARY -------------------------------------")
        print("Each of the", self.input_space_size, "mini-columns in this Spatial Pooler has now each randomonly connected to", self.potential_pool, 
              "of bits in the input space. \nThe connection strength is normally distributed approximately between", min(self.columns[0]['potential_connections_permanence_values']),
             "and", max(self.columns[0]['potential_connections_permanence_values']), "with a mean of", self.connection_threshold, 
              "which also acts as a connection threshold",
             "\nThere are now" , len(self.columns[0]['connected_columns']), "connected columns. \nTime taken to initialise:", end_time - start_time, "seconds.")

        
    def compare_input_space_bits_to_columns(self):
        d = []
        for key, value in self.columns.items():
            for i in value['connected_columns']:
                d.append([i, key])
        d.sort()
        e = {}
        f = []
        d.append([-1, -1])
        for j in range(1, len(d) - 1):
            f.append(d[j][1])
            if d[j][0] != d[j + 1][0]:
                e[d[j][0]] = f
                f = []
        self.inputs_connected_to_columns = e
            

# s2 = SpatialPoolerV2()
# s2.get_summary()
# s2.initialise_columns_to_input_space()
# random_inputs = [SDR(input_space_size,active_bits_in_inputs, "TimeStep_" + str(i)) for i in range(0,3)]
# random_inputs[0].get_summary()
# s2.add_inputs(random_inputs)
# s2.get_summary()
# s2.compare_inputs_to_connected_columns()
# 2.columns[0]
# s2.compare_input_space_bits_to_columns()

# %% [markdown]
# Let's try it out with another example. This time we will go up to an input space of 1024. We are start finding some performance issues now, and in the next version we will need reconsider a more vectorised style implementation, but in the interests of keeping things as inutitive as possible. We will start tracking the time involved however:

# %%
s2 = SpatialPoolerV2()
s2.get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Capacity of mini-columns in spatial pooler: 1024
# |L2| Potential pool of each minicolumn: 45.0 %
# |L2| Connection threshold: 0.1
# |L2| Connection threshold standard deviation: 0.01
# |L4| Columns initialised: False
# |L5| Current number of inputs: 0

# %% [markdown]
# So we have initialised Spatial pooler, with a larger inputs space. Let's now initialise those columns

# %%
s2.initialise_columns_to_input_space()
# Out:
# ---------------------SUMMARY -------------------------------------
# Each of the 1024 mini-columns in this Spatial Pooler has now each randomonly connected to 0.45 of bits in the input space.
# The connection strength is normally distributed approximately between 0.06340553048598957 and 0.12613273118820414 with a mean of 0.1 which also acts as a connection threshold
# There are now 241 connected columns.
# Time taken to initialise: 5.757139399996959 seconds.

# %% [markdown]
# Next, let's add some inputs. Eventually we probably don't want to store the inputs in our Spatial Pooler, we will need to figure out a better way to do this, and later we can look more closely at both the Nupic code base and htm.core. But for now, its fine. Let's create 3 random inputs, using our SDR class, and just to make sure it worked, we will the summary for the first one that we have created:

# %%
random_inputs = [SDR(input_space_size,active_bits_in_inputs, "TimeStep_" + str(i)) for i in range(0,3)]
random_inputs[0].get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Label: TimeStep_0
# |L1| Input space size of SDR: 1024
# |L2| Number of active bits in SDR: 32
# |L3| Percentage of active bits: 3.125 %
# |L3| Active bits: [262, 135, 529, 544, 936, 682, 429, 558, 817, 946, 53, 825, 578, 324, 839, 75, 971, 845, 715, 79, 338, 210, 92, 97, 996, 491, 107, 623, 760, 634, 764, 253]

# %% [markdown]
# Now add them. The summary will tell us that they are in the Spatial Pooler

# %%
s2.add_inputs(random_inputs)
s2.get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Capacity of mini-columns in spatial pooler: 1024
# |L2| Potential pool of each minicolumn: 45.0 %
# |L2| Connection threshold: 0.1
# |L2| Connection threshold standard deviation: 0.01
# |L4| Columns initialised: True
# |L5| Current number of inputs: 3

# %% [markdown]
# Now let's compare the overlap of our inputs to our minicolumns connects to the input space. This means that, for each import, we will look at columns connections and see if there is an overlap, and track this. For now I will just keep it in a list. I will also create a kind of log file in the Spatial pooler, and you can print that to see what it is doing

# %%
s2.compare_input_space_bits_to_columns()

# %% [markdown]
# So now let's look at some visualisations. The first thing to consider is just to have alook at each input space, and see what what columns it is connected to. When we created <code>compare_input_space_bits_to_columns()</code> which is a bit of a hacky function, but we won't really use it beyond the next visualisation. To this, let's choose 2 inputs spaces at random and then have a look at which columns they are connected to:

# %%
random_bits_in_inputs_space = np.random.randint(0, 1024, 2)
random_bits_in_inputs_space
# Out:
# array([ 56, 971])

# %% [markdown]
# Our function above updated the variable <code>self.inputs_connected_to_columns</code> in our Spatial Pooler. So now its easy to us to get these values (<code>s2.inputs_connected_to_columns[290]</code> will tell us what columns the inputs space at 290 is connected to)

# %%
bit_space_size_choice
# Out:
# 1024

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(18, 4))

ax1 = hc.create_axis_for_sdr(ax1, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, 
                             number_of_bits_used_to_encode_value_choice, "Input bit at " + str(random_bits_in_inputs_space[0]))
ax2 = hc.create_axis_for_sdr(ax2, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, 
                             number_of_bits_used_to_encode_value_choice, "All columns connected to input " + str(random_bits_in_inputs_space[0]))
ax3 = hc.create_axis_for_sdr(ax3, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, 
                             number_of_bits_used_to_encode_value_choice, "Input bit at " + str(random_bits_in_inputs_space[1]))
ax4 = hc.create_axis_for_sdr(ax4, np.sqrt(bit_space_size_choice) + 1, np.sqrt(bit_space_size_choice) + 1, 
                             number_of_bits_used_to_encode_value_choice, "All columns connected to input " + str(random_bits_in_inputs_space[1]))

coords1 = hc.convert_sdr_to_tuple_for_visualisation([random_bits_in_inputs_space[0]], bit_space_size_choice)
coords2 = hc.convert_sdr_to_tuple_for_visualisation([random_bits_in_inputs_space[1]], bit_space_size_choice)
coords3 = hc.convert_sdr_to_tuple_for_visualisation(s2.inputs_connected_to_columns[random_bits_in_inputs_space[0]], bit_space_size_choice)
coords4 = hc.convert_sdr_to_tuple_for_visualisation(s2.inputs_connected_to_columns[random_bits_in_inputs_space[1]], bit_space_size_choice)

p = [ax1.add_patch(Rectangle(coords1[i], 1, 1, color = "blue")) for i in range(len(coords1))]
p = [ax3.add_patch(Rectangle(coords2[i], 1, 1, color = "blue")) for i in range(len(coords2))]
p = [ax2.add_patch(Rectangle(coords3[i], 1, 1, color = "#b30000")) for i in range(len(coords3))]
p = [ax4.add_patch(Rectangle(coords4[i], 1, 1, color = "#b30000")) for i in range(len(coords4))]

# %% [markdown]
# Its wotrth notin as well thatthe inputs onnections are normally distributed

# %%
p = plt.hist([len(s2.inputs_connected_to_columns[i]) for i in s2.inputs_connected_to_columns ])

# %%
s2.compare_inputs_to_connected_columns()
s2.log_file
# Out:
# [('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '0'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '1'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '2'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '3'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '4'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '5'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '6'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '7'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '8'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '9'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '10'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '11'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '12'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '13'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '14'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '15'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '16'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '17'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '18'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '19'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '20'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '21'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '22'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '23'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '24'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '25'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '26'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '27'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '28'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '29'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '30'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '31'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '32'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '33'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '34'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '35'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '36'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '37'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '38'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '39'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '40'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '41'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '42'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '43'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '44'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '45'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '46'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '47'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   1,
#   'with mini-column',
#   '48'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '49'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '50'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '51'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '52'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '53'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '54'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '55'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '56'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '57'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '58'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '59'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '60'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '61'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '62'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   14,
#   'with mini-column',
#   '63'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '64'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '65'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '66'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '67'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '68'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '69'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '70'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '71'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '72'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '73'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   13,
#   'with mini-column',
#   '74'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '75'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '76'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '77'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '78'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '79'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '80'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '81'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '82'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '83'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '84'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '85'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '86'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '87'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '88'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '89'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '90'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '91'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '92'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '93'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '94'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '95'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '96'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '97'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '98'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '99'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '100'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '101'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '102'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '103'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '104'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '105'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '106'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '107'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '108'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '109'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '110'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '111'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '112'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '113'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '114'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '115'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '116'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '117'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '118'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '119'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '120'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '121'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '122'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '123'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '124'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '125'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '126'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '127'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '128'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '129'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '130'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '131'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '132'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '133'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '134'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '135'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   13,
#   'with mini-column',
#   '136'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '137'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '138'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '139'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '140'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '141'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '142'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '143'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '144'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '145'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '146'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '147'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '148'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '149'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   1,
#   'with mini-column',
#   '150'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   13,
#   'with mini-column',
#   '151'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '152'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '153'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '154'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '155'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '156'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '157'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '158'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '159'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '160'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '161'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '162'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '163'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '164'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '165'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '166'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '167'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '168'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '169'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '170'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '171'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '172'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '173'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '174'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '175'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '176'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '177'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '178'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '179'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '180'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '181'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '182'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '183'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '184'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '185'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '186'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '187'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '188'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '189'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '190'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '191'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '192'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '193'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '194'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '195'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '196'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '197'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '198'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '199'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '200'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '201'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '202'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '203'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '204'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '205'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '206'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '207'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '208'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '209'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '210'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '211'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '212'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '213'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '214'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   13,
#   'with mini-column',
#   '215'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '216'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '217'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '218'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '219'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '220'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '221'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '222'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '223'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '224'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '225'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '226'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '227'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '228'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '229'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '230'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '231'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '232'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '233'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '234'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '235'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '236'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '237'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '238'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '239'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '240'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '241'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '242'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '243'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '244'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '245'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '246'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   15,
#   'with mini-column',
#   '247'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '248'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '249'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '250'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '251'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '252'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '253'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '254'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '255'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '256'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '257'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '258'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '259'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '260'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '261'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '262'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '263'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '264'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '265'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '266'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '267'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '268'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '269'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '270'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '271'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '272'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '273'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '274'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '275'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '276'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '277'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '278'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '279'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '280'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '281'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '282'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '283'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '284'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '285'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '286'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '287'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '288'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '289'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '290'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '291'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '292'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '293'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '294'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '295'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '296'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '297'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '298'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '299'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '300'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '301'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '302'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '303'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '304'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '305'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '306'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '307'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   14,
#   'with mini-column',
#   '308'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '309'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '310'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '311'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '312'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '313'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '314'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '315'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '316'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '317'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '318'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '319'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '320'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '321'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '322'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '323'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '324'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '325'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '326'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '327'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '328'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '329'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '330'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '331'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '332'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '333'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '334'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '335'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '336'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '337'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '338'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '339'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '340'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '341'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '342'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '343'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '344'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '345'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '346'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '347'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '348'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '349'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '350'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '351'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '352'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '353'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '354'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '355'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '356'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '357'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '358'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '359'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '360'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '361'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '362'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '363'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '364'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '365'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '366'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '367'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '368'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '369'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '370'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '371'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '372'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '373'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '374'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '375'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '376'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '377'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '378'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '379'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '380'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '381'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '382'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '383'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '384'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '385'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '386'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '387'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '388'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '389'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '390'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '391'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '392'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '393'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '394'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '395'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '396'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '397'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '398'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '399'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '400'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '401'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '402'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '403'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '404'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '405'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '406'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '407'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '408'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '409'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '410'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '411'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '412'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '413'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '414'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '415'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '416'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '417'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '418'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '419'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '420'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '421'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   14,
#   'with mini-column',
#   '422'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '423'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '424'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '425'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '426'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '427'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '428'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '429'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '430'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '431'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '432'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '433'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '434'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '435'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '436'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '437'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '438'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '439'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '440'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '441'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '442'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '443'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '444'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '445'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '446'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '447'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '448'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '449'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '450'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '451'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '452'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '453'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '454'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '455'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '456'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '457'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '458'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '459'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '460'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '461'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '462'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '463'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '464'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '465'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '466'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   1,
#   'with mini-column',
#   '467'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '468'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '469'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '470'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   14,
#   'with mini-column',
#   '471'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '472'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '473'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '474'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '475'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '476'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '477'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '478'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '479'),
#  ('The input at',
# ...
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '840'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '841'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '842'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '843'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '844'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '845'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '846'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '847'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '848'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '849'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '850'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '851'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '852'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '853'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '854'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '855'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '856'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '857'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '858'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '859'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '860'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '861'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '862'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '863'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '864'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '865'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '866'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '867'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '868'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '869'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '870'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '871'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '872'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '873'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '874'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '875'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '876'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '877'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '878'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '879'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '880'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '881'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '882'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '883'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '884'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   14,
#   'with mini-column',
#   '885'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '886'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '887'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '888'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '889'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '890'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '891'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '892'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '893'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '894'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '895'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '896'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '897'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '898'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '899'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '900'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '901'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '902'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '903'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '904'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '905'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '906'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '907'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '908'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '909'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '910'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '911'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '912'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '913'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '914'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '915'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '916'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '917'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '918'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '919'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '920'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '921'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '922'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '923'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '924'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '925'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '926'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '927'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '928'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '929'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '930'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '931'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '932'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '933'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '934'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '935'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '936'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '937'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '938'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '939'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '940'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '941'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '942'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '943'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '944'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '945'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '946'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '947'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '948'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '949'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '950'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   11,
#   'with mini-column',
#   '951'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '952'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '953'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '954'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '955'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '956'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '957'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '958'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '959'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '960'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '961'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '962'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '963'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '964'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '965'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '966'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '967'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '968'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '969'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '970'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '971'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '972'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '973'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '974'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '975'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '976'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '977'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '978'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '979'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   4,
#   'with mini-column',
#   '980'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '981'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   2,
#   'with mini-column',
#   '982'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '983'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '984'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '985'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '986'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   3,
#   'with mini-column',
#   '987'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '988'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '989'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   9,
#   'with mini-column',
#   '990'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   7,
#   'with mini-column',
#   '991'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '992'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '993'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '994'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   5,
#   'with mini-column',
#   '995'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   12,
#   'with mini-column',
#   '996'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   10,
#   'with mini-column',
#   '997'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   6,
#   'with mini-column',
#   '998'),
#  ('The input at',
#   'TimeStep_0',
#   'has an overlap score of',
#   8,
#   'with mini-column',
#   '999'),
#  ...]

# %% [markdown]
# This notebook is getting a bit long, so let's revisit the gym example in the next one
