# %%
import numpy as np
import sympy as sp
import shared_functions as sf
from IPython.display import HTML
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %% [markdown]
# In the last notebook we extended our understanding of summation to include the Pascale Array, a structure generated by entries index, we found all kinds o patterns and established the Pascal Summation Theorem to understand this construction
#
# But we still need to move toward Algebraic Calculus, and in this notebook we are going to extend this ideas from late time of Pascal Matrix with and combine with the power of linear algebra.
#
# We have already looked in detail at linear algebra, and it a powerful way. For me, this subject is about like an protocal that joins so much of math, and makes it not dependent on particular number systems and introduces powerful ideas of relativity into the way we think about counting.
#
# Recall that the key problem of Algebra is how to solve systems of equations.

# %% [markdown]
# get Bournouli formula.....its big! leads to bernouli nummers....the B_j are bernoulli numbers, facinating weuqnce  of rational numbers....note all of odd bernouli numbers are 0 execpt for 1 - check out slown A000367 and A002445 are numerators and denominators of bernoulie numbers
#
#
# We will exploit telescoping area - successive differences...we see lots of cancellation....recal the binomial theorum....combine binomial theorem with teslopit series...exploit telesopiing series.....
#
# We can create linear equations and solve in matrix form...end up with general story....we get the inverse - we end up inverse matrix with bernouli numbers....
