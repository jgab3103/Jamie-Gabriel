# %% [markdown]
# <i>STATUS: Draft<i>

# %%
import numpy as np
import sympy as sp
from IPython.display import HTML
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.patches import Rectangle, Circle, ConnectionPatch
from IPython.display import Image
import sys
import pandas as pd
import HTM_Code as hc
import colorsys
import time as timer

# %% [markdown]
# In the last notebook we built a first Spatial Pooler. In this one, we will create another version, but this time we will use the hotgym data. This data set is discussed in both episodes 7 and 8:

# %%
ep7 = '<iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
ep8 = '<iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
table = '<table style="width:100%"><tr><td>' + ep7 + '</td><td>' + ep8 + '</td></tr>'
HTML(table)
# Out:
# <table style="width:100%"><tr><td><iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td><td><iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td></tr>

# %% [markdown]
# Its also time now to finally use some real data. Its a data set of 4391 records, that tracks power consuptiom in a gymnasium over time. Let's import the data and have a look at it:

# %%
df = pd.read_csv("./data/gymdata.csv", header=1)
df = df.rename(columns={"datetime": "date_time", "float": "power_consumption"})
df = df.iloc[1:]
df.head()
# Out:
#      date_time  power_consumption
# 1  7/2/10 0:00               21.2
# 2  7/2/10 1:00               16.4
# 3  7/2/10 2:00                4.7
# 4  7/2/10 3:00                4.7
# 5  7/2/10 4:00                4.6

# %% [markdown]
# Let's plot the first 1000 records to get a sense of how things look:

# %%
df.power_consumption[:1000].plot(figsize = (18,2))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Next, let's do bit of work on the data set, just to clean up the columns, to seperate date and time, and create an indicator of whether its weekend or not, so the data can easily be placed in a multi-encoder

# %%
df.date_time = pd.to_datetime(df.date_time, format="%m/%d/%y %H:%M")
df['date'] = [d.date() for d in df.date_time]
df['time_of_day'] = [d.time() for d in df.date_time]
df['weekday'] = [d.weekday() for d in df.date]
df['is_weekend'] = df.loc[df.weekday < 4, 'weekday'] = 0
df['is_weekend'] = df.loc[df.weekday >= 4, 'weekday'] = 1
df = df.drop('date_time', axis=1)
df = df.drop('weekday', axis=1)

df.head()
# Out:
#    power_consumption        date time_of_day  is_weekend
# 1               21.2  2010-07-02    00:00:00           1
# 2               16.4  2010-07-02    01:00:00           1
# 3                4.7  2010-07-02    02:00:00           1
# 4                4.7  2010-07-02    03:00:00           1
# 5                4.6  2010-07-02    04:00:00           1

# %% [markdown]
# The other thing we will bring in at this point start referencing at this point is a glossary. From episode 7 there is alot of nomencalture with all the HTM stuff, and we need a way to organise it careful with the nomenclature. I want to have it as a handy reference so have just created a spreadhseet, and will now so let's bring that in too and sort it by spatial pooler tag, subtle differences across different things so we need to be start beign really careful with the way we are using language.
#
# We will also start working more closely with Nupic Code Base at this point

# %%
glossary = pd.read_csv("./data/glossary.csv", header=0)
glossary.loc[glossary['Tags'].str.contains("spatial pooler")].style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# #T_04b4e_row0_col0,#T_04b4e_row0_col1,#T_04b4e_row0_col2,#T_04b4e_row0_col3,#T_04b4e_row1_col0,#T_04b4e_row1_col1,#T_04b4e_row1_col2,#T_04b4e_row1_col3,#T_04b4e_row2_col0,#T_04b4e_row2_col1,#T_04b4e_row2_col2,#T_04b4e_row2_col3,#T_04b4e_row3_col0,#T_04b4e_row3_col1,#T_04b4e_row3_col2,#T_04b4e_row3_col3,#T_04b4e_row4_col0,#T_04b4e_row4_col1,#T_04b4e_row4_col2,#T_04b4e_row4_col3,#T_04b4e_row5_col0,#T_04b4e_row5_col1,#T_04b4e_row5_col2,#T_04b4e_row5_col3,#T_04b4e_row6_col0,#T_04b4e_row6_col1,#T_04b4e_row6_col2,#T_04b4e_row6_col3,#T_04b4e_row7_col0,#T_04b4e_row7_col1,#T_04b4e_row7_col2,#T_04b4e_row7_col3,#T_04b4e_row8_col0,#T_04b4e_row8_col1,#T_04b4e_row8_col2,#T_04b4e_row8_col3{
#             text-align:  left;
#         }</style><table id="T_04b4e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Tags</th>        <th class="col_heading level0 col1" >Term</th>        <th class="col_heading level0 col2" >ParamName</th>        <th class="col_heading level0 col3" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04b4e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_04b4e_row0_col0" class="data row0 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row0_col1" class="data row0 col1" >Column</td>
#                         <td id="T_04b4e_row0_col2" class="data row0 col2" >column</td>
#                         <td id="T_04b4e_row0_col3" class="data row0 col3" >An HTM region is organized in columns of cells. The SP operates at the column-level, where a column of a cells function as a single computational unit.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_04b4e_row1_col0" class="data row1 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row1_col1" class="data row1 col1" >Inhibition</td>
#                         <td id="T_04b4e_row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_04b4e_row1_col3" class="data row1 col3" >The mechanism for maintaining sparse activations of neurons. In the SP this manifests as columns inhibiting nearby columns from becoming active.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_04b4e_row2_col0" class="data row2 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row2_col1" class="data row2 col1" >Inhibition radius</td>
#                         <td id="T_04b4e_row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_04b4e_row2_col3" class="data row2 col3" >The size of a column's local neighborhood, within which columns may inhibit each other from becoming active.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_04b4e_row3_col0" class="data row3 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row3_col1" class="data row3 col1" >Active duty cycle</td>
#                         <td id="T_04b4e_row3_col2" class="data row3 col2" >activeDutyCycle</td>
#                         <td id="T_04b4e_row3_col3" class="data row3 col3" >A moving average denoting the frequency of column activation.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_04b4e_row4_col0" class="data row4 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row4_col1" class="data row4 col1" >Overlap duty cycle</td>
#                         <td id="T_04b4e_row4_col2" class="data row4 col2" >overlapDutyCycle</td>
#                         <td id="T_04b4e_row4_col3" class="data row4 col3" >A moving average denoting the frequency of the column's overlap value being at least equal to the proximal segment activation threshold.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_04b4e_row5_col0" class="data row5 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row5_col1" class="data row5 col1" >Receptive field</td>
#                         <td id="T_04b4e_row5_col2" class="data row5 col2" >receptiveReceptiveField</td>
#                         <td id="T_04b4e_row5_col3" class="data row5 col3" >The input space that a column can potentially connect to</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_04b4e_row6_col0" class="data row6 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row6_col1" class="data row6 col1" >Permance value</td>
#                         <td id="T_04b4e_row6_col2" class="data row6 col2" >permancePermanceValue</td>
#                         <td id="T_04b4e_row6_col3" class="data row6 col3" >indicates the amount of growth between a mini-column in the Spatial Pooling algorithm and one of the cells in its receptive field. Acceptable values are [0,1].</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_04b4e_row7_col0" class="data row7 col0" >spatial pooler</td>
#                         <td id="T_04b4e_row7_col1" class="data row7 col1" >Permance threshold</td>
#                         <td id="T_04b4e_row7_col2" class="data row7 col2" >permancePermanceThreshold</td>
#                         <td id="T_04b4e_row7_col3" class="data row7 col3" >If a synapse's permanence is above this value, it is considered fully connected.</td>
#             </tr>
#             <tr>
#                         <th id="T_04b4e_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_04b4e_row8_col0" class="data row8 col0" >spatial pooler; neuroscience</td>
#                         <td id="T_04b4e_row8_col1" class="data row8 col1" >Synapse</td>
#                         <td id="T_04b4e_row8_col2" class="data row8 col2" >nan</td>
#                         <td id="T_04b4e_row8_col3" class="data row8 col3" >A junction between cells. In the Spatial Pooling algorithm, synapses on a column's dendritic segment connect to bits in the input space. A synapse can be in the following states: Connected: permanence is above the threshold, Potential: permanence is below the threshold, Unconnected: does not have the ability to connect.</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# With that out of the way, let's create an instance of a MultiEncoder and put our data into it. We will need four encoders, one for power consumption, one for date, one for time of day, and one for weekend:

# %% [markdown]
# Now let's put all those into a single encoder, the inputs ready for our spatial pooler.

# %% [markdown]
# Now let's create new version of our Spatial Pooler. It will do much of the previous version, but a number of extra features, that get discussed in episode 8. We will also model our Spatial Pooler more along the lines of <a href="#">https://github.com/numenta/nupic/blob/master/src/nupic/algorithms/spatial_pooler.py</a>. We will use similiar variable names, but we will keep the methods a bit simpler to emphasise the various steps in what is happening. The steps will be pretty linear and our code will do the following:
#
# 1. <code>intialiseColumnsToInputSpace()</code>
# 2. <code>addInputsToSpatialPooler()</code>
# 3. <code>computeOverlapOfInputAndActiveColumn()</code>
# 4. <code>updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace()</code>
#
# We will also create a <code>getSummary()</code> function to keep track of things, and <code> create_comparison_from_each_bit_in_input_space_to_its_active_columns()</code> to provide some data so we can look at any given input space and how it is connected:

# %%
class SpatialPoolerV3:
    def __init__(self,
               inputDimensions=[4, 4],
               columnDimensions=[32, 32],
               potentialRadius=16,
               potentialPct=0.5,
               globalInhibition=True,
               numActiveColumnsPerInhArea=10.0,
               stimulusThreshold=0,
               synPermInactiveDec=0.008,
               synPermActiveInc=0.05,
               synPermConnected=0.10):
        
        self._numInputs = np.prod(inputDimensions)
        self._numColumns = np.prod(columnDimensions)
        self._columnDimensions = columnDimensions
        self._inputDimensions = inputDimensions
        self._potentialRadius = int(max(potentialRadius, self._numInputs))
        self._potentialPct = potentialPct
        self._globalInhibition = globalInhibition 
        self._numActiveColumnsPerInhArea = int(numActiveColumnsPerInhArea)
        self._stimulusThreshold = stimulusThreshold
        self._synPermInactiveDec = synPermInactiveDec
        self._synPermActiveInc = synPermActiveInc
        self._synPermConnected = synPermConnected
        self._columns = {}
        self._columnsInitialised = False
        self._learningIsOn = True
        self._inputs = []
        self.connections_of_bits_in_input_space_to_columns = None
        self.inputs_connected_to_columns = []
    

    def initialiseColumnsToInputSpace(self):
        timerStart = timer.perf_counter()
        potentialPoolSize = int(self._potentialPct * self._numInputs)

        for i in range(self._numColumns):
        
            potentialConnections = hc.create_randomised_sdr(self._numInputs, potentialPoolSize)
            nonConnectedColumns = [x for x in range(0, self._numInputs) if x not in potentialConnections]
            potentialConnectionsPermanenceValues = np.random.normal(self._synPermConnected, 0.01, potentialPoolSize)
            activeColumns = []
            
            for j in range(0, len(potentialConnections)):
                if potentialConnectionsPermanenceValues[j] > 0.1:
                    activeColumns.append(potentialConnections[j])
                    
            self._columns[i] = {'potentialConnections': potentialConnections,
                                'nonConnectedColumns': nonConnectedColumns,
                                'potentialConnectionsPermanenceValues': potentialConnectionsPermanenceValues,
                                'activeColumns': activeColumns
                              }
        self._columnsInitialised = True
        timerEnd = timer.perf_counter()
        self.getSummary(summary_type = 2, timeTaken = timerEnd - timerStart)
    

    
    def compareEachBitInInputSpaceToItsConnectedActiveColumns(self):
        d = []
        for key, value in self._columns.items():
            for i in value['activeColumns']:
                d.append([i, key])
        d.sort()
        e = {}
        f = []
        d.append([-1, -1])
        for j in range(1, len(d) - 1):
            f.append(d[j][1])
            if d[j][0] != d[j + 1][0]:
                e[d[j][0]] = f
                f = []
        self.connections_of_bits_in_input_space_to_columns = e
        
        
    def addInputsToSpatialPooler(self, inputs, multiple = True):
        self._inputs = inputs
    

    def updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace(self, inputConnectedToColumns):
        print("learning is on")
        print(inputConnectedToColumns)
    
    def computeOverlapOfInputsAndActiveColumns(self):
        timerStart = timer.perf_counter()
        for i in range(len(self._inputs)):
            for key, value in self._columns.items():
                temp_dict = {}
                overlap = list(set(value['activeColumns']).intersection(self._inputs[i].active_bits))
                temp_dict[self._inputs[i].label] = [{"column": key},{"overlap_score": len(overlap)}, {"overlap_bits": overlap}]
                self.inputs_connected_to_columns.append(temp_dict)
            if self._learningIsOn:
                self.updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace(temp_dict)
    
        timerEnd = timer.perf_counter()
        self.getSummary(summary_type = 3, timeTaken = timerEnd - timerStart)

    

    
    def getSummary(self, summary_type, timeTaken = 0):
        print("\n----------------- SUMMARY -------------------------")
        if summary_type == 1:
            print("|L1| Column space size (numColumns):", self._numColumns)
            print("|L2| Input space size (numInputs):", self._numInputs)
            print("|L3| Input bits visible to each columns, or receptive field (potentialRadius):", self._potentialRadius)
            print("|L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct):", self._potentialPct * 100, "%")
            print("|L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition):", self._globalInhibition)
            print("|L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea):", self._numActiveColumnsPerInhArea)
            print("|L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold):", self._stimulusThreshold)
            print("|L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec):", self._synPermInactiveDec)
            print("|L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc):", self._synPermActiveInc)
            print("|L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected):", self._synPermConnected)
            print("|L11| Columns initialised:", self._columnsInitialised)
        elif summary_type == 2:
            print("|L1| Based on initital paramaters, each of the", self._numColumns, "columns in this Spatial Pooler has a potential connection to", self._potentialPct, "of bits in the input space")
            print("|L1| The values of all potential connection strength are normally distributed between approximately", np.round(min(self._columns[0]['potentialConnectionsPermanenceValues']), 3),
              "and", np.round(max(self._columns[0]['potentialConnectionsPermanenceValues']),3))
            print("|L1| Based on the connection threshold set at", self._synPermConnected,",", len(self._columns[0]['activeColumns']), "columns will now be active in the Spatial Pooler")
            print("|L1| Time elapsed during initialisation:", np.round(timeTaken,3), "seconds.")
        elif summary_type == 3:
            print("|L1| Some metric:")
            print("|L1| Time elapsed during initialisation:", np.round(timeTaken,3), "seconds.")

        
s1 = SpatialPoolerV3()
s1.getSummary(1)
s1.initialiseColumnsToInputSpace()
inputSpaceSize = 10
activeBitsInInputs = 2
gymPowerConsumptionInputs = [hc.SDR(inputSpaceSize,activeBitsInInputs, "input_" + str(i)) for i in range(0,1024)]
s1.addInputsToSpatialPooler(gymPowerConsumptionInputs)
s1.computeOverlapOfInputsAndActiveColumns()
#s1.inputs_connected_to_columns
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Column space size (numColumns): 1024
# |L2| Input space size (numInputs): 16
# |L3| Input bits visible to each columns, or receptive field (potentialRadius): 16
# |L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct): 50.0 %
# |L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition): True
# |L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea): 10
# |L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold): 0
# |L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec): 0.008
# |L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc): 0.05
# |L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected): 0.1
# |L11| Columns initialised: False
#
# ----------------- SUMMARY -------------------------
# |L1| Based on initital paramaters, each of the 1024 columns in this Spatial Pooler has a potential connection to 0.5 of bits in the input space
# |L1| The values of all potential connection strength are normally distributed between approximately 0.082 and 0.122
# |L1| Based on the connection threshold set at 0.1 , 2 columns will now be active in the Spatial Pooler
# |L1| Time elapsed during initialisation: 0.047 seconds.
# learning is on
# {'input_0': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_2': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_3': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_4': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_5': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_6': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_7': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_8': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_9': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_10': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_11': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_12': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_13': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_14': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_15': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_16': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_17': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_18': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_19': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_20': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_21': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_22': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_23': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_24': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_25': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_26': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_27': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_28': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_29': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_30': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_31': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_32': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_33': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_34': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_35': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_36': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_37': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_38': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_39': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_40': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_41': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_42': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_43': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_44': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_45': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_46': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_47': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_48': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_49': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_50': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_51': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_52': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_53': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_54': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_55': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_56': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_57': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_58': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_59': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_60': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_61': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_62': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_63': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_64': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_65': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_66': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_67': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_68': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_69': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_70': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_71': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_72': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_73': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_74': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_75': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_76': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_77': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_78': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_79': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_80': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_81': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_82': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_83': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_84': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_85': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_86': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_87': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_88': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_89': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_90': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_91': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_92': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_93': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_94': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_95': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_96': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_97': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_98': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_99': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_100': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_101': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_102': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_103': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_104': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_105': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_106': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_107': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_108': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_109': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_110': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_111': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_112': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_113': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_114': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_115': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_116': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_117': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_118': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_119': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_120': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_121': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_122': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_123': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_124': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_125': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_126': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_127': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_128': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_129': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_130': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_131': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_132': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_133': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_134': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_135': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_136': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_137': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_138': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_139': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_140': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_141': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_142': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_143': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_144': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_145': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_146': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_147': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_148': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_149': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_150': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_151': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_152': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_153': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_154': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_155': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_156': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_157': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_158': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_159': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_160': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_161': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_162': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_163': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_164': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_165': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_166': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_167': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_168': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_169': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_170': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_171': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_172': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_173': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_174': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_175': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_176': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_177': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_178': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_179': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_180': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_181': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_182': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_183': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_184': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_185': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_186': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_187': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_188': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_189': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_190': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_191': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_192': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_193': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_194': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_195': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_196': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_197': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_198': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_199': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_200': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_201': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_202': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_203': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_204': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_205': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_206': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_207': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_208': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_209': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_210': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_211': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_212': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_213': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_214': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_215': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_216': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_217': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_218': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_219': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_220': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_221': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_222': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_223': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_224': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_225': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_226': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input
[{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_902': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_903': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_904': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_905': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_906': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_907': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_908': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_909': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_910': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_911': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_912': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_913': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_914': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_915': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_916': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_917': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_918': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_919': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_920': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_921': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_922': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_923': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_924': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_925': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_926': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_927': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_928': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_929': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_930': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_931': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_932': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_933': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_934': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_935': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_936': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_937': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_938': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_939': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_940': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_941': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_942': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_943': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_944': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_945': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_946': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_947': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_948': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_949': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_950': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_951': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_952': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_953': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_954': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_955': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_956': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_957': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_958': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_959': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_960': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_961': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_962': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_963': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_964': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_965': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_966': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_967': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_968': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_969': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_970': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_971': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_972': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_973': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_974': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_975': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_976': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_977': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_978': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_979': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_980': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_981': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_982': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_983': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_984': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_985': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_986': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_987': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_988': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_989': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_990': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_991': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_992': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_993': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_994': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_995': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_996': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_997': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_998': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_999': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1000': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1001': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1002': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1003': [{'column': 1023}, {'overlap_score': 2}, {'overlap_bits': [5, 7]}]}
# learning is on
# {'input_1004': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1005': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_1006': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1007': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1008': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1009': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1010': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_1011': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_1012': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1013': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1014': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1015': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1016': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1017': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1018': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1019': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [5]}]}
# learning is on
# {'input_1020': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1021': [{'column': 1023}, {'overlap_score': 0}, {'overlap_bits': []}]}
# learning is on
# {'input_1022': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
# learning is on
# {'input_1023': [{'column': 1023}, {'overlap_score': 1}, {'overlap_bits': [7]}]}
#
# ----------------- SUMMARY -------------------------
# |L1| Some metric:
# |L1| Time elapsed during initialisation: 8.778 seconds.

# %%
s1 = SpatialPoolerV3()
s1.getSummary(1)
s1.initialiseColumnsToInputSpace()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Column space size (numColumns): 1024
# |L2| Input space size (numInputs): 16
# |L3| Input bits visible to each columns, or receptive field (potentialRadius): 16
# |L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct): 50.0 %
# |L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition): True
# |L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea): 10
# |L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold): 0
# |L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec): 0.008
# |L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc): 0.05
# |L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected): 0.1
# |L11| Columns initialised: False
#
# ----------------- SUMMARY -------------------------
# |L1| Based on initital paramaters, each of the 1024 columns in this Spatial Pooler has a potential connection to 0.5 of bits in the input space
# |L1| The values of all potential connection strength are normally distributed between approximately 0.085 and 0.114
# |L1| Based on the connection threshold set at 0.1 , 6 columns will now be active in the Spatial Pooler
# |L1| Time elapsed during initialisation: 0.045 seconds.

# %% [markdown]
# So we are really starting to see a time lag now. Again, don't panic, we are aiming for clarity not speed right now. Our next step is to add the inputs. We will need to pass the gym data into an encoder to do this

# %%
# create enclder

# %%
inputSpaceSize = 10
activeBitsInInputs = 2
gymPowerConsumptionInputs = [hc.SDR(inputSpaceSize,activeBitsInInputs, "input_" + str(i)) for i in range(0,1024)]

# %% [markdown]
# So we now have semantically related data points, for each time step in the power consumption data. Let's get a summary of that first HDR

# %%
gymPowerConsumptionInputs[0].get_summary()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Label: input_0
# |L1| Input space size of SDR: 10
# |L2| Number of active bits in SDR: 2
# |L3| Percentage of active bits: 20.0 %
# |L3| Active bits: [9, 4]

# %%
s1.addInputsToSpatialPooler(gymPowerConsumptionInputs)

# %%
s1.compareEachBitInInputSpaceToItsConnectedActiveColumns()

# %%
randomBitsInInputSpace = np.random.randint(0, 16, 2)
randomBitsInInputSpace
# Out:
# array([2, 4])

# %%
inputSize = 1024
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(18, 4))

ax1 = hc.create_axis_for_sdr(ax1, np.sqrt(inputSize) + 1, np.sqrt(inputSize) + 1, 
                             20, "Input bit at " + str(randomBitsInInputSpace[0]))
ax2 = hc.create_axis_for_sdr(ax2, np.sqrt(4096) + 1, np.sqrt(4096) + 1, 
                             20, "Active columns related to input " + str(randomBitsInInputSpace[0]))

ax3 = hc.create_axis_for_sdr(ax3, np.sqrt(inputSize) + 1, np.sqrt(inputSize) + 1, 
                             20, "Input bit at " + str(randomBitsInInputSpace[1]))
ax4 = hc.create_axis_for_sdr(ax4, np.sqrt(4096) + 1, np.sqrt(4096) + 1, 
                             20, "Active columns related to input " + str(randomBitsInInputSpace[1]))

coords1 = hc.convert_sdr_to_tuple_for_visualisation([randomBitsInInputSpace[0]], 1024)
coords2 = hc.convert_sdr_to_tuple_for_visualisation(s1.connections_of_bits_in_input_space_to_columns[randomBitsInInputSpace[0]], 4096)
coords3 = hc.convert_sdr_to_tuple_for_visualisation([randomBitsInInputSpace[1]], 1024)
coords4 = hc.convert_sdr_to_tuple_for_visualisation(s1.connections_of_bits_in_input_space_to_columns[randomBitsInInputSpace[1]], 4096)

p = [ax1.add_patch(Rectangle(coords1[i], 1, 1, color = "blue")) for i in range(len(coords1))]
p = [ax2.add_patch(Rectangle(coords2[i], 1, 1, color = "#b30000")) for i in range(len(coords2))]
p = [ax3.add_patch(Rectangle(coords3[i], 1, 1, color = "blue")) for i in range(len(coords3))]
p = [ax4.add_patch(Rectangle(coords4[i], 1, 1, color = "#b30000")) for i in range(len(coords4))]

# %%
s1.computeOverlapOfInputsAndActiveColumns()

# %%
s1.inputs_connected_to_columns
# Out:
# [{'input_0': [{'column': 0}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 1}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 2}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 3}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 4}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 5}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 6}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 7}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 8}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 9}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 10}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 11}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 12}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 13}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 14}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 15}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 16}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 17}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 18}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 19}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 20}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 21}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 22}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 23}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 24}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 25}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 26}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 27}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 28}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 29}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 30}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 31}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 32}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 33}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 34}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 35}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 36}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 37}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 38}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 39}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 40}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 41}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 42}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 43}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 44}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 45}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 46}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 47}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 48}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 49}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 50}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 51}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 52}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 53}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 54}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 55}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 56}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 57}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 58}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 59}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 60}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 61}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 62}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 63}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 64}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 65}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 66}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 67}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 68}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 69}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 70}, {'overlap_score': 1}, {'overlap_bits': [8]}]},
#  {'input_0': [{'column': 71}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 72}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 73}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 74}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 75}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 76}, {'overlap_score': 2}, {'overlap_bits': [8, 2]}]},
#  {'input_0': [{'column': 77}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column': 78}, {'overlap_score': 1}, {'overlap_bits': [2]}]},
#  {'input_0': [{'column': 79}, {'overlap_score': 0}, {'overlap_bits': []}]},
#  {'input_0': [{'column':