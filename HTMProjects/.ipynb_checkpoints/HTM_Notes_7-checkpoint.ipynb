# %% [markdown]
# <i>STATUS: Draft<i>

# %%
import numpy as np
import sympy as sp
from IPython.display import HTML, display
import ipywidgets as widgets
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.patches import Rectangle, Circle, ConnectionPatch
from IPython.display import Image
import sys
import pandas as pd
import HTM_Code as hc
import colorsys
import time as timer

# %% [markdown]
# In the last notebook we built a first Spatial Pooler. In this one, we will create another version, but this time we will use the hotgym data. This data set is discussed in both episodes 7 and 8:

# %%
ep7 = '<iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
ep8 = '<iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>'
table = '<table style="width:100%"><tr><td>' + ep7 + '</td><td>' + ep8 + '</td></tr>'
HTML(table)
# Out:
# <table style="width:100%"><tr><td><iframe style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/R5UoFNtv5AU" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td><td><iframe  style="background:#99ddff; color:black; padding: 10px" width="400" height="315" src="https://www.youtube.com/embed/rHvjykCIrZM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></td></tr>

# %% [markdown]
# Its also time now to finally use some real data. Its a data set of 4391 records, that tracks power consuptiom in a gymnasium over time. Let's import the data and have a look at it:

# %%
df = pd.read_csv("./data/gymdata.csv", header=1)
df = df.rename(columns={"datetime": "date_time", "float": "power_consumption"})
df = df.iloc[1:]
df.head()
# Out:
#      date_time  power_consumption
# 1  7/2/10 0:00               21.2
# 2  7/2/10 1:00               16.4
# 3  7/2/10 2:00                4.7
# 4  7/2/10 3:00                4.7
# 5  7/2/10 4:00                4.6

# %% [markdown]
# Let's plot the first 1000 records to get a sense of how things look:

# %%
df.power_consumption[:1000].plot(figsize = (18,2))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Next, let's do bit of work on the data set, just to clean up the columns, to seperate date and time, and create an indicator of whether its weekend or not, so the data can easily be placed in a multi-encoder

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
df.date_time = pd.to_datetime(df.date_time, format="%m/%d/%y %H:%M")
df['date'] = [d.date() for d in df.date_time]
df['time_of_day'] = [d.time() for d in df.date_time]
df['weekday'] = [d.weekday() for d in df.date]
df['is_weekend'] = df.loc[df.weekday < 4, 'weekday'] = 0
df['is_weekend'] = df.loc[df.weekday >= 4, 'weekday'] = 1
df = df.drop('date_time', axis=1)
df = df.drop('weekday', axis=1)

df.head()
# Out:
#    power_consumption        date time_of_day  is_weekend
# 1               21.2  2010-07-02    00:00:00           1
# 2               16.4  2010-07-02    01:00:00           1
# 3                4.7  2010-07-02    02:00:00           1
# 4                4.7  2010-07-02    03:00:00           1
# 5                4.6  2010-07-02    04:00:00           1

# %% [markdown]
# The other thing we will bring in at this point start referencing at this point is a glossary. From episode 7 there is alot of nomencalture with all the HTM stuff, and we need a way to organise it careful with the nomenclature. I want to have it as a handy reference so have just created a spreadhseet, and will now so let's bring that in too and sort it by spatial pooler tag, subtle differences across different things so we need to be start beign really careful with the way we are using language.
#
# We will also start working more closely with Nupic Code Base at this point

# %%
glossary = pd.read_csv("./data/glossary.csv", header=0)
glossary.loc[glossary['Tags'].str.contains("spatial pooler")].style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
# #T_bc567_row0_col0,#T_bc567_row0_col1,#T_bc567_row0_col2,#T_bc567_row0_col3,#T_bc567_row1_col0,#T_bc567_row1_col1,#T_bc567_row1_col2,#T_bc567_row1_col3,#T_bc567_row2_col0,#T_bc567_row2_col1,#T_bc567_row2_col2,#T_bc567_row2_col3,#T_bc567_row3_col0,#T_bc567_row3_col1,#T_bc567_row3_col2,#T_bc567_row3_col3,#T_bc567_row4_col0,#T_bc567_row4_col1,#T_bc567_row4_col2,#T_bc567_row4_col3,#T_bc567_row5_col0,#T_bc567_row5_col1,#T_bc567_row5_col2,#T_bc567_row5_col3,#T_bc567_row6_col0,#T_bc567_row6_col1,#T_bc567_row6_col2,#T_bc567_row6_col3,#T_bc567_row7_col0,#T_bc567_row7_col1,#T_bc567_row7_col2,#T_bc567_row7_col3,#T_bc567_row8_col0,#T_bc567_row8_col1,#T_bc567_row8_col2,#T_bc567_row8_col3{
#             text-align:  left;
#         }</style><table id="T_bc567_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Tags</th>        <th class="col_heading level0 col1" >Term</th>        <th class="col_heading level0 col2" >ParamName</th>        <th class="col_heading level0 col3" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc567_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bc567_row0_col0" class="data row0 col0" >spatial pooler</td>
#                         <td id="T_bc567_row0_col1" class="data row0 col1" >Column</td>
#                         <td id="T_bc567_row0_col2" class="data row0 col2" >column</td>
#                         <td id="T_bc567_row0_col3" class="data row0 col3" >An HTM region is organized in columns of cells. The SP operates at the column-level, where a column of a cells function as a single computational unit.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bc567_row1_col0" class="data row1 col0" >spatial pooler</td>
#                         <td id="T_bc567_row1_col1" class="data row1 col1" >Inhibition</td>
#                         <td id="T_bc567_row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_bc567_row1_col3" class="data row1 col3" >The mechanism for maintaining sparse activations of neurons. In the SP this manifests as columns inhibiting nearby columns from becoming active.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bc567_row2_col0" class="data row2 col0" >spatial pooler</td>
#                         <td id="T_bc567_row2_col1" class="data row2 col1" >Inhibition radius</td>
#                         <td id="T_bc567_row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_bc567_row2_col3" class="data row2 col3" >The size of a column's local neighborhood, within which columns may inhibit each other from becoming active.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bc567_row3_col0" class="data row3 col0" >spatial pooler</td>
#                         <td id="T_bc567_row3_col1" class="data row3 col1" >Active duty cycle</td>
#                         <td id="T_bc567_row3_col2" class="data row3 col2" >activeDutyCycle</td>
#                         <td id="T_bc567_row3_col3" class="data row3 col3" >A moving average denoting the frequency of column activation.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bc567_row4_col0" class="data row4 col0" >spatial pooler</td>
#                         <td id="T_bc567_row4_col1" class="data row4 col1" >Overlap duty cycle</td>
#                         <td id="T_bc567_row4_col2" class="data row4 col2" >overlapDutyCycle</td>
#                         <td id="T_bc567_row4_col3" class="data row4 col3" >A moving average denoting the frequency of the column's overlap value being at least equal to the proximal segment activation threshold.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_bc567_row5_col0" class="data row5 col0" >spatial pooler</td>
#                         <td id="T_bc567_row5_col1" class="data row5 col1" >Receptive field</td>
#                         <td id="T_bc567_row5_col2" class="data row5 col2" >receptiveReceptiveField</td>
#                         <td id="T_bc567_row5_col3" class="data row5 col3" >The input space that a column can potentially connect to</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_bc567_row6_col0" class="data row6 col0" >spatial pooler</td>
#                         <td id="T_bc567_row6_col1" class="data row6 col1" >Permance value</td>
#                         <td id="T_bc567_row6_col2" class="data row6 col2" >permancePermanceValue</td>
#                         <td id="T_bc567_row6_col3" class="data row6 col3" >indicates the amount of growth between a mini-column in the Spatial Pooling algorithm and one of the cells in its receptive field. Acceptable values are [0,1].</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_bc567_row7_col0" class="data row7 col0" >spatial pooler</td>
#                         <td id="T_bc567_row7_col1" class="data row7 col1" >Permance threshold</td>
#                         <td id="T_bc567_row7_col2" class="data row7 col2" >permancePermanceThreshold</td>
#                         <td id="T_bc567_row7_col3" class="data row7 col3" >If a synapse's permanence is above this value, it is considered fully connected.</td>
#             </tr>
#             <tr>
#                         <th id="T_bc567_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_bc567_row8_col0" class="data row8 col0" >spatial pooler; neuroscience</td>
#                         <td id="T_bc567_row8_col1" class="data row8 col1" >Synapse</td>
#                         <td id="T_bc567_row8_col2" class="data row8 col2" >nan</td>
#                         <td id="T_bc567_row8_col3" class="data row8 col3" >A junction between cells. In the Spatial Pooling algorithm, synapses on a column's dendritic segment connect to bits in the input space. A synapse can be in the following states: Connected: permanence is above the threshold, Potential: permanence is below the threshold, Unconnected: does not have the ability to connect.</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# With that out of the way, let's create an instance of a MultiEncoder and put our data into it. We will need four encoders, one for power consumption, one for date, one for time of day, and one for weekend:

# %% [markdown]
# Now let's put all those into a single encoder, the inputs ready for our spatial pooler.

# %% [markdown]
# Now let's create new version of our Spatial Pooler. It will do much of the previous version, but a number of extra features, that get discussed in episode 8. We will also model our Spatial Pooler more along the lines of <a href="#">https://github.com/numenta/nupic/blob/master/src/nupic/algorithms/spatial_pooler.py</a>. We will use similiar variable names, but we will keep the methods a bit simpler to emphasise the various steps in what is happening. The steps will be pretty linear and our code will do the following:
#
# 1. <code>intialiseColumnsToInputSpace()</code>
# 2. <code>addInputsToSpatialPooler()</code>
# 3. <code>computeOverlapOfInputAndActiveColumn()</code>
# 4. <code>updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace()</code>
#
# We will also create a <code>getSummary()</code> function to keep track of things, and <code> create_comparison_from_each_bit_in_input_space_to_its_active_columns()</code> to provide some data so we can look at any given input space and how it is connected:

# %%
class SpatialPoolerV3:
    def __init__(self,
               inputDimensions=[2, 8],
               columnDimensions=[4, 10],
               potentialRadius=16,
               potentialPct=0.5,
               globalInhibition=True,
               numActiveColumnsPerInhArea=8.0,
               stimulusThreshold=0,
               synPermInactiveDec=0.008,
               synPermActiveInc=0.05,
               synPermConnected=0.10):
        
        self._numInputs = np.prod(inputDimensions)
        self._numColumns = np.prod(columnDimensions)
        self._columnDimensions = columnDimensions
        self._inputDimensions = inputDimensions
        self._potentialRadius = int(max(potentialRadius, self._numInputs))
        self._potentialPct = potentialPct
        self._globalInhibition = globalInhibition 
        self._numActiveColumnsPerInhArea = int(numActiveColumnsPerInhArea)
        self._stimulusThreshold = stimulusThreshold
        self._synPermInactiveDec = synPermInactiveDec
        self._synPermActiveInc = synPermActiveInc
        self._synPermConnected = synPermConnected
        self._columns = {}
        self._columnsInitialised = False
        self._learningIsOn = True
        self._inputs = []
        self.connections_of_bits_in_input_space_to_columns = None
        self.inputs_connected_to_columns = []
        self.columnsHistory = []
    

    def initialiseColumnsToInputSpace(self):
        timerStart = timer.perf_counter()
        potentialPoolSize = int(self._potentialPct * self._numInputs)

        for i in range(self._numColumns):
        
            potentialConnections = hc.create_randomised_sdr(self._numInputs, potentialPoolSize)
            nonConnectedColumns = [x for x in range(0, self._numInputs) if x not in potentialConnections]
            potentialConnectionsPermanenceValues = np.random.normal(self._synPermConnected, 0.01, potentialPoolSize)
            activeColumns = []
            
            for j in range(0, len(potentialConnections)):
                if potentialConnectionsPermanenceValues[j] > 0.1:
                    activeColumns.append(potentialConnections[j])
                    
            self._columns[i] = {'potentialConnections': potentialConnections,
                                'nonConnectedColumns': nonConnectedColumns,
                                'potentialConnectionsPermanenceValues': potentialConnectionsPermanenceValues,
                                'activeColumns': activeColumns
                              }
        self._columnsInitialised = True
        timerEnd = timer.perf_counter()
        self.getSummary(summary_type = 2, timeTaken = timerEnd - timerStart)
    

    
    def compareEachBitInInputSpaceToItsConnectedActiveColumns(self):
        d = []
        for key, value in self._columns.items():
            for i in value['activeColumns']:
                d.append([i, key])
        d.sort()
        e = {}
        f = []
        d.append([-1, -1])
        for j in range(1, len(d) - 1):
            f.append(d[j][1])
            if d[j][0] != d[j + 1][0]:
                e[d[j][0]] = f
                f = []
        self.connections_of_bits_in_input_space_to_columns = e
        
        
    def addInputsToSpatialPooler(self, inputs, multiple = True):
        self._inputs = inputs
    
    def updateColumns(self):
        updatedColumns = self._columns.copy()
        self.columnsHistory.append(updatedColumns)
        activeColumns = []
        #print(updatedColumns)
        
        for i in range(0, len(updatedColumns)):
            print("UPDATE EACH ")
            print(updatedColumns[i])
            #for j in [i]['potentialConnections']:
             #  print("DD")
            
            
#             if updatedColumns['potentialConnectionsPermanenceValues'][j] > 0.1:
#                 activeColumns.append(updatedColumns['potentialConnections'][j])
                
#         self._columns[i] = {'potentialConnections': potentialConnections,
#                                 'nonConnectedColumns': nonConnectedColumns,
#                                 'potentialConnectionsPermanenceValues': potentialConnectionsPermanenceValues,
#                                 'activeColumns': activeColumns
#                               }
                
    def updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace(self,inputAndAllColumnsOverlaps):

        self.updateColumns()       

        inputAndAllColumnsOverlaps.sort(key=lambda item: item.get("overlap_score"), reverse = True)
        
        inputAndAllColumnsOverlapsLimitedByActiveColumns = inputAndAllColumnsOverlaps[0:self._numActiveColumnsPerInhArea]
        #print("INPUT")
        for i in range(len(inputAndAllColumnsOverlapsLimitedByActiveColumns)):
            for j in range(len(inputAndAllColumnsOverlapsLimitedByActiveColumns[i]['overlap_bits'])):
                #print("\n##### SUMM")
                #print("Column No:", inputAndAllColumnsOverlapsLimitedByActiveColumns[i]['column'])
                colNumber = inputAndAllColumnsOverlapsLimitedByActiveColumns[i]['column']
                overlappedBit = inputAndAllColumnsOverlapsLimitedByActiveColumns[i]['overlap_bits'][j]
                #print("Increase permance value at: ", inputAndAllColumnsOverlapsLimitedByActiveColumns[i]['overlap_bits'][j])
                #print("COL", self._columns[i])
                try:
                    ind =  self._columns[i]['potentialConnections'].index(overlappedBit)
                except:
                    #print("INDEX IS IN NON CONNECTED COLS")
                    ind = self._columns[i]['nonConnectedColumns'].index(overlappedBit)
                    
                    
                #print("INDEX OF OVERLAPPED BIT", ind)
                #print("INCREASE VALUE: " , self._columns[i]['potentialConnectionsPermanenceValues'][ind])
                self._columns[i]['potentialConnectionsPermanenceValues'][ind] =  self._columns[i]['potentialConnectionsPermanenceValues'][ind] + self._synPermActiveInc
                #print("NEW VAL: ", self._columns[i]['potentialConnectionsPermanenceValues'][ind])
                
                
        for i in range(len(inputAndAllColumnsOverlaps)):
            for j in range(len(inputAndAllColumnsOverlaps[i]['columnsWithoutOverlap'])):
                #print("\n##### SUMM")
                #print("Column No:", inputAndAllColumnsOverlaps[i]['column'])
                colNumber = inputAndAllColumnsOverlaps[i]['column']
                overlappedBit = inputAndAllColumnsOverlaps[i]['columnsWithoutOverlap'][j]
                #print("Decrease permance value at: ", inputAndAllColumnsOverlaps[i]['columnsWithoutOverlap'][j])
                #print("COL", self._columns[i])
                try:
                    ind =  self._columns[i]['potentialConnections'].index(overlappedBit)
                except:
                    #print("INDEX IS IN NON CONNECTED COLS")
                    ind = self._columns[i]['nonConnectedColumns'].index(overlappedBit)
                    
                    
                #print("INDEX OF OVERLAPPED BIT", ind)
                #print("CURRENT VALUE: " , self._columns[i]['potentialConnectionsPermanenceValues'][ind])
                self._columns[i]['potentialConnectionsPermanenceValues'][ind] =  self._columns[i]['potentialConnectionsPermanenceValues'][ind] - self._synPermInactiveDec
                #print("NEW VAL: ", self._columns[i]['potentialConnectionsPermanenceValues'][ind])
                    

               
    
    def computeOverlapOfInputsAndActiveColumns(self):
        timerStart = timer.perf_counter()
        for i in range(len(self._inputs)):
            inputAndAllColumnsOverlaps = []
            for key, value in self._columns.items():
                overlap = list(set(value['activeColumns']).intersection(self._inputs[i].active_bits))
                nonOverlapped = [j for j in value['activeColumns']  if j not in overlap]
                
                
                inputAndColumnOverlap = {"column": key, 
                                         "overlap_score": len(overlap), 
                                         "overlap_bits": overlap,
                                        "columnsWithoutOverlap": nonOverlapped}
                inputAndAllColumnsOverlaps.append(inputAndColumnOverlap)
                
            if self._learningIsOn:
                
                self.updateColumnPotentialConnectionsAndReinitialiseColumnToInputSpace(inputAndAllColumnsOverlaps)
    
        timerEnd = timer.perf_counter()
        self.getSummary(summary_type = 3, timeTaken = timerEnd - timerStart)

    

    
    def getSummary(self, summary_type, timeTaken = 0):
        print("\n----------------- SUMMARY -------------------------")
        if summary_type == 1:
            print("|L1| Column space size (numColumns):", self._numColumns)
            print("|L2| Input space size (numInputs):", self._numInputs)
            print("|L3| Input bits visible to each columns, or receptive field (potentialRadius):", self._potentialRadius)
            print("|L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct):", self._potentialPct * 100, "%")
            print("|L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition):", self._globalInhibition)
            print("|L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea):", self._numActiveColumnsPerInhArea)
            print("|L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold):", self._stimulusThreshold)
            print("|L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec):", self._synPermInactiveDec)
            print("|L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc):", self._synPermActiveInc)
            print("|L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected):", self._synPermConnected)
            print("|L11| Columns initialised:", self._columnsInitialised)
        elif summary_type == 2:
            print("|L1| Based on initital paramaters, each of the", self._numColumns, "columns in this Spatial Pooler has a potential connection to", self._potentialPct, "of bits in the input space")
            print("|L1| The values of all potential connection strength are normally distributed between approximately", np.round(min(self._columns[0]['potentialConnectionsPermanenceValues']), 3),
              "and", np.round(max(self._columns[0]['potentialConnectionsPermanenceValues']),3))
            print("|L1| Based on the connection threshold set at", self._synPermConnected,",", len(self._columns[0]['activeColumns']), "columns will now be active in the Spatial Pooler")
            print("|L1| Time elapsed during initialisation:", np.round(timeTaken,3), "seconds.")
        elif summary_type == 3:
            print("|L1| Some metric:")
            print("|L1| Time elapsed during initialisation:", np.round(timeTaken,3), "seconds.")

        
s1 = SpatialPoolerV3()
s1.getSummary(1)
s1.initialiseColumnsToInputSpace()
inputSpaceSize = 400
activeBitsInInputs = 20
numberOfInputs = 16
gymPowerConsumptionInputs = [hc.SDR(inputSpaceSize,activeBitsInInputs, "input_" + str(i)) for i in range(0,numberOfInputs)]
s1.addInputsToSpatialPooler(gymPowerConsumptionInputs)
s1.computeOverlapOfInputsAndActiveColumns()
#s1.inputs_connected_to_columns
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Column space size (numColumns): 40
# |L2| Input space size (numInputs): 16
# |L3| Input bits visible to each columns, or receptive field (potentialRadius): 16
# |L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct): 50.0 %
# |L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition): True
# |L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea): 8
# |L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold): 0
# |L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec): 0.008
# |L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc): 0.05
# |L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected): 0.1
# |L11| Columns initialised: False
#
# ----------------- SUMMARY -------------------------
# |L1| Based on initital paramaters, each of the 40 columns in this Spatial Pooler has a potential connection to 0.5 of bits in the input space
# |L1| The values of all potential connection strength are normally distributed between approximately 0.083 and 0.109
# |L1| Based on the connection threshold set at 0.1 , 4 columns will now be active in the Spatial Pooler
# |L1| Time elapsed during initialisation: 0.003 seconds.
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15], 'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13], 'potentialConnectionsPermanenceValues': array([0.08308783, 0.10421608, 0.10857243, 0.10177903, 0.09478531,
#        0.10161969, 0.09301467, 0.09554617]), 'activeColumns': [2, 3, 5, 11]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15], 'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14], 'potentialConnectionsPermanenceValues': array([0.10015523, 0.09519824, 0.07891885, 0.10350115, 0.1025757 ,
#        0.1107477 , 0.09447688, 0.09603579]), 'activeColumns': [2, 8, 9, 10]}
# UPDATE EACH
# {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15], 'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14], 'potentialConnectionsPermanenceValues': array([0.08591662, 0.10466717, 0.09782531, 0.10454678, 0.09099334,
#        0.12363311, 0.10564433, 0.10393386]), 'activeColumns': [5, 7, 11, 13, 15]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15], 'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14], 'potentialConnectionsPermanenceValues': array([0.10261306, 0.08171292, 0.11309911, 0.09176774, 0.10037   ,
#        0.10577827, 0.10735339, 0.11216205]), 'activeColumns': [1, 4, 8, 9, 10, 15]}
# UPDATE EACH
# {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14], 'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15], 'potentialConnectionsPermanenceValues': array([0.08826911, 0.10647595, 0.09398851, 0.08766963, 0.09414916,
#        0.09729476, 0.10717537, 0.10322213]), 'activeColumns': [4, 11, 14]}
# UPDATE EACH
# {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15], 'potentialConnectionsPermanenceValues': array([0.10518548, 0.11051854, 0.08396514, 0.12663074, 0.10475479,
#        0.1065907 , 0.121464  , 0.10608966]), 'activeColumns': [4, 6, 8, 11, 12, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15], 'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12], 'potentialConnectionsPermanenceValues': array([0.10545063, 0.09055556, 0.08748456, 0.10130377, 0.09556536,
#        0.10576843, 0.11133697, 0.08445969]), 'activeColumns': [2, 10, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15], 'potentialConnectionsPermanenceValues': array([0.11454372, 0.09274164, 0.11277999, 0.10895782, 0.09564403,
#        0.1046851 , 0.11765659, 0.1118611 ]), 'activeColumns': [3, 5, 7, 12, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13], 'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([0.10612329, 0.09310957, 0.1165605 , 0.10667969, 0.10633257,
#        0.10555702, 0.09931435, 0.10462302]), 'activeColumns': [1, 3, 5, 6, 10, 13]}
# UPDATE EACH
# {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13], 'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([0.11055965, 0.08760919, 0.07697393, 0.10742684, 0.10390927,
#        0.08221843, 0.10246567, 0.10307598]), 'activeColumns': [4, 7, 8, 11, 13]}
# UPDATE EACH
# {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15], 'potentialConnectionsPermanenceValues': array([0.10708509, 0.11306132, 0.10317626, 0.1104078 , 0.1175785 ,
#        0.10464601, 0.08872974, 0.09987811]), 'activeColumns': [6, 7, 8, 9, 11, 12]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14], 'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15], 'potentialConnectionsPermanenceValues': array([0.09866477, 0.09716574, 0.09784312, 0.10446156, 0.09308253,
#        0.08929289, 0.08176329, 0.09095191]), 'activeColumns': [8]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13], 'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([0.07756171, 0.1038738 , 0.11726295, 0.09433086, 0.10248535,
#        0.09436337, 0.10466211, 0.10367331]), 'activeColumns': [2, 3, 6, 10, 13]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15], 'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13], 'potentialConnectionsPermanenceValues': array([0.0964838 , 0.09621683, 0.10280195, 0.1016247 , 0.0878147 ,
#        0.10061918, 0.11649225, 0.08770307]), 'activeColumns': [7, 9, 11, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 
 13, 14]}
# UPDATE EACH
# {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15], 'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.03277999,  0.07095782,  0.15564403,
#        -0.0073149 ,  0.07965659,  0.0578611 ]), 'activeColumns': [3, 5, 7, 12, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13], 'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([0.03412329, 0.07710957, 0.0365605 , 0.00267969, 0.00233257,
#        0.01755702, 0.06731435, 0.00862302]), 'activeColumns': [1, 3, 5, 6, 10, 13]}
# UPDATE EACH
# {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13], 'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02897393,  0.01942684, -0.00809073,
#         0.03421843,  0.03046567,  0.00707598]), 'activeColumns': [4, 7, 8, 11, 13]}
# UPDATE EACH
# {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15], 'potentialConnectionsPermanenceValues': array([ 0.03508509, -0.00693868, -0.00082374,  0.0064078 ,  0.0135785 ,
#         0.00864601,  0.07272974,  0.05987811]), 'activeColumns': [6, 7, 8, 9, 11, 12]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14], 'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15], 'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.06108253,
#        0.06529289, 0.07376329, 0.07495191]), 'activeColumns': [8]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13], 'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15], 'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#         0.04636337,  0.00866211,  0.00767331]), 'activeColumns': [2, 3, 6, 10, 13]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15], 'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13], 'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0718147 ,
#        -0.00338082,  0.00449225,  0.05570307]), 'activeColumns': [7, 9, 11, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15], 'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14], 'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05962001, 0.0202121 , 0.05316403,
#        0.01554279, 0.0680043 , 0.0138262 ]), 'activeColumns': [9, 11, 15]}
# UPDATE EACH
# {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14], 'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15], 'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.00263193,  0.01995732, -0.00357179,
#         0.05488453, -0.01984114,  0.01859828]), 'activeColumns': [6, 8, 10, 12, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15], 'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10], 'potentialConnectionsPermanenceValues': array([ 0.0776819 ,  0.05945014,  0.05111123,  0.07918764,  0.02210412,
#         0.00449915, -0.00518171,  0.08253063]), 'activeColumns': [12, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15], 'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12], 'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.05526477,  0.01997939, -0.00482766,
#         0.04509614,  0.0134356 ,  0.02719795]), 'activeColumns': [10, 11, 14, 15]}
# UPDATE EACH
# {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15], 'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14], 'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#         0.05644045,  0.04360841,  0.07524886]), 'activeColumns': [2, 5, 6, 7]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15], 'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14], 'potentialConnectionsPermanenceValues': array([0.02581988, 0.07603874, 0.08358476, 0.01446909, 0.01714142,
#        0.04493581, 0.05577492, 0.00163977]), 'activeColumns': [1, 6, 7, 15]}
# UPDATE EACH
# {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14], 'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15], 'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0728603 ,  0.07948511,  0.00468594,  0.01219535,
#         0.0581363 ,  0.02925511, -0.00646039]), 'activeColumns': [7, 8, 13, 14]}
# UPDATE EACH
# {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15], 'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14], 'potentialConnectionsPermanenceValues': array([0.06917063, 0.06577692, 0.04487265, 0.06770512, 0.07540548,
#        0.06667261, 0.046445  , 0.01123246]), 'activeColumns': [15]}
# UPDATE EACH
# {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15], 'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13], 'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.01562884, 0.01553656, 0.05666159,
#        0.01900517, 0.05398968, 0.05445863]), 'activeColumns': [1, 3, 5, 9]}
# UPDATE EACH
# {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 
nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15], 'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.01200852,  0.00685252,  0.00212153,
#         0.00277976, -0.01690685,  0.00357683]), 'activeColumns': [2, 4, 6, 8, 9, 12, 13]}
# UPDATE EACH
# {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14], 'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15], 'potentialConnectionsPermanenceValues': array([0.08311329, 0.01825217, 0.0519128 , 0.01687738, 0.0837158 ,
#        0.05436163, 0.04947601, 0.01842616]), 'activeColumns': [6, 10, 14]}
# UPDATE EACH
# {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15], 'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13], 'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.07236041, -0.01121072,  0.06824294,
#         0.06327231, -0.00213274,  0.00071593]), 'activeColumns': [1, 9, 14, 15]}
# UPDATE EACH
# {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15], 'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13], 'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.00424759,  0.01254257,  0.00803623, -0.00476357,
#         0.00633906,  0.08770252,  0.06663264]), 'activeColumns': [2, 3, 4, 8, 9, 12]}
#
# ----------------- SUMMARY -------------------------
# |L1| Some metric:
# |L1| Time elapsed during initialisation: 0.19 seconds.

# %%
#s1.columnsHistory
# Out:
# [{0: {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.13308783, 0.05021608, 0.12057243, 0.10577903, 0.12078531,
#           0.14761969, 0.14301467, 0.07154617]),
#    'activeColumns': [2, 3, 5, 11]},
#   1: {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07015523, 0.11319824, 0.08091885, 0.10750115, 0.0485757 ,
#           0.1647477 , 0.04647688, 0.11403579]),
#    'activeColumns': [2, 8, 9, 10]},
#   2: {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.12791662, 0.10866717, 0.13182531, 0.05054678, 0.13299334,
#           0.18563311, 0.00164433, 0.04193386]),
#    'activeColumns': [5, 7, 11, 13, 15]},
#   3: {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15],
#    'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07261306,  0.16571292,  0.04309911,  0.10976774,  0.09637   ,
#           -0.00622173,  0.04535339,  0.08216205]),
#    'activeColumns': [1, 4, 8, 9, 10, 15]},
#   4: {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14],
#    'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08826911, 0.01047595, 0.16198851, 0.09766963, 0.17014916,
#           0.06529476, 0.08717537, 0.06522213]),
#    'activeColumns': [4, 11, 14]},
#   5: {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01718548,  0.04851854,  0.06796514,  0.12263074,  0.18275479,
#           -0.0054093 ,  0.075464  ,  0.06808966]),
#    'activeColumns': [4, 6, 8, 11, 12, 13, 14]},
#   6: {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12],
#    'potentialConnectionsPermanenceValues': array([0.02545063, 0.18255556, 0.12148456, 0.04730377, 0.17156536,
#           0.04376843, 0.04133697, 0.05245969]),
#    'activeColumns': [2, 10, 13, 14]},
#   7: {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.08277999,  0.07095782,  0.15564403,
#           -0.0073149 ,  0.06365659,  0.0498611 ]),
#    'activeColumns': [3, 5, 7, 12, 13, 14]},
#   8: {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.03412329,  0.06910957,  0.0285605 , -0.00532031,  0.00233257,
#            0.01755702,  0.06731435,  0.00062302]),
#    'activeColumns': [1, 3, 5, 6, 10, 13]},
#   9: {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13],
#    'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02097393,  0.01142684, -0.01609073,
#            0.01821843,  0.03046567,  0.00707598]),
#    'activeColumns': [4, 7, 8, 11, 13]},
#   10: {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.02708509, -0.00693868, -0.00082374, -0.0015922 ,  0.0135785 ,
#            0.00864601,  0.05672974,  0.05987811]),
#    'activeColumns': [6, 7, 8, 9, 11, 12]},
#   11: {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14],
#    'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.04508253,
#           0.06529289, 0.07376329, 0.06695191]),
#    'activeColumns': [8]},
#   12: {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#            0.03836337,  0.00866211, -0.00032669]),
#    'activeColumns': [2, 3, 6, 10, 13]},
#   13: {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0638147 ,
#           -0.00338082, -0.00350775,  0.04770307]),
#    'activeColumns': [7, 9, 11, 14]},
#   14: {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15],
#    'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05162001, 0.0122121 , 0.04516403,
#           0.01554279, 0.0680043 , 0.0138262 ]),
#    'activeColumns': [9, 11, 15]},
#   15: {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.01063193,  0.00395732, -0.01157179,
#            0.04688453, -0.01984114,  0.01859828]),
#    'activeColumns': [6, 8, 10, 12, 14]},
#   16: {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.0696819 ,  0.05945014,  0.04311123,  0.07918764,  0.02210412,
#           -0.00350085, -0.00518171,  0.08253063]),
#    'activeColumns': [12, 13, 14]},
#   17: {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12],
#    'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.03926477,  0.01197939, -0.01282766,
#            0.04509614,  0.0134356 ,  0.02719795]),
#    'activeColumns': [10, 11, 14, 15]},
#   18: {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#            0.05644045,  0.02760841,  0.07524886]),
#    'activeColumns': [2, 5, 6, 7]},
#   19: {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.02581988,  0.06803874,  0.08358476, -0.00153091,  0.01714142,
#            0.03693581,  0.03977492,  0.00163977]),
#    'activeColumns': [1, 6, 7, 15]},
#   20: {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14],
#    'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0648603 ,  0.07148511,  0.00468594, -0.00380465,
#            0.0581363 ,  0.02125511, -0.00646039]),
#    'activeColumns': [7, 8, 13, 14]},
#   21: {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15],
#    'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06917063, 0.04977692, 0.04487265, 0.06770512, 0.05940548,
#           0.05867261, 0.046445  , 0.00323246]),
#    'activeColumns': [15]},
#   22: {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.00762884, 0.00753656, 0.04866159,
#           0.01900517, 0.03798968, 0.04645863]),
#    'activeColumns': [1, 3, 5, 9]},
#   23: {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 7, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06683895, 0.04755475, 0.04907932, 0.03636167, 0.01135532,
#           0.01238023, 0.05527697, 0.02467528]),
#    'activeColumns': [8, 9, 10, 15]},
#   24: {'potentialConnections': [1, 2, 3, 5, 6, 8, 9, 10],
#    'nonConnectedColumns': [0, 4, 7, 11, 12, 13, 14, 15],
#    'potentialConnectionsPermanenceValues': array([0.0648059 , 0.02799146, 0.03864688, 0.00880883, 0.02588978,
#           0.02618257, 0.00707163, 0.0084867 ]),
#    'activeColumns': [2, 5, 6, 8, 9, 10]},
#   25: {'potentialConnections': [3, 6, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.09739602,  0.08919633,  0.0626757 ,  0.08235884,  0.02349523,
#            0.01429834,  0.04547563, -0.02722086]),
#    'activeColumns': [12, 13, 15]},
#   26: {'potentialConnections': [3, 7, 8, 9, 11, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 6, 10, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.08784849,  0.02261385,  0.00066266,  0.01078032,  0.07058536,
#           -0.00704702,  0.046235  ,  0.00341718]),
#    'activeColumns': [7, 8, 9, 12, 15]},
#   27: {'potentialConnections': [1, 2, 4, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 3, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.01998846, 0.02131688, 0.07710192, 0.06791773, 0.00782088,
#           0.00499674, 0.06054251, 0.03404801]),
#    'activeColumns': [1, 2, 7, 8]},
#   28: {'potentialConnections': [2, 3, 4, 6, 8, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 5, 7, 9, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07603741,  0.03071354,  0.08260933, -0.01118162, -0.01800317,
#            0.0036566 ,  0.00493405, -0.01062274]),
#    'activeColumns': [3, 6, 8, 10, 12, 15]},
#   29: {'potentialConnections': [2, 4, 5, 6, 7, 8, 12, 14],
#    'nonConnectedColumns': [0, 1, 3, 9, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.09062318, 0.01352054, 0.02967489, 0.06659616, 0.01077156,
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.07159424,  0.07281285, -0.0110643 ,  0.01402092, -0.00443454,
#            0.00554905, -0.00036403,  0.0032742 ]),
#    'activeColumns': [4, 7, 9, 10, 12, 14]},
#   32: {'potentialConnections': [1, 2, 4, 5, 6, 9, 11, 14],
#    'nonConnectedColumns': [0, 3, 7, 8, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.04481463, -0.00644882,  0.01136426,  0.06677991, -0.01670272,
#            0.00181536,  0.01253423,  0.04314288]),
#    'activeColumns': [1, 2, 4, 6, 9, 11]},
#   33: {'potentialConnections': [1, 2, 5, 7, 9, 11, 13, 14],
#    'nonConnectedColumns': [0, 3, 4, 6, 8, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 2.14550730e-02, -1.93049208e-05,  4.64185445e-02, -1.56581438e-02,
#           -2.28983430e-02,  1.81068879e-02,  7.31534133e-02,  6.39824620e-03]),
#    'activeColumns': [1, 2, 7, 9, 11, 14]},
#   34: {'potentialConnections': [1, 3, 5, 7, 8, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 6, 9, 10, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.00494391, -0.01374256, -0.00070253,  0.05784814, -0.02518143,
#            0.04567875,  0.0041707 ,  0.04892125]),
#    'activeColumns': [1, 3, 5, 8, 12]},
#   35: {'potentialConnections': [1, 2, 6, 8, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 7, 9, 10, 11],
#    'potentialConnectionsPermanenceValues': array([ 0.07447305, -0.00879804,  0.04436995,  0.06133332, -0.01387912,
#            0.0069592 ,  0.09547075,  0.07236436]),
#    'activeColumns': [2, 12, 13]},
#   36: {'potentialConnections': [1, 2, 4, 6, 8, 9, 12, 13],
#    'nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.00400852, -0.00114748, -0.00587847,
#           -0.00522024, -0.03290685,  0.00357683]),
#    'activeColumns': [2, 4, 6, 8, 9, 12, 13]},
#   37: {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15],
#    'potentialConnectionsPermanenceValues': array([0.07511329, 0.01025217, 0.0439128 , 0.00887738, 0.0837158 ,
#           0.04636163, 0.04947601, 0.01842616]),
#    'activeColumns': [6, 10, 14]},
#   38: {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.06436041, -0.01121072,  0.06024294,
#            0.06327231, -0.01013274,  0.00071593]),
#    'activeColumns': [1, 9, 14, 15]},
#   39: {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13],
#    'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.01224759,  0.01254257,  0.00803623, -0.01276357,
#            0.00633906,  0.07970252,  0.05863264]),
#    'activeColumns': [2, 3, 4, 8, 9, 12]}},
#  {0: {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.13308783, 0.05021608, 0.12057243, 0.10577903, 0.12078531,
#           0.14761969, 0.14301467, 0.07154617]),
#    'activeColumns': [2, 3, 5, 11]},
#   1: {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07015523, 0.11319824, 0.08091885, 0.10750115, 0.0485757 ,
#           0.1647477 , 0.04647688, 0.11403579]),
#    'activeColumns': [2, 8, 9, 10]},
#   2: {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.12791662, 0.10866717, 0.13182531, 0.05054678, 0.13299334,
#           0.18563311, 0.00164433, 0.04193386]),
#    'activeColumns': [5, 7, 11, 13, 15]},
#   3: {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15],
#    'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07261306,  0.16571292,  0.04309911,  0.10976774,  0.09637   ,
#           -0.00622173,  0.04535339,  0.08216205]),
#    'activeColumns': [1, 4, 8, 9, 10, 15]},
#   4: {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14],
#    'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08826911, 0.01047595, 0.16198851, 0.09766963, 0.17014916,
#           0.06529476, 0.08717537, 0.06522213]),
#    'activeColumns': [4, 11, 14]},
#   5: {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01718548,  0.04851854,  0.06796514,  0.12263074,  0.18275479,
#           -0.0054093 ,  0.075464  ,  0.06808966]),
#    'activeColumns': [4, 6, 8, 11, 12, 13, 14]},
#   6: {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12],
#    'potentialConnectionsPermanenceValues': array([0.02545063, 0.18255556, 0.12148456, 0.04730377, 0.17156536,
#           0.04376843, 0.04133697, 0.05245969]),
#    'activeColumns': [2, 10, 13, 14]},
#   7: {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.08277999,  0.07095782,  0.15564403,
#           -0.0073149 ,  0.06365659,  0.0498611 ]),
#    'activeColumns': [3, 5, 7, 12, 13, 14]},
#   8: {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.03412329,  0.06910957,  0.0285605 , -0.00532031,  0.00233257,
#            0.01755702,  0.06731435,  0.00062302]),
#    'activeColumns': [1, 3, 5, 6, 10, 13]},
#   9: {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13],
#    'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02097393,  0.01142684, -0.01609073,
#            0.01821843,  0.03046567,  0.00707598]),
#    'activeColumns': [4, 7, 8, 11, 13]},
#   10: {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.02708509, -0.00693868, -0.00082374, -0.0015922 ,  0.0135785 ,
#            0.00864601,  0.05672974,  0.05987811]),
#    'activeColumns': [6, 7, 8, 9, 11, 12]},
#   11: {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14],
#    'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.04508253,
#           0.06529289, 0.07376329, 0.06695191]),
#    'activeColumns': [8]},
#   12: {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#            0.03836337,  0.00866211, -0.00032669]),
#    'activeColumns': [2, 3, 6, 10, 13]},
#   13: {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0638147 ,
#           -0.00338082, -0.00350775,  0.04770307]),
#    'activeColumns': [7, 9, 11, 14]},
#   14: {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15],
#    'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05162001, 0.0122121 , 0.04516403,
#           0.01554279, 0.0680043 , 0.0138262 ]),
#    'activeColumns': [9, 11, 15]},
#   15: {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.01063193,  0.00395732, -0.01157179,
#            0.04688453, -0.01984114,  0.01859828]),
#    'activeColumns': [6, 8, 10, 12, 14]},
#   16: {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.0696819 ,  0.05945014,  0.04311123,  0.07918764,  0.02210412,
#           -0.00350085, -0.00518171,  0.08253063]),
#    'activeColumns': [12, 13, 14]},
#   17: {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12],
#    'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.03926477,  0.01197939, -0.01282766,
#            0.04509614,  0.0134356 ,  0.02719795]),
#    'activeColumns': [10, 11, 14, 15]},
#   18: {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#            0.05644045,  0.02760841,  0.07524886]),
#    'activeColumns': [2, 5, 6, 7]},
#   19: {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.02581988,  0.06803874,  0.08358476, -0.00153091,  0.01714142,
#            0.03693581,  0.03977492,  0.00163977]),
#    'activeColumns': [1, 6, 7, 15]},
#   20: {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14],
#    'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0648603 ,  0.07148511,  0.00468594, -0.00380465,
#            0.0581363 ,  0.02125511, -0.00646039]),
#    'activeColumns': [7, 8, 13, 14]},
#   21: {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15],
#    'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06917063, 0.04977692, 0.04487265, 0.06770512, 0.05940548,
#           0.05867261, 0.046445  , 0.00323246]),
#    'activeColumns': [15]},
#   22: {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.00762884, 0.00753656, 0.04866159,
#           0.01900517, 0.03798968, 0.04645863]),
#    'activeColumns': [1, 3, 5, 9]},
#   23: {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 7, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06683895, 0.04755475, 0.04907932, 0.03636167, 0.01135532,
#           0.01238023, 0.05527697, 0.02467528]),
#    'activeColumns': [8, 9, 10, 15]},
#   24: {'potentialConnections': [1, 2, 3, 5, 6, 8, 9, 10],
#    'nonConnectedColumns': [0, 4, 7, 11, 12, 13, 14, 15],
#    'potentialConnectionsPermanenceValues': array([0.0648059 , 0.02799146, 0.03864688, 0.00880883, 0.02588978,
#           0.02618257, 0.00707163, 0.0084867 ]),
#    'activeColumns': [2, 5, 6, 8, 9, 10]},
#   25: {'potentialConnections': [3, 6, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.09739602,  0.08919633,  0.0626757 ,  0.08235884,  0.02349523,
#            0.01429834,  0.04547563, -0.02722086]),
#    'activeColumns': [12, 13, 15]},
#   26: {'potentialConnections': [3, 7, 8, 9, 11, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 6, 10, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.08784849,  0.02261385,  0.00066266,  0.01078032,  0.07058536,
#           -0.00704702,  0.046235  ,  0.00341718]),
#    'activeColumns': [7, 8, 9, 12, 15]},
#   27: {'potentialConnections': [1, 2, 4, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 3, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.01998846, 0.02131688, 0.07710192, 0.06791773, 0.00782088,
#           0.00499674, 0.06054251, 0.03404801]),
#    'activeColumns': [1, 2, 7, 8]},
#   28: {'potentialConnections': [2, 3, 4, 6, 8, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 5, 7, 9, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07603741,  0.03071354,  0.08260933, -0.01118162, -0.01800317,
#            0.0036566 ,  0.00493405, -0.01062274]),
#    'activeColumns': [3, 6, 8, 10, 12, 15]},
#   29: {'potentialConnections': [2, 4, 5, 6, 7, 8, 12, 14],
#    'nonConnectedColumns': [0, 1, 3, 9, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.09062318, 0.01352054, 0.02967489, 0.06659616, 0.01077156,
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.07159424,  0.07281285, -0.0110643 ,  0.01402092, -0.00443454,
#            0.00554905, -0.00036403,  0.0032742 ]),
#    'activeColumns': [4, 7, 9, 10, 12, 14]},
#   32: {'potentialConnections': [1, 2, 4, 5, 6, 9, 11, 14],
#    'nonConnectedColumns': [0, 3, 7, 8, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.04481463, -0.00644882,  0.01136426,  0.06677991, -0.01670272,
#            0.00181536,  0.01253423,  0.04314288]),
#    'activeColumns': [1, 2, 4, 6, 9, 11]},
#   33: {'potentialConnections': [1, 2, 5, 7, 9, 11, 13, 14],
#    'nonConnectedColumns': [0, 3, 4, 6, 8, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 2.14550730e-02, -1.93049208e-05,  4.64185445e-02, -1.56581438e-02,
#           -2.28983430e-02,  1.81068879e-02,  7.31534133e-02,  6.39824620e-03]),
#    'activeColumns': [1, 2, 7, 9, 11, 14]},
#   34: {'potentialConnections': [1, 3, 5, 7, 8, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 6, 9, 10, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.00494391, -0.01374256, -0.00070253,  0.05784814, -0.02518143,
#            0.04567875,  0.0041707 ,  0.04892125]),
#    'activeColumns': [1, 3, 5, 8, 12]},
#   35: {'potentialConnections': [1, 2, 6, 8, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 7, 9, 10, 11],
#    'potentialConnectionsPermanenceValues': array([ 0.07447305, -0.00879804,  0.04436995,  0.06133332, -0.01387912,
#            0.0069592 ,  0.09547075,  0.07236436]),
#    'activeColumns': [2, 12, 13]},
#   36: {'potentialConnections': [1, 2, 4, 6, 8, 9, 12, 13],
#    'nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.00400852, -0.00114748, -0.00587847,
#           -0.00522024, -0.03290685,  0.00357683]),
#    'activeColumns': [2, 4, 6, 8, 9, 12, 13]},
#   37: {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15],
#    'potentialConnectionsPermanenceValues': array([0.07511329, 0.01025217, 0.0439128 , 0.00887738, 0.0837158 ,
#           0.04636163, 0.04947601, 0.01842616]),
#    'activeColumns': [6, 10, 14]},
#   38: {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.06436041, -0.01121072,  0.06024294,
#            0.06327231, -0.01013274,  0.00071593]),
#    'activeColumns': [1, 9, 14, 15]},
#   39: {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13],
#    'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.01224759,  0.01254257,  0.00803623, -0.01276357,
#            0.00633906,  0.07970252,  0.05863264]),
#    'activeColumns': [2, 3, 4, 8, 9, 12]}},
#  {0: {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.13308783, 0.05021608, 0.12057243, 0.10577903, 0.12078531,
#           0.14761969, 0.14301467, 0.07154617]),
#    'activeColumns': [2, 3, 5, 11]},
#   1: {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07015523, 0.11319824, 0.08091885, 0.10750115, 0.0485757 ,
#           0.1647477 , 0.04647688, 0.11403579]),
#    'activeColumns': [2, 8, 9, 10]},
#   2: {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.12791662, 0.10866717, 0.13182531, 0.05054678, 0.13299334,
#           0.18563311, 0.00164433, 0.04193386]),
#    'activeColumns': [5, 7, 11, 13, 15]},
#   3: {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15],
#    'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07261306,  0.16571292,  0.04309911,  0.10976774,  0.09637   ,
#           -0.00622173,  0.04535339,  0.08216205]),
#    'activeColumns': [1, 4, 8, 9, 10, 15]},
#   4: {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14],
#    'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08826911, 0.01047595, 0.16198851, 0.09766963, 0.17014916,
#           0.06529476, 0.08717537, 0.06522213]),
#    'activeColumns': [4, 11, 14]},
#   5: {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01718548,  0.04851854,  0.06796514,  0.12263074,  0.18275479,
#           -0.0054093 ,  0.075464  ,  0.06808966]),
#    'activeColumns': [4, 6, 8, 11, 12, 13, 14]},
#   6: {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12],
#    'potentialConnectionsPermanenceValues': array([0.02545063, 0.18255556, 0.12148456, 0.04730377, 0.17156536,
#           0.04376843, 0.04133697, 0.05245969]),
#    'activeColumns': [2, 10, 13, 14]},
#   7: {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.08277999,  0.07095782,  0.15564403,
#           -0.0073149 ,  0.06365659,  0.0498611 ]),
#    'activeColumns': [3, 5, 7, 12, 13, 14]},
#   8: {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.03412329,  0.06910957,  0.0285605 , -0.00532031,  0.00233257,
#            0.01755702,  0.06731435,  0.00062302]),
#    'activeColumns': [1, 3, 5, 6, 10, 13]},
#   9: {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13],
#    'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02097393,  0.01142684, -0.01609073,
#            0.01821843,  0.03046567,  0.00707598]),
#    'activeColumns': [4, 7, 8, 11, 13]},
#   10: {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.02708509, -0.00693868, -0.00082374, -0.0015922 ,  0.0135785 ,
#            0.00864601,  0.05672974,  0.05987811]),
#    'activeColumns': [6, 7, 8, 9, 11, 12]},
#   11: {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14],
#    'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.04508253,
#           0.06529289, 0.07376329, 0.06695191]),
#    'activeColumns': [8]},
#   12: {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#            0.03836337,  0.00866211, -0.00032669]),
#    'activeColumns': [2, 3, 6, 10, 13]},
#   13: {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0638147 ,
#           -0.00338082, -0.00350775,  0.04770307]),
#    'activeColumns': [7, 9, 11, 14]},
#   14: {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15],
#    'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05162001, 0.0122121 , 0.04516403,
#           0.01554279, 0.0680043 , 0.0138262 ]),
#    'activeColumns': [9, 11, 15]},
#   15: {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.01063193,  0.00395732, -0.01157179,
#            0.04688453, -0.01984114,  0.01859828]),
#    'activeColumns': [6, 8, 10, 12, 14]},
#   16: {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.0696819 ,  0.05945014,  0.04311123,  0.07918764,  0.02210412,
#           -0.00350085, -0.00518171,  0.08253063]),
#    'activeColumns': [12, 13, 14]},
#   17: {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12],
#    'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.03926477,  0.01197939, -0.01282766,
#            0.04509614,  0.0134356 ,  0.02719795]),
#    'activeColumns': [10, 11, 14, 15]},
#   18: {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#            0.05644045,  0.02760841,  0.07524886]),
#    'activeColumns': [2, 5, 6, 7]},
#   19: {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.02581988,  0.06803874,  0.08358476, -0.00153091,  0.01714142,
#            0.03693581,  0.03977492,  0.00163977]),
#    'activeColumns': [1, 6, 7, 15]},
#   20: {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14],
#    'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0648603 ,  0.07148511,  0.00468594, -0.00380465,
#            0.0581363 ,  0.02125511, -0.00646039]),
#    'activeColumns': [7, 8, 13, 14]},
#   21: {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15],
#    'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06917063, 0.04977692, 0.04487265, 0.06770512, 0.05940548,
#           0.05867261, 0.046445  , 0.00323246]),
#    'activeColumns': [15]},
#   22: {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.00762884, 0.00753656, 0.04866159,
#           0.01900517, 0.03798968, 0.04645863]),
#    'activeColumns': [1, 3, 5, 9]},
#   23: {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 7, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06683895, 0.04755475, 0.04907932, 0.03636167, 0.01135532,
#           0.01238023, 0.05527697, 0.02467528]),
#    'activeColumns': [8, 9, 10, 15]},
#   24: {'potentialConnections': [1, 2, 3, 5, 6, 8, 9, 10],
#    'nonConnectedColumns': [0, 4, 7, 11, 12, 13, 14, 15],
#    'potentialConnectionsPermanenceValues': array([0.0648059 , 0.02799146, 0.03864688, 0.00880883, 0.02588978,
#           0.02618257, 0.00707163, 0.0084867 ]),
#    'activeColumns': [2, 5, 6, 8, 9, 10]},
#   25: {'potentialConnections': [3, 6, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.09739602,  0.08919633,  0.0626757 ,  0.08235884,  0.02349523,
#            0.01429834,  0.04547563, -0.02722086]),
#    'activeColumns': [12, 13, 15]},
#   26: {'potentialConnections': [3, 7, 8, 9, 11, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 6, 10, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.08784849,  0.02261385,  0.00066266,  0.01078032,  0.07058536,
#           -0.00704702,  0.046235  ,  0.00341718]),
#    'activeColumns': [7, 8, 9, 12, 15]},
#   27: {'potentialConnections': [1, 2, 4, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 3, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.01998846, 0.02131688, 0.07710192, 0.06791773, 0.00782088,
#           0.00499674, 0.06054251, 0.03404801]),
#    'activeColumns': [1, 2, 7, 8]},
#   28: {'potentialConnections': [2, 3, 4, 6, 8, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 5, 7, 9, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07603741,  0.03071354,  0.08260933, -0.01118162, -0.01800317,
#            0.0036566 ,  0.00493405, -0.01062274]),
#    'activeColumns': [3, 6, 8, 10, 12, 15]},
#   29: {'potentialConnections': [2, 4, 5, 6, 7, 8, 12, 14],
#    'nonConnectedColumns': [0, 1, 3, 9, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.09062318, 0.01352054, 0.02967489, 0.06659616, 0.01077156,
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.07159424,  0.07281285, -0.0110643 ,  0.01402092, -0.00443454,
#            0.00554905, -0.00036403,  0.0032742 ]),
#    'activeColumns': [4, 7, 9, 10, 12, 14]},
#   32: {'potentialConnections': [1, 2, 4, 5, 6, 9, 11, 14],
#    'nonConnectedColumns': [0, 3, 7, 8, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.04481463, -0.00644882,  0.01136426,  0.06677991, -0.01670272,
#            0.00181536,  0.01253423,  0.04314288]),
#    'activeColumns': [1, 2, 4, 6, 9, 11]},
#   33: {'potentialConnections': [1, 2, 5, 7, 9, 11, 13, 14],
#    'nonConnectedColumns': [0, 3, 4, 6, 8, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 2.14550730e-02, -1.93049208e-05,  4.64185445e-02, -1.56581438e-02,
#           -2.28983430e-02,  1.81068879e-02,  7.31534133e-02,  6.39824620e-03]),
#    'activeColumns': [1, 2, 7, 9, 11, 14]},
#   34: {'potentialConnections': [1, 3, 5, 7, 8, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 6, 9, 10, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.00494391, -0.01374256, -0.00070253,  0.05784814, -0.02518143,
#            0.04567875,  0.0041707 ,  0.04892125]),
#    'activeColumns': [1, 3, 5, 8, 12]},
#   35: {'potentialConnections': [1, 2, 6, 8, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 7, 9, 10, 11],
#    'potentialConnectionsPermanenceValues': array([ 0.07447305, -0.00879804,  0.04436995,  0.06133332, -0.01387912,
#            0.0069592 ,  0.09547075,  0.07236436]),
#    'activeColumns': [2, 12, 13]},
#   36: {'potentialConnections': [1, 2, 4, 6, 8, 9, 12, 13],
#    'nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.00400852, -0.00114748, -0.00587847,
#           -0.00522024, -0.03290685,  0.00357683]),
#    'activeColumns': [2, 4, 6, 8, 9, 12, 13]},
#   37: {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15],
#    'potentialConnectionsPermanenceValues': array([0.07511329, 0.01025217, 0.0439128 , 0.00887738, 0.0837158 ,
#           0.04636163, 0.04947601, 0.01842616]),
#    'activeColumns': [6, 10, 14]},
#   38: {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.06436041, -0.01121072,  0.06024294,
#            0.06327231, -0.01013274,  0.00071593]),
#    'activeColumns': [1, 9, 14, 15]},
#   39: {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13],
#    'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.01224759,  0.01254257,  0.00803623, -0.01276357,
#            0.00633906,  0.07970252,  0.05863264]),
#    'activeColumns': [2, 3, 4, 8, 9, 12]}},
#  {0: {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.13308783, 0.05021608, 0.12057243, 0.10577903, 0.12078531,
#           0.14761969, 0.14301467, 0.07154617]),
#    'activeColumns': [2, 3, 5, 11]},
#   1: {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07015523, 0.11319824, 0.08091885, 0.10750115, 0.0485757 ,
#           0.1647477 , 0.04647688, 0.11403579]),
#    'activeColumns': [2, 8, 9, 10]},
#   2: {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.12791662, 0.10866717, 0.13182531, 0.05054678, 0.13299334,
#           0.18563311, 0.00164433, 0.04193386]),
#    'activeColumns': [5, 7, 11, 13, 15]},
#   3: {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15],
#    'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07261306,  0.16571292,  0.04309911,  0.10976774,  0.09637   ,
#           -0.00622173,  0.04535339,  0.08216205]),
#    'activeColumns': [1, 4, 8, 9, 10, 15]},
#   4: {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14],
#    'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08826911, 0.01047595, 0.16198851, 0.09766963, 0.17014916,
#           0.06529476, 0.08717537, 0.06522213]),
#    'activeColumns': [4, 11, 14]},
#   5: {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01718548,  0.04851854,  0.06796514,  0.12263074,  0.18275479,
#           -0.0054093 ,  0.075464  ,  0.06808966]),
#    'activeColumns': [4, 6, 8, 11, 12, 13, 14]},
#   6: {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12],
#    'potentialConnectionsPermanenceValues': array([0.02545063, 0.18255556, 0.12148456, 0.04730377, 0.17156536,
#           0.04376843, 0.04133697, 0.05245969]),
#    'activeColumns': [2, 10, 13, 14]},
#   7: {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.08277999,  0.07095782,  0.15564403,
#           -0.0073149 ,  0.06365659,  0.0498611 ]),
#    'activeColumns': [3, 5, 7, 12, 13, 14]},
#   8: {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.03412329,  0.06910957,  0.0285605 , -0.00532031,  0.00233257,
#            0.01755702,  0.06731435,  0.00062302]),
#    'activeColumns': [1, 3, 5, 6, 10, 13]},
#   9: {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13],
#    'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02097393,  0.01142684, -0.01609073,
#            0.01821843,  0.03046567,  0.00707598]),
#    'activeColumns': [4, 7, 8, 11, 13]},
#   10: {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.02708509, -0.00693868, -0.00082374, -0.0015922 ,  0.0135785 ,
#            0.00864601,  0.05672974,  0.05987811]),
#    'activeColumns': [6, 7, 8, 9, 11, 12]},
#   11: {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14],
#    'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.04508253,
#           0.06529289, 0.07376329, 0.06695191]),
#    'activeColumns': [8]},
#   12: {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#            0.03836337,  0.00866211, -0.00032669]),
#    'activeColumns': [2, 3, 6, 10, 13]},
#   13: {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0638147 ,
#           -0.00338082, -0.00350775,  0.04770307]),
#    'activeColumns': [7, 9, 11, 14]},
#   14: {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15],
#    'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05162001, 0.0122121 , 0.04516403,
#           0.01554279, 0.0680043 , 0.0138262 ]),
#    'activeColumns': [9, 11, 15]},
#   15: {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.01063193,  0.00395732, -0.01157179,
#            0.04688453, -0.01984114,  0.01859828]),
#    'activeColumns': [6, 8, 10, 12, 14]},
#   16: {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.0696819 ,  0.05945014,  0.04311123,  0.07918764,  0.02210412,
#           -0.00350085, -0.00518171,  0.08253063]),
#    'activeColumns': [12, 13, 14]},
#   17: {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12],
#    'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.03926477,  0.01197939, -0.01282766,
#            0.04509614,  0.0134356 ,  0.02719795]),
#    'activeColumns': [10, 11, 14, 15]},
#   18: {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#            0.05644045,  0.02760841,  0.07524886]),
#    'activeColumns': [2, 5, 6, 7]},
#   19: {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.02581988,  0.06803874,  0.08358476, -0.00153091,  0.01714142,
#            0.03693581,  0.03977492,  0.00163977]),
#    'activeColumns': [1, 6, 7, 15]},
#   20: {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14],
#    'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0648603 ,  0.07148511,  0.00468594, -0.00380465,
#            0.0581363 ,  0.02125511, -0.00646039]),
#    'activeColumns': [7, 8, 13, 14]},
#   21: {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15],
#    'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06917063, 0.04977692, 0.04487265, 0.06770512, 0.05940548,
#           0.05867261, 0.046445  , 0.00323246]),
#    'activeColumns': [15]},
#   22: {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.00762884, 0.00753656, 0.04866159,
#           0.01900517, 0.03798968, 0.04645863]),
#    'activeColumns': [1, 3, 5, 9]},
#   23: {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 7, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06683895, 0.04755475, 0.04907932, 0.03636167, 0.01135532,
#           0.01238023, 0.05527697, 0.02467528]),
#    'activeColumns': [8, 9, 10, 15]},
#   24: {'potentialConnections': [1, 2, 3, 5, 6, 8, 9, 10],
#    'nonConnectedColumns': [0, 4, 7, 11, 12, 13, 14, 15],
#    'potentialConnectionsPermanenceValues': array([0.0648059 , 0.02799146, 0.03864688, 0.00880883, 0.02588978,
#           0.02618257, 0.00707163, 0.0084867 ]),
#    'activeColumns': [2, 5, 6, 8, 9, 10]},
#   25: {'potentialConnections': [3, 6, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.09739602,  0.08919633,  0.0626757 ,  0.08235884,  0.02349523,
#            0.01429834,  0.04547563, -0.02722086]),
#    'activeColumns': [12, 13, 15]},
#   26: {'potentialConnections': [3, 7, 8, 9, 11, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 6, 10, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.08784849,  0.02261385,  0.00066266,  0.01078032,  0.07058536,
#           -0.00704702,  0.046235  ,  0.00341718]),
#    'activeColumns': [7, 8, 9, 12, 15]},
#   27: {'potentialConnections': [1, 2, 4, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 3, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.01998846, 0.02131688, 0.07710192, 0.06791773, 0.00782088,
#           0.00499674, 0.06054251, 0.03404801]),
#    'activeColumns': [1, 2, 7, 8]},
#   28: {'potentialConnections': [2, 3, 4, 6, 8, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 5, 7, 9, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07603741,  0.03071354,  0.08260933, -0.01118162, -0.01800317,
#            0.0036566 ,  0.00493405, -0.01062274]),
#    'activeColumns': [3, 6, 8, 10, 12, 15]},
#   29: {'potentialConnections': [2, 4, 5, 6, 7, 8, 12, 14],
#    'nonConnectedColumns': [0, 1, 3, 9, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.09062318, 0.01352054, 0.02967489, 0.06659616, 0.01077156,
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
# ...
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.07159424,  0.07281285, -0.0110643 ,  0.01402092, -0.00443454,
#            0.00554905, -0.00036403,  0.0032742 ]),
#    'activeColumns': [4, 7, 9, 10, 12, 14]},
#   32: {'potentialConnections': [1, 2, 4, 5, 6, 9, 11, 14],
#    'nonConnectedColumns': [0, 3, 7, 8, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.04481463, -0.00644882,  0.01136426,  0.06677991, -0.01670272,
#            0.00181536,  0.01253423,  0.04314288]),
#    'activeColumns': [1, 2, 4, 6, 9, 11]},
#   33: {'potentialConnections': [1, 2, 5, 7, 9, 11, 13, 14],
#    'nonConnectedColumns': [0, 3, 4, 6, 8, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 2.14550730e-02, -1.93049208e-05,  4.64185445e-02, -1.56581438e-02,
#           -2.28983430e-02,  1.81068879e-02,  7.31534133e-02,  6.39824620e-03]),
#    'activeColumns': [1, 2, 7, 9, 11, 14]},
#   34: {'potentialConnections': [1, 3, 5, 7, 8, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 6, 9, 10, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.00494391, -0.01374256, -0.00070253,  0.05784814, -0.02518143,
#            0.04567875,  0.0041707 ,  0.04892125]),
#    'activeColumns': [1, 3, 5, 8, 12]},
#   35: {'potentialConnections': [1, 2, 6, 8, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 7, 9, 10, 11],
#    'potentialConnectionsPermanenceValues': array([ 0.07447305, -0.00879804,  0.04436995,  0.06133332, -0.01387912,
#            0.0069592 ,  0.09547075,  0.07236436]),
#    'activeColumns': [2, 12, 13]},
#   36: {'potentialConnections': [1, 2, 4, 6, 8, 9, 12, 13],
#    'nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.00400852, -0.00114748, -0.00587847,
#           -0.00522024, -0.03290685,  0.00357683]),
#    'activeColumns': [2, 4, 6, 8, 9, 12, 13]},
#   37: {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15],
#    'potentialConnectionsPermanenceValues': array([0.07511329, 0.01025217, 0.0439128 , 0.00887738, 0.0837158 ,
#           0.04636163, 0.04947601, 0.01842616]),
#    'activeColumns': [6, 10, 14]},
#   38: {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.06436041, -0.01121072,  0.06024294,
#            0.06327231, -0.01013274,  0.00071593]),
#    'activeColumns': [1, 9, 14, 15]},
#   39: {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13],
#    'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.01224759,  0.01254257,  0.00803623, -0.01276357,
#            0.00633906,  0.07970252,  0.05863264]),
#    'activeColumns': [2, 3, 4, 8, 9, 12]}},
#  {0: {'potentialConnections': [1, 2, 3, 5, 8, 11, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 7, 9, 10, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.13308783, 0.05021608, 0.12057243, 0.10577903, 0.12078531,
#           0.14761969, 0.14301467, 0.07154617]),
#    'activeColumns': [2, 3, 5, 11]},
#   1: {'potentialConnections': [2, 3, 6, 8, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 7, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07015523, 0.11319824, 0.08091885, 0.10750115, 0.0485757 ,
#           0.1647477 , 0.04647688, 0.11403579]),
#    'activeColumns': [2, 8, 9, 10]},
#   2: {'potentialConnections': [1, 5, 6, 7, 8, 11, 13, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 9, 10, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.12791662, 0.10866717, 0.13182531, 0.05054678, 0.13299334,
#           0.18563311, 0.00164433, 0.04193386]),
#    'activeColumns': [5, 7, 11, 13, 15]},
#   3: {'potentialConnections': [1, 2, 4, 7, 8, 9, 10, 15],
#    'nonConnectedColumns': [0, 3, 5, 6, 11, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07261306,  0.16571292,  0.04309911,  0.10976774,  0.09637   ,
#           -0.00622173,  0.04535339,  0.08216205]),
#    'activeColumns': [1, 4, 8, 9, 10, 15]},
#   4: {'potentialConnections': [1, 4, 6, 7, 8, 9, 11, 14],
#    'nonConnectedColumns': [0, 2, 3, 5, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08826911, 0.01047595, 0.16198851, 0.09766963, 0.17014916,
#           0.06529476, 0.08717537, 0.06522213]),
#    'activeColumns': [4, 11, 14]},
#   5: {'potentialConnections': [4, 6, 7, 8, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 5, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01718548,  0.04851854,  0.06796514,  0.12263074,  0.18275479,
#           -0.0054093 ,  0.075464  ,  0.06808966]),
#    'activeColumns': [4, 6, 8, 11, 12, 13, 14]},
#   6: {'potentialConnections': [2, 7, 8, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 5, 6, 9, 12],
#    'potentialConnectionsPermanenceValues': array([0.02545063, 0.18255556, 0.12148456, 0.04730377, 0.17156536,
#           0.04376843, 0.04133697, 0.05245969]),
#    'activeColumns': [2, 10, 13, 14]},
#   7: {'potentialConnections': [3, 4, 5, 7, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 6, 8, 9, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09254372,  0.14274164,  0.08277999,  0.07095782,  0.15564403,
#           -0.0073149 ,  0.06365659,  0.0498611 ]),
#    'activeColumns': [3, 5, 7, 12, 13, 14]},
#   8: {'potentialConnections': [1, 2, 3, 5, 6, 10, 11, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 9, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.03412329,  0.06910957,  0.0285605 , -0.00532031,  0.00233257,
#            0.01755702,  0.06731435,  0.00062302]),
#    'activeColumns': [1, 3, 5, 6, 10, 13]},
#   9: {'potentialConnections': [4, 5, 6, 7, 8, 9, 11, 13],
#    'nonConnectedColumns': [0, 1, 2, 3, 10, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.01455965,  0.06360919,  0.02097393,  0.01142684, -0.01609073,
#            0.01821843,  0.03046567,  0.00707598]),
#    'activeColumns': [4, 7, 8, 11, 13]},
#   10: {'potentialConnections': [6, 7, 8, 9, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 5, 10, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.02708509, -0.00693868, -0.00082374, -0.0015922 ,  0.0135785 ,
#            0.00864601,  0.05672974,  0.05987811]),
#    'activeColumns': [6, 7, 8, 9, 11, 12]},
#   11: {'potentialConnections': [2, 3, 5, 8, 9, 10, 11, 14],
#    'nonConnectedColumns': [0, 1, 4, 6, 7, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.08266477, 0.07316574, 0.08984312, 0.00846156, 0.04508253,
#           0.06529289, 0.07376329, 0.06695191]),
#    'activeColumns': [8]},
#   12: {'potentialConnections': [1, 2, 3, 5, 6, 9, 10, 13],
#    'nonConnectedColumns': [0, 4, 7, 8, 11, 12, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.06156171,  0.0078738 ,  0.02126295,  0.06233086, -0.00151465,
#            0.03836337,  0.00866211, -0.00032669]),
#    'activeColumns': [2, 3, 6, 10, 13]},
#   13: {'potentialConnections': [2, 3, 7, 9, 10, 11, 14, 15],
#    'nonConnectedColumns': [0, 1, 4, 5, 6, 8, 12, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.0804838 ,  0.08821683,  0.00680195, -0.0023753 ,  0.0638147 ,
#           -0.00338082, -0.00350775,  0.04770307]),
#    'activeColumns': [7, 9, 11, 14]},
#   14: {'potentialConnections': [1, 4, 5, 9, 10, 11, 12, 15],
#    'nonConnectedColumns': [0, 2, 3, 6, 7, 8, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.07350794, 0.06319924, 0.05162001, 0.0122121 , 0.04516403,
#           0.01554279, 0.0680043 , 0.0138262 ]),
#    'activeColumns': [9, 11, 15]},
#   15: {'potentialConnections': [1, 3, 6, 8, 10, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 5, 7, 9, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.08624671,  0.04631784, -0.01063193,  0.00395732, -0.01157179,
#            0.04688453, -0.01984114,  0.01859828]),
#    'activeColumns': [6, 8, 10, 12, 14]},
#   16: {'potentialConnections': [1, 2, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 6, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.0696819 ,  0.05945014,  0.04311123,  0.07918764,  0.02210412,
#           -0.00350085, -0.00518171,  0.08253063]),
#    'activeColumns': [12, 13, 14]},
#   17: {'potentialConnections': [1, 5, 9, 10, 11, 13, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 4, 6, 7, 8, 12],
#    'potentialConnectionsPermanenceValues': array([ 0.08326718,  0.05136316,  0.03926477,  0.01197939, -0.01282766,
#            0.04509614,  0.0134356 ,  0.02719795]),
#    'activeColumns': [10, 11, 14, 15]},
#   18: {'potentialConnections': [2, 5, 6, 7, 9, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 8, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.01564075,  0.02642526,  0.02254917, -0.00717942,  0.0345328 ,
#            0.05644045,  0.02760841,  0.07524886]),
#    'activeColumns': [2, 5, 6, 7]},
#   19: {'potentialConnections': [1, 2, 3, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 4, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.02581988,  0.06803874,  0.08358476, -0.00153091,  0.01714142,
#            0.03693581,  0.03977492,  0.00163977]),
#    'activeColumns': [1, 6, 7, 15]},
#   20: {'potentialConnections': [1, 3, 4, 7, 8, 11, 13, 14],
#    'nonConnectedColumns': [0, 2, 5, 6, 9, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.09073381,  0.0648603 ,  0.07148511,  0.00468594, -0.00380465,
#            0.0581363 ,  0.02125511, -0.00646039]),
#    'activeColumns': [7, 8, 13, 14]},
#   21: {'potentialConnections': [3, 4, 6, 7, 8, 9, 12, 15],
#    'nonConnectedColumns': [0, 1, 2, 5, 10, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06917063, 0.04977692, 0.04487265, 0.06770512, 0.05940548,
#           0.05867261, 0.046445  , 0.00323246]),
#    'activeColumns': [15]},
#   22: {'potentialConnections': [1, 2, 3, 5, 7, 9, 14, 15],
#    'nonConnectedColumns': [0, 4, 6, 8, 10, 11, 12, 13],
#    'potentialConnectionsPermanenceValues': array([0.03761386, 0.07458017, 0.00762884, 0.00753656, 0.04866159,
#           0.01900517, 0.03798968, 0.04645863]),
#    'activeColumns': [1, 3, 5, 9]},
#   23: {'potentialConnections': [2, 5, 6, 8, 9, 10, 11, 15],
#    'nonConnectedColumns': [0, 1, 3, 4, 7, 12, 13, 14],
#    'potentialConnectionsPermanenceValues': array([0.06683895, 0.04755475, 0.04907932, 0.03636167, 0.01135532,
#           0.01238023, 0.05527697, 0.02467528]),
#    'activeColumns': [8, 9, 10, 15]},
#   24: {'potentialConnections': [1, 2, 3, 5, 6, 8, 9, 10],
#    'nonConnectedColumns': [0, 4, 7, 11, 12, 13, 14, 15],
#    'potentialConnectionsPermanenceValues': array([0.0648059 , 0.02799146, 0.03864688, 0.00880883, 0.02588978,
#           0.02618257, 0.00707163, 0.0084867 ]),
#    'activeColumns': [2, 5, 6, 8, 9, 10]},
#   25: {'potentialConnections': [3, 6, 8, 11, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 7, 9, 10],
#    'potentialConnectionsPermanenceValues': array([ 0.09739602,  0.08919633,  0.0626757 ,  0.08235884,  0.02349523,
#            0.01429834,  0.04547563, -0.02722086]),
#    'activeColumns': [12, 13, 15]},
#   26: {'potentialConnections': [3, 7, 8, 9, 11, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 2, 4, 5, 6, 10, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.08784849,  0.02261385,  0.00066266,  0.01078032,  0.07058536,
#           -0.00704702,  0.046235  ,  0.00341718]),
#    'activeColumns': [7, 8, 9, 12, 15]},
#   27: {'potentialConnections': [1, 2, 4, 6, 7, 8, 13, 15],
#    'nonConnectedColumns': [0, 3, 5, 9, 10, 11, 12, 14],
#    'potentialConnectionsPermanenceValues': array([0.01998846, 0.02131688, 0.07710192, 0.06791773, 0.00782088,
#           0.00499674, 0.06054251, 0.03404801]),
#    'activeColumns': [1, 2, 7, 8]},
#   28: {'potentialConnections': [2, 3, 4, 6, 8, 10, 12, 15],
#    'nonConnectedColumns': [0, 1, 5, 7, 9, 11, 13, 14],
#    'potentialConnectionsPermanenceValues': array([ 0.07603741,  0.03071354,  0.08260933, -0.01118162, -0.01800317,
#            0.0036566 ,  0.00493405, -0.01062274]),
#    'activeColumns': [3, 6, 8, 10, 12, 15]},
#   29: {'potentialConnections': [2, 4, 5, 6, 7, 8, 12, 14],
#    'nonConnectedColumns': [0, 1, 3, 9, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.09062318, 0.01352054, 0.02967489, 0.06659616, 0.01077156,
#           0.0182043 , 0.00402758, 0.04926948]),
#    'activeColumns': [4, 5, 7, 8, 12]},
#   30: {'potentialConnections': [2, 3, 4, 5, 6, 9, 12, 14],
#    'nonConnectedColumns': [0, 1, 7, 8, 10, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([0.02927839, 0.02380357, 0.01969046, 0.05348924, 0.0118379 ,
#           0.01174872, 0.04536583, 0.05209996]),
#    'activeColumns': [2, 3, 4, 6, 9]},
#   31: {'potentialConnections': [1, 2, 4, 7, 9, 10, 12, 14],
#    'nonConnectedColumns': [0, 3, 5, 6, 8, 11, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.07159424,  0.07281285, -0.0110643 ,  0.01402092, -0.00443454,
#            0.00554905, -0.00036403,  0.0032742 ]),
#    'activeColumns': [4, 7, 9, 10, 12, 14]},
#   32: {'potentialConnections': [1, 2, 4, 5, 6, 9, 11, 14],
#    'nonConnectedColumns': [0, 3, 7, 8, 10, 12, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.04481463, -0.00644882,  0.01136426,  0.06677991, -0.01670272,
#            0.00181536,  0.01253423,  0.04314288]),
#    'activeColumns': [1, 2, 4, 6, 9, 11]},
#   33: {'potentialConnections': [1, 2, 5, 7, 9, 11, 13, 14],
#    'nonConnectedColumns': [0, 3, 4, 6, 8, 10, 12, 15],
#    'potentialConnectionsPermanenceValues': array([ 2.14550730e-02, -1.93049208e-05,  4.64185445e-02, -1.56581438e-02,
#           -2.28983430e-02,  1.81068879e-02,  7.31534133e-02,  6.39824620e-03]),
#    'activeColumns': [1, 2, 7, 9, 11, 14]},
#   34: {'potentialConnections': [1, 3, 5, 7, 8, 11, 12, 14],
#    'nonConnectedColumns': [0, 2, 4, 6, 9, 10, 13, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.00494391, -0.01374256, -0.00070253,  0.05784814, -0.02518143,
#            0.04567875,  0.0041707 ,  0.04892125]),
#    'activeColumns': [1, 3, 5, 8, 12]},
#   35: {'potentialConnections': [1, 2, 6, 8, 12, 13, 14, 15],
#    'nonConnectedColumns': [0, 3, 4, 5, 7, 9, 10, 11],
#    'potentialConnectionsPermanenceValues': array([ 0.07447305, -0.00879804,  0.04436995,  0.06133332, -0.01387912,
#            0.0069592 ,  0.09547075,  0.07236436]),
#    'activeColumns': [2, 12, 13]},
#   36: {'potentialConnections': [1, 2, 4, 6, 8, 9, 12, 13],
#    'nonConnectedColumns': [0, 3, 5, 7, 10, 11, 14, 15],
#    'potentialConnectionsPermanenceValues': array([ 0.05075576, -0.01021969,  0.00400852, -0.00114748, -0.00587847,
#           -0.00522024, -0.03290685,  0.00357683]),
#    'activeColumns': [2, 4, 6, 8, 9, 12, 13]},
#   37: {'potentialConnections': [5, 6, 8, 10, 11, 12, 13, 14],
#    'nonConnectedColumns': [0, 1, 2, 3, 4, 7, 9, 15],
#    'potentialConnectionsPermanenceValues': array([0.07511329, 0.01025217, 0.0439128 , 0.00887738, 0.0837158 ,
#           0.04636163, 0.04947601, 0.01842616]),
#    'activeColumns': [6, 10, 14]},
#   38: {'potentialConnections': [1, 4, 6, 9, 10, 12, 14, 15],
#    'nonConnectedColumns': [0, 2, 3, 5, 7, 8, 11, 13],
#    'potentialConnectionsPermanenceValues': array([ 0.00465528,  0.07516946,  0.06436041, -0.01121072,  0.06024294,
#            0.06327231, -0.01013274,  0.00071593]),
#    'activeColumns': [1, 9, 14, 15]},
#   39: {'potentialConnections': [2, 3, 4, 8, 9, 12, 14, 15],
#    'nonConnectedColumns': [0, 1, 5, 6, 7, 10, 11, 13],
#    'potentialConnectionsPermanenceValues': array([-0.0018334 , -0.01224759,  0.01254257,  0.00803623, -0.01276357,
#            0.00633906,  0.07970252,  0.05863264]),
#    'activeColumns': [2, 3, 4, 8, 9, 12]}}]

# %% [markdown]
# Now let's create our sptial pooler instance, and intitialise the columns to each bit in the input space:

# %%
s1 = SpatialPoolerV3()
s1.getSummary(1)
s1.initialiseColumnsToInputSpace()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Column space size (numColumns): 1024
# |L2| Input space size (numInputs): 16
# |L3| Input bits visible to each columns, or receptive field (potentialRadius): 16
# |L4| The percent of the inputs, within a column's potential radius, that a column can be connected to (potentialPct): 50.0 %
# |L5| Global Inhibition is on, meaning winning columns will be selected as the most active columns across the whole region (globalInhibition): True
# |L6| Density of active columns within inhibition area (numActiveColumnsPerInhArea): 10
# |L7| Minimum number of synapses that must be on in order for a columns to turn ON (stimulusThreshold): 0
# |L8| Amount by which an inactive synapse is decremented in each time step (synPermInactiveDec): 0.008
# |L9| Amount by which an active synapse is incremented in each time step (synPermActiveInc): 0.05
# |L10| Any synapse whose permanence value is above this value is a connected synapse (synPermConnected): 0.1
# |L11| Columns initialised: False
#
# ----------------- SUMMARY -------------------------
# |L1| Based on initital paramaters, each of the 1024 columns in this Spatial Pooler has a potential connection to 0.5 of bits in the input space
# |L1| The values of all potential connection strength are normally distributed between approximately 0.085 and 0.114
# |L1| Based on the connection threshold set at 0.1 , 6 columns will now be active in the Spatial Pooler
# |L1| Time elapsed during initialisation: 0.045 seconds.

# %% [markdown]
# We can again compare any bit in the input space to its related active columns:

# %%
s1.compareEachBitInInputSpaceToItsConnectedActiveColumns()

# %%
randomBitsInInputSpace = np.random.randint(0, 16, 2)
randomBitsInInputSpace
# Out:
# array([7, 7])

# %%
inputSize = 1024
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(18, 4))

ax1 = hc.create_axis_for_sdr(ax1, np.sqrt(inputSize) + 1, np.sqrt(inputSize) + 1, 
                             20, "Input bit at " + str(randomBitsInInputSpace[0]))
ax2 = hc.create_axis_for_sdr(ax2, np.sqrt(4096) + 1, np.sqrt(4096) + 1, 
                             20, "Active columns related to input " + str(randomBitsInInputSpace[0]))

ax3 = hc.create_axis_for_sdr(ax3, np.sqrt(inputSize) + 1, np.sqrt(inputSize) + 1, 
                             20, "Input bit at " + str(randomBitsInInputSpace[1]))
ax4 = hc.create_axis_for_sdr(ax4, np.sqrt(4096) + 1, np.sqrt(4096) + 1, 
                             20, "Active columns related to input " + str(randomBitsInInputSpace[1]))

coords1 = hc.convert_sdr_to_tuple_for_visualisation([randomBitsInInputSpace[0]], 1024)
coords2 = hc.convert_sdr_to_tuple_for_visualisation(s1.connections_of_bits_in_input_space_to_columns[randomBitsInInputSpace[0]], 4096)
coords3 = hc.convert_sdr_to_tuple_for_visualisation([randomBitsInInputSpace[1]], 1024)
coords4 = hc.convert_sdr_to_tuple_for_visualisation(s1.connections_of_bits_in_input_space_to_columns[randomBitsInInputSpace[1]], 4096)

p = [ax1.add_patch(Rectangle(coords1[i], 1, 1, color = "blue")) for i in range(len(coords1))]
p = [ax2.add_patch(Rectangle(coords2[i], 1, 1, color = "#b30000")) for i in range(len(coords2))]
p = [ax3.add_patch(Rectangle(coords3[i], 1, 1, color = "blue")) for i in range(len(coords3))]
p = [ax4.add_patch(Rectangle(coords4[i], 1, 1, color = "#b30000")) for i in range(len(coords4))]

# %% [markdown]
# Next step, place our gym power consumption data in an encoder:

# %%
inputSpaceSize = 10
activeBitsInInputs = 2
gymPowerConsumptionInputs = [hc.SDR(inputSpaceSize,activeBitsInInputs, "input_" + str(i)) for i in range(0,1024)]

# %% [markdown]
# So we now have semantically related data points, for each time step in the power consumption data. Let's get a summary of that first SDR

# %%
# create enclder

# %%
gymPowerConsumptionInputs[0].get_summary()

# %% [markdown]
# Now add these inputs into our spatial pooler:

# %%
s1.addInputsToSpatialPooler(gymPowerConsumptionInputs)

# %% [markdown]
# Now let's compute overlapOf inputs. This time we are going to have learningIsOn set to True

# %%
s1.computeOverlapOfInputsAndActiveColumns()
# Out:
# ----------------- SUMMARY -------------------------
# |L1| Some metric:
# |L1| Time elapsed during initialisation: 1.917 seconds.

# %% [markdown]
# So what is this telling us, and what metrics should we use to understand it:

# %%
# now explore metrics, then do c
