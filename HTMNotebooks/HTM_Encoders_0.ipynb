# %%
import music21 as mu

# %%
e1 = mu.converter.parse("./data/MusicXMLFiles/ActorPreludeSample.musicxml")

# %%
e1.show('text')
# Out:
# {0.0} <music21.text.TextBox 'Prelude to...'>
# {0.0} <music21.text.TextBox 'Lee Actor ...'>
# {0.0} <music21.text.TextBox '© 2004 Pol...'>
# {0.0} <music21.text.TextBox '- 2 -'>
# {0.0} <music21.text.TextBox '- 3 -'>
# {0.0} <music21.text.TextBox '- 4 -'>
# {0.0} <music21.metadata.Metadata object at 0x7ff80592aee0>
# {0.0} <music21.stream.Part Piccolo>
#     {0.0} <music21.instrument.Instrument 'P1: Piccolo: Picc. (V2k)'>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.expressions.TextExpression 'Moderato'>
#         {0.0} <music21.expressions.TextExpression ''>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber None, staffSize 108, staffLines None>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.tempo.MetronomeMark andante moderato Quarter=85.0>
#         {0.0} <music21.key.KeySignature of no sharps or flats>
# ...
