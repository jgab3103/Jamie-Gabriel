# %% [markdown]
# <i>STATUS: Draft<i>

# %%
import numpy as np
import sympy as sp
from IPython.display import HTML, IFrame
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib.patches import Rectangle
from IPython.display import Image
import sys
import HTM_Code as hc
import pandas as pd

# %% [markdown]
# In the last notebook, we built our first encoder. Admittedly, it was very simple. It just allows us to create integers and provide them to, and provide back indice location. It provided a little extra functionality so it could track previous, and comparison. And we established some rules that we would like to see in place.
#
# We also discussed what similiarity metrics in such an environment might look like, based on the rules. Its important to emphasie that we have really conflated the idea of semantic meaning, with distance, which is problematic, and we will need to take a deeper look at what it means to really encode something semantically.
#
# Finally, the Encoder Class that was introduced in the last notebook is also included in the HTM_Code.py file for us to use

# %% [markdown]
# <div style="background:#99ddff; color:black; padding: 10px">
# <b>Add to these notes:</b>
#
# I want to keep these notes in HTML so I don't have to host on a server, but a great exceriise is to use the ipython widgets to experience this like it happens in the video.
# </div>

# %%
IFrame("https://www.youtube.com/embed/PTYlge2K1G8", width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/PTYlge2K1G8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# This episode is about how we might build Date and Time Encoder, but the way I like to think of this is . But the idea behind this is really that join multiple encoders togehter. For example, I might be interested in an encoder that takes 365 values, one for each day of the year, or just 2 values (one for whether it is weekend or not the weekend), 4 values (telling me which of the seasons of the year it is), or a minute encoder (telling which minute of the day).
#
# Under the hood, these are each no different from the encoders that we were already looking at. Each value that would stored is simply and SDR with active bits and an SDR size.
#
# I could join each of these encoders together (by simply concatentating the arrays), and I would in principle have an encoder that tracks the meaning of theach these, and I could feed into it a date and time, and see thier differen they are.
#
# To explore this further, let's build another class: a multi enncoder

# %%
class Encoder:
    def __init__(self, bit_space_size = None,
                number_of_bits_used_to_encode_value = None,
                min_val = None,
                max_val = None,
                is_randomly_distributed = None,
                clip_values_outside_range = None):

        self.bit_space_size = bit_space_size
        self.number_of_bits_used_to_encode_value = number_of_bits_used_to_encode_value
        self.clip_values_outside_range = clip_values_outside_range
        self.is_periodic = False
        self.is_randomly_distributed = is_randomly_distributed

        self.resolution = 1
        self.uniqueness = 1
        self.min_value_to_encode = min_val
        self.max_value_to_encode = max_val
        self.max_bit_space_value = bit_space_size
        self.min_bit_space_value = 0
        self.encoded_values = []
        self.encoded_values_bit_locations = []
        self.offset_for_array_indice = 1
        
        self.bucket_capacity = self.compute_bucket_capacity(self.bit_space_size, self.number_of_bits_used_to_encode_value)
        
        if self.is_randomly_distributed:
            self.initial_encoding = np.array(hc.create_randomised_sdr(self.bit_space_size, self.number_of_bits_used_to_encode_value))

            self.encoded_values_and_bit_locations = {str(self.min_value_to_encode):self.initial_encoding}
            self.encoded_values.append(self.min_value_to_encode)
            self.encoded_values_bit_locations.append(np.array(self.initial_encoding))
        
    def get_summary(self):
        print("----------------- SUMMARY -------------------------")
        print("|L3| Bit Space Size: ", self.bit_space_size)
        print("|L4| Number of bits to be used when encoding each value:", self.number_of_bits_used_to_encode_value)
        print("|L5| Range of values that can be encoded: From ", self.min_value_to_encode, ' to ', self.max_value_to_encode)
        print("|L6| Number of buckets available in bit space:", float(self.bucket_capacity))
        print("|L1| Encode periodically: ", self.is_periodic)
        print("|L1| Values are encoded as are randomly distributed arrays: ", self.is_randomly_distributed)
        print("|L1| Resolution: ", self.resolution)
        print("|L1| Unique active bits per bucket: ", self.uniqueness)
        print("|L2| Values outside range will to be clipped: ",self.clip_values_outside_range)
        print("|L7| Encoded values bit locations:\n ", self.encoded_values_bit_locations)
        print("|L8| Encoded values", self.encoded_values)
        print("----------------------------------------------------")

        
    def compute_bucket_capacity(self, n, w):
        if self.is_randomly_distributed:
            return(sp.binomial(self.bit_space_size, self.number_of_bits_used_to_encode_value))
        else:
            return(n - w + 1)

    def create_buckets_for_randomly_encoded_values(self, iterations_needed):
        
        for i in range(0, iterations_needed):
            random_bit_index_to_move = np.random.randint(0, self.number_of_bits_used_to_encode_value, 1)[0]
            random_direction_to_move = np.random.randint(0, 2, 1)

            next_sdr = self.encoded_values_bit_locations[-1].copy()
            value = next_sdr[random_bit_index_to_move]
            
            if random_direction_to_move == 1:
                value = next_sdr[random_bit_index_to_move] + 1
            else: 
                value = next_sdr[random_bit_index_to_move] - 1
                
            if value > self.max_bit_space_value:
                value = value - 2
            elif value < 0:
                value = value + 2

            next_sdr[random_bit_index_to_move] = value

            self.encoded_values_bit_locations.append(next_sdr.copy())
            self.encoded_values.append(np.array(self.encoded_values[-1] + 1))
            self.encoded_values_and_bit_locations[str(self.encoded_values[-1])] = next_sdr.copy()
  

    def encode_value_in_bit_space(self, value_choice):
        print("\nEncoding the value ->", value_choice)
        unclipped_value = value_choice
        if self.clip_values_outside_range:
            if value_choice < self.min_value_to_encode or value_choice > self.max_value_to_encode:
                if value_choice < self.min_value_to_encode:
                    value_choice = self.min_value_to_encode
                else:
                    value_choice = self.max_value_to_encode
                print("The value of: ", unclipped_value, "has been clipped to ->", value_choice)
            elif value_choice > self.min_value_to_encode or value_choice < self.max_value_to_encode:
                pass
        else:
            print("Not a valid choice, ", value_choice, " is outside encoder range")
            return

        
        if self.is_randomly_distributed:
            if (value_choice < self.encoded_values[-1]):
                print("There is a bucket already created for the value", value_choice, "-> ", self.encoded_values_and_bit_locations[str(value_choice)])
                if unclipped_value < self.min_value_to_encode or unclipped_value > self.max_value_to_encode:
                    print("This bucket will be used to encode", unclipped_value)
                    self.encoded_values_and_bit_locations[str(unclipped_value)] = self.encoded_values_and_bit_locations[str(value_choice)]
                return
            
            buckets_needed_to_encode_value = value_choice - self.encoded_values[-1]
            print("Current number of buckets: " , len(self.encoded_values))
            print("Value held in first bucket: ", self.min_value_to_encode)
            print("Number of additional buckets required to accomodate the value choice of", value_choice, ": ", buckets_needed_to_encode_value)
            self.create_buckets_for_randomly_encoded_values(buckets_needed_to_encode_value)
            self.encoded_values_and_bit_locations[str(unclipped_value)] = self.encoded_values_and_bit_locations[str(value_choice)]
        
        else:
            window = [value_choice, value_choice + self.number_of_bits_used_to_encode_value]
            all_values = np.arange(window[0], window[1])
            self.encoded_values_bit_locations.append(all_values)
            self.encoded_values.append(value_choice)

# %%
# bit_space_size_choice = 64
# number_of_bits_used_to_encode_value_choice = 8

# e1 = Encoder(bit_space_size = bit_space_size_choice,
#                 number_of_bits_used_to_encode_value = number_of_bits_used_to_encode_value_choice,
#                 min_val = 0,
#                 max_val = 1,
#             is_randomly_distributed = False,
#             clip_values_outside_range = False)

# %% [markdown]
# To explore this, let's use some data. There is some really interesting data that will turn up in episode's 7 and 8 in the context of the Spatial Pooler, that has some interesting info, but for now, let's use NYC Crime data set.
#
# Information available <a href="https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i">https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i</a>
#
# I am only going to take 50'000 records. Let's download and bring it in.

# %%
df = pd.read_csv("./data/NYCCrimeData.csv")
df = pd.read_csv("./data/data-society-nyc-crime-data/data/nypd_complaint_data_current_ytd.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361740 entries, 0 to 361739
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cmplnt_num         361740 non-null  int64
#  1   cmplnt_fr_dt       361740 non-null  object
#  2   cmplnt_fr_tm       361740 non-null  object
#  3   cmplnt_to_dt       299442 non-null  object
#  4   cmplnt_to_tm       299590 non-null  object
#  5   rpt_dt             361740 non-null  object
#  6   ky_cd              361740 non-null  int64
#  7   ofns_desc          361702 non-null  object
#  8   pd_cd              361477 non-null  float64
#  9   pd_desc            361477 non-null  object
#  10  crm_atpt_cptd_cd   361740 non-null  object
#  11  law_cat_cd         361740 non-null  object
#  12  juris_desc         361740 non-null  object
#  13  boro_nm            361740 non-null  object
#  14  addr_pct_cd        361739 non-null  float64
#  15  loc_of_occur_desc  288401 non-null  object
#  16  prem_typ_desc      360326 non-null  object
#  17  parks_nm           3921 non-null    object
#  18  hadevelopt         18696 non-null   object
#  19  x_coord_cd         355886 non-null  float64
#  20  y_coord_cd         355886 non-null  float64
#  21  latitude           355886 non-null  float64
#  22  longitude          355886 non-null  float64
#  23  lat_lon            355886 non-null  object
#  24  location           355886 non-null  object
# dtypes: float64(6), int64(2), object(17)
# memory usage: 69.0+ MB

# %% [markdown]
# The first thing I want to do is create some more readable names and fix some formatting so make it easier to deal with. I am also going to add some derived data, so we can see day, season which will show us more about our encoder

# %%
#df = pd.read_csv("./data/data-society-nyc-crime-data/data/nypd_complaint_data_current_ytd.csv")
df = pd.read_csv("./data/NYCCrimeData.csv")
df.head()
# Out:
#    Unnamed: 0  cmplnt_num cmplnt_fr_dt cmplnt_fr_tm cmplnt_to_dt cmplnt_to_tm  \
# 0           0   736216184   2016-09-30     23:25:00   2016-09-30     23:25:00
# 1           1   294332956   2016-09-30     23:16:00   2016-09-30     23:21:00
# 2           2   852981427   2016-09-30     23:00:00   2016-09-30     23:05:00
# 3           3   369976063   2016-09-30     23:00:00          NaN          NaN
# 4           4   117213771   2016-09-30     23:00:00   2016-09-30     23:10:00
#
#        rpt_dt  ky_cd                     ofns_desc  pd_cd  ...  \
# 0  2016-09-30    236             DANGEROUS WEAPONS  782.0  ...
# 1  2016-09-30    344  ASSAULT 3 & RELATED OFFENSES  101.0  ...
# 2  2016-09-30    235               DANGEROUS DRUGS  567.0  ...
# 3  2016-09-30    118             DANGEROUS WEAPONS  793.0  ...
# 4  2016-09-30    578                 HARRASSMENT 2  637.0  ...
#
#   loc_of_occur_desc               prem_typ_desc parks_nm   hadevelopt  \
# 0               NaN        TRANSIT - NYC SUBWAY      NaN          NaN
# 1       OPPOSITE OF                      STREET      NaN          NaN
# 2            INSIDE  RESIDENCE - PUBLIC HOUSING      NaN  CASTLE HILL
# 3               NaN                      STREET      NaN          NaN
# 4          FRONT OF                      STREET      NaN          NaN
#
#   x_coord_cd  y_coord_cd   latitude  longitude  \
# 0  1015308.0    244373.0  40.837376 -73.887761
# 1   997932.0    180172.0  40.661205 -73.950687
# 2  1025580.0    236918.0  40.816872 -73.850685
# 3  1038464.0    192970.0  40.696177 -73.804492
# 4  1016301.0    209428.0  40.741458 -73.884339
#
#                              lat_lon                           location
# 0  POINT(-73.887760929 40.837376359)  POINT(-73.887760929 40.837376359)
# 1  POINT(-73.950686652 40.661204871)  POINT(-73.950686652 40.661204871)
# 2  POINT(-73.850684927 40.816872438)  POINT(-73.850684927 40.816872438)
# 3  POINT(-73.804492266 40.696177006)  POINT(-73.804492266 40.696177006)
# 4  POINT(-73.884339073 40.741458245)  POINT(-73.884339073 40.741458245)
#
# [5 rows x 26 columns]

# %%
#df = pd.read_csv("./data/data-society-nyc-crime-data/data/nypd_complaint_data_current_ytd.csv")
df = pd.read_csv("./data/NYCCrimeData.csv")

df = df.rename(columns={"cmplnt_num": "uniqueID",
                        "cmplnt_fr_tm": "timeOfDayOfOccurence",
                        "rpt_dt":"dateEventReported",
                        "ky_cd":"offenseClassificationCode",
                        "ofns_desc":"offenseClassificationDescription",
                        "pd_cd": "internalClassificationCode",
                        "pd_desc":"internalClassificationDescription",
                        "crm_atpt_cptd_cd": "crimeSuccessStatus",
                        "law_cat_cd": "offenseLevel",
                        "juris_desc": "jurisdictionCodeDescription",
                        "boro_nm":"nameOfBouough",
                        "addr_pct_cd":  "precinctWhereOccured",
                        "loc_of_occur_desc":"positionLocationOfOccurence",
                        "prem_typ_desc":"premisesDescription",
                        "parks_nm":"greenspaceNameIfApplicable",
                        "hadevelopt":"housingDevelopmentNameIfApplicable" })


df.dateEventReported = pd.to_datetime(df.dateEventReported)

df.timeOfDayOfOccurence = pd.to_datetime(df.timeOfDayOfOccurence)
df.timeOfDayOfOccurence= df.timeOfDayOfOccurence.dt.time

df['weekdayCodeWhenEventReported'] = [d.weekday() for d in df.dateEventReported]
df['weekdayNameWhenEventReported'] = [calendar.day_name[d.weekday()] for d in df.dateEventReported]
df['monthCodeWhenEventReported'] = df['dateEventReported'].dt.month
df['seasonCodeWhenEventReported'] = (df['dateEventReported'].dt.month - 1) % 3

df = df.drop('x_coord_cd', axis=1)
df = df.drop('y_coord_cd', axis=1)

df = df.drop('cmplnt_fr_dt', axis=1)
df = df.drop('cmplnt_to_dt', axis=1)
df = df.drop('cmplnt_to_tm', axis=1)

df = df.drop('lat_lon', axis=1)
df = df.drop('location', axis=1)

# %% [markdown]
# Let's check out the first few records:

# %%
pd.value_counts(df.dateEventReported)
# Out:
# 2016-09-22    1497
# 2016-09-06    1485
# 2016-09-23    1479
# 2016-09-15    1469
# 2016-08-31    1457
# 2016-08-25    1455
# 2016-09-28    1448
# 2016-08-30    1445
# 2016-09-20    1423
# 2016-08-29    1411
# 2016-09-09    1405
# 2016-09-14    1404
# 2016-09-16    1398
# 2016-09-08    1393
# 2016-09-21    1390
# 2016-08-26    1387
# 2016-09-07    1379
# 2016-09-02    1363
# 2016-09-13    1355
# 2016-08-28    1336
# 2016-09-29    1323
# 2016-09-27    1322
# 2016-09-12    1296
# 2016-09-26    1289
# 2016-09-17    1280
# 2016-09-24    1263
# 2016-09-03    1260
# 2016-08-27    1257
# 2016-09-11    1244
# 2016-09-01    1242
# 2016-09-10    1234
# 2016-09-05    1231
# 2016-09-18    1225
# 2016-09-30    1223
# 2016-09-25    1198
# 2016-09-04    1173
# 2016-09-19    1159
# 2016-08-24     332
# 2016-08-17       9
# 2016-08-19       8
# 2016-08-21       6
# 2016-08-18       6
# 2016-08-23       6
# 2016-08-11       6
# 2016-08-10       5
# 2016-08-09       5
# 2016-08-08       5
# 2016-08-12       3
# 2016-08-15       3
# 2016-08-20       3
# 2016-08-16       2
# 2016-08-05       1
# 2016-08-13       1
# 2016-08-22       1
# Name: dateEventReported, dtype: int64

# %%
df[10000:11000].transpose()
# Out:
#                                                         10000  \
# Unnamed: 0                                              10000
# uniqueID                                            290566759
# timeOfDayOfOccurence                                 01:45:00
# dateEventReported                         2016-09-23 00:00:00
# offenseClassificationCode                                 113
# offenseClassificationDescription                      FORGERY
# internalClassificationCode                              725.0
# internalClassificationDescription   FORGERY,M.V. REGISTRATION
# crimeSuccessStatus                                  COMPLETED
# offenseLevel                                           FELONY
# jurisdictionCodeDescription                  N.Y. POLICE DEPT
# nameOfBouough                                        BROOKLYN
# precinctWhereOccured                                     67.0
# positionLocationOfOccurence                               NaN
# premisesDescription                                    STREET
# greenspaceNameIfApplicable                                NaN
# housingDevelopmentNameIfApplicable                        NaN
# latitude                                            40.638437
# longitude                                          -73.951157
# weekdayCodeWhenEventReported                                4
# weekdayNameWhenEventReported                           Friday
# monthCodeWhenEventReported                                  9
# seasonCodeWhenEventReported                                 2
#
#                                                              10001  \
# Unnamed: 0                                                   10001
# uniqueID                                                 578685125
# timeOfDayOfOccurence                                      01:45:00
# dateEventReported                              2016-09-23 00:00:00
# offenseClassificationCode                                      235
# offenseClassificationDescription                   DANGEROUS DRUGS
# internalClassificationCode                                   511.0
# internalClassificationDescription   CONTROLLED SUBSTANCE, POSSESSI
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                           MISDEMEANOR
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                               QUEENS
# precinctWhereOccured                                         115.0
# positionLocationOfOccurence                                    NaN
# premisesDescription                                         STREET
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                 40.747742
# longitude                                                  -73.883
# weekdayCodeWhenEventReported                                     4
# weekdayNameWhenEventReported                                Friday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                                10002  \
# Unnamed: 0                                                     10002
# uniqueID                                                   610029577
# timeOfDayOfOccurence                                        01:45:00
# dateEventReported                                2016-09-23 00:00:00
# offenseClassificationCode                                        351
# offenseClassificationDescription      CRIMINAL MISCHIEF & RELATED OF
# internalClassificationCode                                     259.0
# internalClassificationDescription   CRIMINAL MISCHIEF,UNCLASSIFIED 4
# crimeSuccessStatus                                         COMPLETED
# offenseLevel                                             MISDEMEANOR
# jurisdictionCodeDescription                         N.Y. POLICE DEPT
# nameOfBouough                                                 QUEENS
# precinctWhereOccured                                           106.0
# positionLocationOfOccurence                                   INSIDE
# premisesDescription                     PARKING LOT/GARAGE (PRIVATE)
# greenspaceNameIfApplicable                                       NaN
# housingDevelopmentNameIfApplicable                               NaN
# latitude                                                   40.681212
# longitude                                                  -73.83983
# weekdayCodeWhenEventReported                                       4
# weekdayNameWhenEventReported                                  Friday
# monthCodeWhenEventReported                                         9
# seasonCodeWhenEventReported                                        2
#
#                                                     10003  \
# Unnamed: 0                                          10003
# uniqueID                                        248652147
# timeOfDayOfOccurence                             01:45:00
# dateEventReported                     2016-09-23 00:00:00
# offenseClassificationCode                             578
# offenseClassificationDescription            HARRASSMENT 2
# internalClassificationCode                          638.0
# internalClassificationDescription   HARASSMENT,SUBD 3,4,5
# crimeSuccessStatus                              COMPLETED
# offenseLevel                                    VIOLATION
# jurisdictionCodeDescription              N.Y. POLICE DEPT
# nameOfBouough                                   MANHATTAN
# precinctWhereOccured                                 10.0
# positionLocationOfOccurence                           NaN
# premisesDescription                                STREET
# greenspaceNameIfApplicable                            NaN
# housingDevelopmentNameIfApplicable                    NaN
# latitude                                        40.752031
# longitude                                      -74.004722
# weekdayCodeWhenEventReported                            4
# weekdayNameWhenEventReported                       Friday
# monthCodeWhenEventReported                              9
# seasonCodeWhenEventReported                             2
#
#                                                              10004  \
# Unnamed: 0                                                   10004
# uniqueID                                                 293569800
# timeOfDayOfOccurence                                      01:40:00
# dateEventReported                              2016-09-23 00:00:00
# offenseClassificationCode                                      121
# offenseClassificationDescription    CRIMINAL MISCHIEF & RELATED OF
# internalClassificationCode                                   273.0
# internalClassificationDescription             TAMPERING 1,CRIMINAL
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                                FELONY
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                                BRONX
# precinctWhereOccured                                          52.0
# positionLocationOfOccurence                                    NaN
# premisesDescription                                         STREET
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                 40.861839
# longitude                                               -73.892853
# weekdayCodeWhenEventReported                                     4
# weekdayNameWhenEventReported                                Friday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                        10005  \
# Unnamed: 0                                             10005
# uniqueID                                           622367983
# timeOfDayOfOccurence                                01:40:00
# dateEventReported                        2016-09-23 00:00:00
# offenseClassificationCode                                118
# offenseClassificationDescription           DANGEROUS WEAPONS
# internalClassificationCode                             792.0
# internalClassificationDescription   WEAPONS POSSESSION 1 & 2
# crimeSuccessStatus                                 COMPLETED
# offenseLevel                                          FELONY
# jurisdictionCodeDescription                 N.Y. POLICE DEPT
# nameOfBouough                                         QUEENS
# precinctWhereOccured                                   114.0
# positionLocationOfOccurence                              NaN
# premisesDescription                                   STREET
# greenspaceNameIfApplicable                               NaN
# housingDevelopmentNameIfApplicable                       NaN
# latitude                                           40.768133
# longitude                                         -73.903827
# weekdayCodeWhenEventReported                               4
# weekdayNameWhenEventReported                          Friday
# monthCodeWhenEventReported                                 9
# seasonCodeWhenEventReported                                2
#
#                                                     10006  \
# Unnamed: 0                                          10006
# uniqueID                                        957175805
# timeOfDayOfOccurence                             01:32:00
# dateEventReported                     2016-09-23 00:00:00
# offenseClassificationCode                             578
# offenseClassificationDescription            HARRASSMENT 2
# internalClassificationCode                          638.0
# internalClassificationDescription   HARASSMENT,SUBD 3,4,5
# crimeSuccessStatus                              COMPLETED
# offenseLevel                                    VIOLATION
# jurisdictionCodeDescription              N.Y. POLICE DEPT
# nameOfBouough                                      QUEENS
# precinctWhereOccured                                109.0
# positionLocationOfOccurence                      FRONT OF
# premisesDescription                       RESIDENCE-HOUSE
# greenspaceNameIfApplicable                            NaN
# housingDevelopmentNameIfApplicable                    NaN
# latitude                                          40.7736
# longitude                                      -73.805485
# weekdayCodeWhenEventReported                            4
# weekdayNameWhenEventReported                       Friday
# monthCodeWhenEventReported                              9
# seasonCodeWhenEventReported                             2
#
#                                                          10007  \
# Unnamed: 0                                               10007
# uniqueID                                             447192435
# timeOfDayOfOccurence                                  01:30:00
# dateEventReported                          2016-09-23 00:00:00
# offenseClassificationCode                                  126
# offenseClassificationDescription       MISCELLANEOUS PENAL LAW
# internalClassificationCode                               117.0
# internalClassificationDescription      RECKLESS ENDANGERMENT 1
# crimeSuccessStatus                                   COMPLETED
# offenseLevel                                            FELONY
# jurisdictionCodeDescription                N.Y. HOUSING POLICE
# nameOfBouough                                            BRONX
# precinctWhereOccured                                      40.0
# positionLocationOfOccurence                        OPPOSITE OF
# premisesDescription                 RESIDENCE - PUBLIC HOUSING
# greenspaceNameIfApplicable                                 NaN
# housingDevelopmentNameIfApplicable                         NaN
# latitude                                             40.818469
# longitude                                           -73.917682
# weekdayCodeWhenEventReported                                 4
# weekdayNameWhenEventReported                            Friday
# monthCodeWhenEventReported                                   9
# seasonCodeWhenEventReported                                  2
#
#                                                     10008  \
# Unnamed: 0                                          10008
# uniqueID                                        864107292
# timeOfDayOfOccurence                             01:30:00
# dateEventReported                     2016-09-23 00:00:00
# offenseClassificationCode                             578
# offenseClassificationDescription            HARRASSMENT 2
# internalClassificationCode                          638.0
# internalClassificationDescription   HARASSMENT,SUBD 3,4,5
# crimeSuccessStatus                              COMPLETED
# offenseLevel                                    VIOLATION
# jurisdictionCodeDescription              N.Y. POLICE DEPT
# nameOfBouough                                   MANHATTAN
# precinctWhereOccured                                 10.0
# positionLocationOfOccurence                           NaN
# premisesDescription                                STREET
# greenspaceNameIfApplicable                            NaN
# housingDevelopmentNameIfApplicable                    NaN
# latitude                                        40.745301
# longitude                                      -73.998489
# weekdayCodeWhenEventReported                            4
# weekdayNameWhenEventReported                       Friday
# monthCodeWhenEventReported                              9
# seasonCodeWhenEventReported                             2
#
#                                                              10009  ...  \
# Unnamed: 0                                                   10009  ...
# uniqueID                                                 736124422  ...
# timeOfDayOfOccurence                                      01:30:00  ...
# dateEventReported                              2016-09-23 00:00:00  ...
# offenseClassificationCode                                      341  ...
# offenseClassificationDescription                     PETIT LARCENY  ...
# internalClassificationCode                                   333.0  ...
# internalClassificationDescription   LARCENY,PETIT FROM STORE-SHOPL  ...
# crimeSuccessStatus                                       COMPLETED  ...
# offenseLevel                                           MISDEMEANOR  ...
# jurisdictionCodeDescription                       N.Y. POLICE DEPT  ...
# nameOfBouough                                             BROOKLYN  ...
# precinctWhereOccured                                          77.0  ...
# positionLocationOfOccurence                                 INSIDE  ...
# premisesDescription                                     DRUG STORE  ...
# greenspaceNameIfApplicable                                     NaN  ...
# housingDevelopmentNameIfApplicable                             NaN  ...
# latitude                                                 40.671269  ...
# longitude                                               -73.943415  ...
# weekdayCodeWhenEventReported                                     4  ...
# weekdayNameWhenEventReported                                Friday  ...
# monthCodeWhenEventReported                                       9  ...
# seasonCodeWhenEventReported                                      2  ...
#
#                                                              10990  \
# Unnamed: 0                                                   10990
# uniqueID                                                 754100963
# timeOfDayOfOccurence                                      14:50:00
# dateEventReported                              2016-09-22 00:00:00
# offenseClassificationCode                                      341
# offenseClassificationDescription                     PETIT LARCENY
# internalClassificationCode                                   338.0
# internalClassificationDescription   LARCENY,PETIT FROM BUILDING,UN
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                           MISDEMEANOR
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                               QUEENS
# precinctWhereOccured                                         103.0
# positionLocationOfOccurence                                 INSIDE
# premisesDescription                               DEPARTMENT STORE
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                 40.705312
# longitude                                               -73.795294
# weekdayCodeWhenEventReported                                     3
# weekdayNameWhenEventReported                              Thursday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                             10991  \
# Unnamed: 0                                                  10991
# uniqueID                                                264757134
# timeOfDayOfOccurence                                     14:50:00
# dateEventReported                             2016-09-22 00:00:00
# offenseClassificationCode                                     361
# offenseClassificationDescription    OFF. AGNST PUB ORD SENSBLTY &
# internalClassificationCode                                  639.0
# internalClassificationDescription         AGGRAVATED HARASSMENT 2
# crimeSuccessStatus                                      COMPLETED
# offenseLevel                                          MISDEMEANOR
# jurisdictionCodeDescription                      N.Y. POLICE DEPT
# nameOfBouough                                              QUEENS
# precinctWhereOccured                                        101.0
# positionLocationOfOccurence                                INSIDE
# premisesDescription                                 PUBLIC SCHOOL
# greenspaceNameIfApplicable                                    NaN
# housingDevelopmentNameIfApplicable                            NaN
# latitude                                                40.593709
# longitude                                              -73.786144
# weekdayCodeWhenEventReported                                    3
# weekdayNameWhenEventReported                             Thursday
# monthCodeWhenEventReported                                      9
# seasonCodeWhenEventReported                                     2
#
#                                                                         10992  \
# Unnamed: 0                                                              10992
# uniqueID                                                            966021879
# timeOfDayOfOccurence                                                 14:50:00
# dateEventReported                                         2016-09-22 00:00:00
# offenseClassificationCode                                                 109
# offenseClassificationDescription                                GRAND LARCENY
# internalClassificationCode                                              439.0
# internalClassificationDescription   LARCENY,GRAND FROM OPEN AREAS, UNATTENDED
# crimeSuccessStatus                                                  COMPLETED
# offenseLevel                                                           FELONY
# jurisdictionCodeDescription                                  N.Y. POLICE DEPT
# nameOfBouough                                                        BROOKLYN
# precinctWhereOccured                                                     83.0
# positionLocationOfOccurence                                               NaN
# premisesDescription                                           PARK/PLAYGROUND
# greenspaceNameIfApplicable                               MARIA HERNANDEZ PARK
# housingDevelopmentNameIfApplicable                                        NaN
# latitude                                                            40.702818
# longitude                                                          -73.925392
# weekdayCodeWhenEventReported                                                3
# weekdayNameWhenEventReported                                         Thursday
# monthCodeWhenEventReported                                                  9
# seasonCodeWhenEventReported                                                 2
#
#                                                          10993  \
# Unnamed: 0                                               10993
# uniqueID                                             333020160
# timeOfDayOfOccurence                                  14:50:00
# dateEventReported                          2016-09-22 00:00:00
# offenseClassificationCode                                  578
# offenseClassificationDescription                 HARRASSMENT 2
# internalClassificationCode                               637.0
# internalClassificationDescription   HARASSMENT,SUBD 1,CIVILIAN
# crimeSuccessStatus                                   COMPLETED
# offenseLevel                                         VIOLATION
# jurisdictionCodeDescription                   N.Y. POLICE DEPT
# nameOfBouough                                    STATEN ISLAND
# precinctWhereOccured                                     120.0
# positionLocationOfOccurence                           FRONT OF
# premisesDescription                            RESIDENCE-HOUSE
# greenspaceNameIfApplicable                                 NaN
# housingDevelopmentNameIfApplicable                         NaN
# latitude                                             40.637258
# longitude                                           -74.076567
# weekdayCodeWhenEventReported                                 3
# weekdayNameWhenEventReported                          Thursday
# monthCodeWhenEventReported                                   9
# seasonCodeWhenEventReported                                  2
#
#                                                              10994  \
# Unnamed: 0                                                   10994
# uniqueID                                                 986798257
# timeOfDayOfOccurence                                      14:47:00
# dateEventReported                              2016-09-22 00:00:00
# offenseClassificationCode                                      341
# offenseClassificationDescription                     PETIT LARCENY
# internalClassificationCode                                   333.0
# internalClassificationDescription   LARCENY,PETIT FROM STORE-SHOPL
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                           MISDEMEANOR
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                             BROOKLYN
# precinctWhereOccured                                          84.0
# positionLocationOfOccurence                                 INSIDE
# premisesDescription                               DEPARTMENT STORE
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                 40.687054
# longitude                                               -73.990251
# weekdayCodeWhenEventReported                                     3
# weekdayNameWhenEventReported                              Thursday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                              10995  \
# Unnamed: 0                                                   10995
# uniqueID                                                 900320400
# timeOfDayOfOccurence                                      14:45:00
# dateEventReported                              2016-09-22 00:00:00
# offenseClassificationCode                                      113
# offenseClassificationDescription                           FORGERY
# internalClassificationCode                                   729.0
# internalClassificationDescription   FORGERY,ETC.,UNCLASSIFIED-FELO
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                                FELONY
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                               QUEENS
# precinctWhereOccured                                         100.0
# positionLocationOfOccurence                                 INSIDE
# premisesDescription                                           BANK
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                  40.58258
# longitude                                               -73.835444
# weekdayCodeWhenEventReported                                     3
# weekdayNameWhenEventReported                              Thursday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                       10996  \
# Unnamed: 0                                            10996
# uniqueID                                          932981176
# timeOfDayOfOccurence                               14:45:00
# dateEventReported                       2016-09-22 00:00:00
# offenseClassificationCode                               126
# offenseClassificationDescription    MISCELLANEOUS PENAL LAW
# internalClassificationCode                            117.0
# internalClassificationDescription   RECKLESS ENDANGERMENT 1
# crimeSuccessStatus                                COMPLETED
# offenseLevel                                         FELONY
# jurisdictionCodeDescription                N.Y. POLICE DEPT
# nameOfBouough                                      BROOKLYN
# precinctWhereOccured                                   94.0
# positionLocationOfOccurence                          INSIDE
# premisesDescription                  RESIDENCE - APT. HOUSE
# greenspaceNameIfApplicable                              NaN
# housingDevelopmentNameIfApplicable                      NaN
# latitude                                          40.724722
# longitude                                        -73.940531
# weekdayCodeWhenEventReported                              3
# weekdayNameWhenEventReported                       Thursday
# monthCodeWhenEventReported                                9
# seasonCodeWhenEventReported                               2
#
#                                                              10997  \
# Unnamed: 0                                                   10997
# uniqueID                                                 580649561
# timeOfDayOfOccurence                                      14:40:00
# dateEventReported                              2016-09-22 00:00:00
# offenseClassificationCode                                      341
# offenseClassificationDescription                     PETIT LARCENY
# internalClassificationCode                                   333.0
# internalClassificationDescription   LARCENY,PETIT FROM STORE-SHOPL
# crimeSuccessStatus                                       COMPLETED
# offenseLevel                                           MISDEMEANOR
# jurisdictionCodeDescription                       N.Y. POLICE DEPT
# nameOfBouough                                             BROOKLYN
# precinctWhereOccured                                          72.0
# positionLocationOfOccurence                               FRONT OF
# premisesDescription                               DEPARTMENT STORE
# greenspaceNameIfApplicable                                     NaN
# housingDevelopmentNameIfApplicable                             NaN
# latitude                                                 40.654751
# longitude                                               -74.007368
# weekdayCodeWhenEventReported                                     3
# weekdayNameWhenEventReported                              Thursday
# monthCodeWhenEventReported                                       9
# seasonCodeWhenEventReported                                      2
#
#                                                     10998  \
# Unnamed: 0                                          10998
# uniqueID                                        161593920
# timeOfDayOfOccurence                             14:40:00
# dateEventReported                     2016-09-22 00:00:00
# offenseClassificationCode                             578
# offenseClassificationDescription            HARRASSMENT 2
# internalClassificationCode                          638.0
# internalClassificationDescription   HARASSMENT,SUBD 3,4,5
# crimeSuccessStatus                              COMPLETED
# offenseLevel                                    VIOLATION
# jurisdictionCodeDescription           N.Y. TRANSIT POLICE
# nameOfBouough                                       BRONX
# precinctWhereOccured                                 42.0
# positionLocationOfOccurence                           NaN
# premisesDescription                  TRANSIT - NYC SUBWAY
# greenspaceNameIfApplicable                            NaN
# housingDevelopmentNameIfApplicable                    NaN
# latitude                                        40.837376
# longitude                                      -73.887761
# weekdayCodeWhenEventReported                            3
# weekdayNameWhenEventReported                     Thursday
# monthCodeWhenEventReported                              9
# seasonCodeWhenEventReported                             2
#
#                                                     10999
# Unnamed: 0                                          10999
# uniqueID                                        862515314
# timeOfDayOfOccurence                             14:40:00
# dateEventReported                     2016-09-22 00:00:00
# offenseClassificationCode                             578
# offenseClassificationDescription            HARRASSMENT 2
# internalClassificationCode                          638.0
# internalClassificationDescription   HARASSMENT,SUBD 3,4,5
# crimeSuccessStatus                              COMPLETED
# offenseLevel                                    VIOLATION
# jurisdictionCodeDescription              N.Y. POLICE DEPT
# nameOfBouough                                       BRONX
# precinctWhereOccured                                 44.0
# positionLocationOfOccurence                      FRONT OF
# premisesDescription                                STREET
# greenspaceNameIfApplicable                            NaN
# housingDevelopmentNameIfApplicable                    NaN
# latitude                                        40.823156
# longitude                                      -73.921568
# weekdayCodeWhenEventReported                            3
# weekdayNameWhenEventReported                     Thursday
# monthCodeWhenEventReported                              9
# seasonCodeWhenEventReported                             2
#
# [23 rows x 1000 columns]

# %% [markdown]
# There is some interesting data here, some some scalar type values, and

# %%
#df.info()

# %%
df = pd.read_csv("./data/gymdata.csv", header=1)
df = df.rename(columns={"datetime": "dateTime", "float": "powerConsumption"})
df = df.iloc[1:]
df.dateTime = pd.to_datetime(df.dateTime, format="%m/%d/%y %H:%M")
df['date'] = [d.date() for d in df.dateTime]
df['timeOfDay'] = [d.time() for d in df.dateTime]
df['dayCode'] = [d.weekday() for d in df.date]
df['monthCode'] = df['dateTime'].dt.month
#df['monthCode'] = (df['dateTime'].dt.month - 1) % 3
df['isWeekend'] = np.where(df.dayCode > 4, True, False)
df['dayName'] = [calendar.day_name[d.weekday()] for d in df.date]
# df = df.drop('date_time', axis=1)
#df = df.drop('weekday', axis=1)

# %%
pd.value_counts(df.monthCode)
# Out:
# 8     744
# 10    744
# 12    743
# 9     720
# 7     720
# 11    720
# Name: monthCode, dtype: int64

# %%
df[df.isWeekend == True]
# Out:
#                 dateTime  powerConsumption        date timeOfDay  dayCode  \
# 25   2010-07-03 00:00:00              22.5  2010-07-03  00:00:00        5
# 26   2010-07-03 01:00:00              22.3  2010-07-03  01:00:00        5
# 27   2010-07-03 02:00:00               6.0  2010-07-03  02:00:00        5
# 28   2010-07-03 03:00:00               4.7  2010-07-03  03:00:00        5
# 29   2010-07-03 04:00:00               4.4  2010-07-03  04:00:00        5
# ...                  ...               ...         ...       ...      ...
# 4268 2010-12-26 19:00:00               5.5  2010-12-26  19:00:00        6
# 4269 2010-12-26 20:00:00               5.5  2010-12-26  20:00:00        6
# 4270 2010-12-26 21:00:00               5.2  2010-12-26  21:00:00        6
# 4271 2010-12-26 22:00:00               4.9  2010-12-26  22:00:00        6
# 4272 2010-12-26 23:00:00               5.0  2010-12-26  23:00:00        6
#
#       monthCode  isWeekend   dayName
# 25            0       True  Saturday
# 26            0       True  Saturday
# 27            0       True  Saturday
# 28            0       True  Saturday
# 29            0       True  Saturday
# ...         ...        ...       ...
# 4268          2       True    Sunday
# 4269          2       True    Sunday
# 4270          2       True    Sunday
# 4271          2       True    Sunday
# 4272          2       True    Sunday
#
# [1248 rows x 8 columns]

# %%
from datetime import date
import calendar
my_date = date.today()
print(my_date.weekday())
calendar.day_name[my_date.weekday()]  #'Wednesday'
# Out:
# 2
# 'Wednesday'

# %% [markdown]
# Now onto next episode of HTM School

# %%
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://www.youtube.com/embed/PTYlge2K1G8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
class MultiEncoder:
    def __init__(self):
        self.encoders = []
        self.bit_space_size = None
    def add_encoder(self, encoder):
        self.encoders.append(encoder)
    def join_encoders(self):
        pass

# %% [markdown]
# So this is a really powerful idea. We can think about multiple time series unfolding, date time components. Or we could think of symbolic music, track key changes

# %%
def compute_union_and_overlap(SDR1_on_bits, SDR2_on_bits):
    union = list(set(SDR1_on_bits).union(SDR2_on_bits))
    overlap = list(set(SDR1_on_bits).intersection(SDR2_on_bits))
    
    return({"union": union, "overlap": overlap})

# %% [markdown]
# This is starting to seem more like we saw in the early notebooks, we can how semantic similairty is affected by noise and subsampling

# %% [markdown]
# There is alot more we can do with encoders. Delta encoder, log encoder. A geospatial encoder particularly interesting, enconding values on a sphere, what other geometrical shapes, opens us up to diffent types of geometry adn topology also

# %% [markdown]
# Let's look at more encoders:
# https://numenta.com/assets/pdf/biological-and-machine-intelligence/BaMI-Encoders.pdf
#
# IMportant to capture semantics properly
#
# 4 principles recall..... eg consider two numbers should be semantically similiar
#
# Note for encoders, we can encode anything we can put in a relationship of
#
# we need encoders to have to to incorporate noise and subsamplinig
#
# Encoding Daa for HTM systems - Purdy
#
#
# Date Time Encoder
