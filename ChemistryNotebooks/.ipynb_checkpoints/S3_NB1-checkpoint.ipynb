# %% [markdown]
# Computatonal neorusocience - what nervou syst do, how fthey function, whey thyey operate in
#
#
# Descriptiove Models (what)
#
# Mechanistic Models (how)
#
# Interpretive models (why)
#
#
#
# consider receptive fields
# - 1960s, hurbel and wiesel experiement in 60s
# - recrod signaals from brain cells and simulation - different types of stimuli
# - converted electrical into audio, here the effectg - shows differnt light shapes, edges of lights,
# -
#
# Receptive field - specific properties of a sensory stimulus that genrate a strong response from the cell (ie. spot of light that turns on location of retina)
#
# we can apply descripbive, mechanistic, interpr to receptive fields
#
# Descriptive model of receptive fields
# - we have retina (projects inverted image)
# - we have retinal ganglion cells gets info and moves info to other parts of brains
# - to explore, put flash of light on small patch oif retina - look at output - can klead to cetnre-surround reciptive fields, mening off-on in centre or surround leading to certain responses - cell - data shows that cell responds to off and on scenaros - consioder on-centre/off surround vs off-cetnre/on-surround
# - note info passed from retina ot lateral geniculate nucleus (LGN) and this passes to primary visual cortex (V1)
# - so this experiement will create changes to cells in primary visual cortex - orientated receptive field - neurns tend to respnd best to bright bar with dark backfound. Of course there are many different orientated recpetive fields depending on what is being activate - cetnre surround idea still here
# - Questoin - how are oreintated recpetive fields obtained from centre-surround receptive fields? - need mechanistic model
#
#
# Mechanistic Model
# - recall retina to LGN to VI
# - how are receptive fields constructed using the neural circutry of visual cortex - how do we get orietnted from centere surround
# - HOW - mechanistic
# - need to look at neuroanatomy
# - info from retino to optic nerve to LG1 and V1
# - comes from number of LGN cells converging to V1 cells - LGN cells are actually merging into V1 cell - model suggested from Hubel Wiesel - V1 cell is contatenation - mechanistic - note that this is controversioal - doesn't take into account other inputs - V1 cells also get info from themselves and other V1 - hubel and wesiel don't take into account
# - note - feedfoward
#
#
# Interpretive MOdel receptive fields
# - idea here is to find algorithm which allows us to do this - take patch of image, and reconstruct image
# - Why are they shaped this way - what are computational advantages of such fields - engineering and comp sci questions
# - One idea - Efficient Coding Hypothetsis - represent images as faithfuly as possible using neurons with receptive fields - so is this is best way to represent these?
# - idea you can add receptive fields $\hat{I} = \Sigma{RF_ir_i}$ - add with linear algebra, find the $RF_i$ to minise the total squared pixel wise errors between $I$ and $\hat{I}$ - this is goal, differnt between natural image, I and reconstructed images
# - so idea is start out with random RF_i and run effiecient coding algorithm on natural image patches - idea of randomly sampling a natural image (like a pixel)( and then running coding -
# - possible to use sparse coding (olshausen and field, 1996)
# - or ICA - Bell and Sejnosksi, 1997
# - or Predicive coding, 1999, Rao and Ballard
# - shows that brain may be trying to faithful and efficient representations of animals natrual environment
#
#
#
# Neuron, Synapses, Brain Regions
#
# - neurons are small - ~25 microns (1 millionth of metre)
# - zoo of neuons - Romon y cajal - early 1900s
# - pyramidal neurons....vs cells from cerebellum vs cells from optic tectum -
# - branching structures are different
# - used to be 2 hypothesis - continuous network vs descrite cells - cells are discrete
#
# Nueron doctrin
# - neuron is fundamental structural and functional unit
# - neurons are discrete cells, not continuous (for majority at least)
# - info flows from dendritest to axon via cell body (for majority
#
#
# leads to idealised model - grpahic hre including
# cell sget multiple EPSP and then summation occurs in cell body - reaches threshold
#
# -Neuron - is a leaky bag of chargede liquid
# - encolsoed a cell membrane
# - membrane is a lipid bilature (fatty bilayer) - impermeable to charhed ion such as Na+ (sodium), CL (chloride)- and K+ (potassium)
# - in membrane are ionic channelsto allow ions to move in and out
#
# - inside neuron -70 mv, outside (0mv)
# - due to NA+ and CL- being hihger outside, and K+ and organic anions A- hgiher inside
#
# - Outside: NA+, CL-, H20, K+
# - inside K+ (more), A-, Na+ (less), CL-(less), H20
# - evolved from single cell organisms - salty water?
# - to maintain difference betweein inside/out - uses Ionic pump maintains -70 mV difference by expelling Na+, allowding K+ ions in
#
#
# - question - how do we change the -70 mv - we nbeed inputs - change electrical potential in local regions of neuon
# - ionic challens - gated means open or closed - presence of voltage, chemicals, or forces
