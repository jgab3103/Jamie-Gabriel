# %% [markdown]
# STATUS: Draft

# %%
import sympy as sp
import numpy as np
import shared_functions as sf

# %% [markdown]
# [Proof 3_3_3_i](#3_3_3_i)<br/>
# <i>Proposition:</i>
# The sum of the first n triangular numbers is a pyramidal number and its value can be derived as:
#
# $$ T_0+T_1+T_2+\cdots+T_{n-1}=\frac{(n-1)n(n+1)}{6}=P_{n-1}.$$
#
# <br/><i>Related name: </i> Sum of triangular numbers
#
#
# [Proof 3_3_3_ii](#3_3_3_ii)<br/>
# <i>Proposition:</i>
# If  $A_k=[k,k^2]$  then it must be the case that:
#
# $$ s(\overrightarrow{A_0A_1A_2\cdots A_{n}})=\frac{n^3-n}{6}. $$
#
# <br/><i>Related name: </i> Sum of triangular numbers
#
#
# [Proof 3_3_6_i](#3_3_6_i)<br/>
# <i>Proposition:</i>
# Suppose A_k=[k,k^2] is a point the parabola $y=x^2$ where k is an integer. For any two natural numbers $m$ and $n$ satisfying $m \le n$ it must be the case that:
#
# $$  s(\overrightarrow{A_m A_{m+1} \cdots A_n})=\frac{(n-m)(n^2+ mn+m^2-1)}{6}. $$
#
# <br/><i>Related name: </i> Formulas for integral oriented polygonal splines on the parabola
#
#
#
# [Proof 3_3_6_ii](#3_3_6_ii)<br/>
# <i>Proposition:</i>
# Suppose A_k=[k,k^2] is a point the parabola $y=x^2$ where k is an integer. For any two natural numbers $m$ and $n$ satisfying $m \gt n$ it must be the case that:
#
# $$  s(\overrightarrow{A_m A_{m+1} \cdots A_n})=\frac{(n-m)(n^2+ mn+m^2-1)}{6}. $$
#
# <br/><i>Related name: </i> Formulas for integral oriented polygonal splines on the parabola
#
#
#
#
# [Proof 3_3_6_iii](#3_3_6_iii)<br/>
# <i>Proposition:</i>
# Suppose A_k=[k,k^2] is a point the parabola $y=x^2$ where k is an integer. For any natural number $m$ it must be the case that:
#
# $$  s(\overrightarrow{A_m A_{m+1} A_{m+2}})=(m+1)^2. $$
#
# <br/><i>Related name: </i> Formulas for integral oriented polygonal splines on the parabola
#
#
# [Proof 3_3_7_i](#3_3_7_i)<br/>
# jg - prove in refs that holds for a < 0
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=0$ to $x=a$ for some rational number $a\ge0$. Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
# $$ A_0=[0,0], \; \; A_1=\left[\frac an, \left(\frac an\right)^2\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^2\right], \; \;\ldots, \; \; A_n=[a,a^2]$$
#
# Note that, in general, points can be denoted as:
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^2\right]  $$ for $k=0,1,\ldots,n$
#
# Given the above, it must be the case that $$  s(\overrightarrow{A_{k-1} A_k})=\frac {a^3}{n^3}T_{k-1}.$$
#
# <br/><i>Related name: </i> Formulas for integral oriented polygonal splines on the parabola
#
#
#
# [Proof 3_3_7_ii](#3_3_7_ii)<br/>
# jg - prove in refs that holds for a < 0
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=0$ to $x=a$ for some rational number $a\ge0$. Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
# $$ A_0=[0,0], \; \; A_1=\left[\frac an, \left(\frac an\right)^2\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^2\right], \; \;\ldots, \; \; A_n=[a,a^2]$$
#
# Note that, in general, points can be denoted as:
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^2\right]  $$ for $k=0,1,\ldots,n$
#
# Given the above, it must be the case that $$ s(\overrightarrow{A_0 A_1 \cdots A_n})=\frac {a^3}{n^3}P_{n-1}.$$
#
# <br/><i>Related name: </i> Formulas for integral oriented polygonal splines on the parabola
#
#
#
#
# [Proof 3_3_8_i](#3_3_8_i)<br/>
# jg - show formula holds when a < 0
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=0$ to $x=a$ for some rational number $a\ge0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$   A_0=[0,0], \; A_1=\left[\frac an, \left(\frac an\right)^2\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^2\right], \;\ldots,\; A_n=[a,a^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^2\right] $$ for $k=0,1,\ldots,n$
#
# Given the above, it must be the case that:
#
# $$  s(\overrightarrow{A_0 A_1 \cdots A_n})=\frac {a^3}{6}\left(1-\left(\frac 1n\right)^2\right). $$
# <br/><i>Related name: </i> A possible area for a standard parabolic arc
#
#
# [Proof 3_3_8_ii](#3_3_8_ii)<br/>
# jg - show formula holds when a < 0
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=0$ to $x=a$ for some rational number $a\ge0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$   A_0=[0,0], \; A_1=\left[\frac an, \left(\frac an\right)^2\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^2\right], \;\ldots,\; A_n=[a,a^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^2\right] $$ for $k=0,1,\ldots,n$
#
# Given the above, the constant term in this expression, when regarded as a polynomical in $h=1/n$ is
#
# $$  \frac {a^3}{6} $$
#
#
# <br/><i>Related name: </i> A possible area for a standard parabolic arc
#
#
#
#
# [Proof 3_3_9_i](#3_3_9_i)<br/>
# jg - show holds when a<b<0 and a<0<b.
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $b \gt a \gt 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$  A_0=[a,a^2], \;\; A_1=\left[a+\frac {b-a}{n}, \left(a+\frac {b-a}{n}\right)^2\right], A_2=\left[a+\frac {2(b-a)}{n}, \left(a+\frac {2(b-a)}{n}\right)^2\right], \;\;\ldots,\;\; A_n=[b,b^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$ A_k=\left[a+\frac {k(b-a)}{n},\left(a+\frac {k(b-a)}{n}\right)^2\right] $$
# for $k=0,1,\ldots,n$
#
# Given the above, for $k=1,\ldots,n,$ it must be the case that:
#
# $$  s(\overrightarrow{A_{n} A_0})=\frac12(ba^2-ab^2). $$
#
#
# <br/><i>Related name: </i> A possible area for a standard parabolic arc
#
#
# [Proof 3_3_9_ii](#3_3_9_ii)<br/>
# jg - whow holds when a<b<0 and a<0<b.
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $b \gt a \gt 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$  A_0=[a,a^2], \;\; A_1=\left[a+\frac {b-a}{n}, \left(a+\frac {b-a}{n}\right)^2\right], A_2=\left[a+\frac {2(b-a)}{n}, \left(a+\frac {2(b-a)}{n}\right)^2\right], \;\;\ldots,\;\; A_n=[b,b^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$ A_k=\left[a+\frac {k(b-a)}{n},\left(a+\frac {k(b-a)}{n}\right)^2\right] $$
# for $k=0,1,\ldots,n$
#
# Given the above, for $k=1,\ldots,n,$ it must be the case that:
#
# $$  s(\overleftrightarrow{A_0 A_1 \cdots A_n})=\frac {(b-a)^3}{n^3}P_{n-1} $$
#
#
# <br/><i>Related name: </i> A possible area for a standard parabolic arc
#
#
#
#
# [Proof 3_3_10_i](#3_3_10_i)<br/>
# jg - whow holds when a<b<0 and a<0<b.
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $b \gt a \gt 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$  A_0=[a,a^2], \; A_1=\left[a+\frac {b-a}{n}, \left(a+\frac {b-a}{n}\right)^2\right], A_2=\left[a+\frac {2(b-a)}{n}, \left(a+\frac {2(b-a)}{n}\right)^2\right], \;\ldots,\; A_n=[b,b^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$A_k=\left[a+\frac {k(b-a)}{n},\left(a+\frac {k(b-a)}{n}\right)^2\right] $$
# for $k=0,1,\ldots,n$
#
# Given the above, it must be the case that the signed area, $s(\overleftrightarrow{A_0 A_1 \cdots A_n})$ is:
# $$  \frac {(b-a)^3}{6}\left(1-\left(\frac 1n\right)^2\right). $$
#
#
# <br/><i>Related name: </i> A possible area for more general parabolic sectors
#
#
#
#
# [Proof 3_3_10_ii](#3_3_10_ii)<br/>
# jg - whow holds when a<b<0 and a<0<b.
# <i>Proposition:</i>
# Suppose  $y=x^2$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $b \gt a \gt 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola. Note that the total number of points is $n+1$ for some integer $n$. Denote these points as:
#
#
# $$  A_0=[a,a^2], \; A_1=\left[a+\frac {b-a}{n}, \left(a+\frac {b-a}{n}\right)^2\right], A_2=\left[a+\frac {2(b-a)}{n}, \left(a+\frac {2(b-a)}{n}\right)^2\right], \;\ldots,\; A_n=[b,b^2] $$
#
# Note that, in general, points can be denoted as:
#
#
# $$A_k=\left[a+\frac {k(b-a)}{n},\left(a+\frac {k(b-a)}{n}\right)^2\right] $$
# for $k=0,1,\ldots,n$
#
# Given the above,the constant term in this expression, when regarded as a polynomial in $h=1/n$, is
# $$  \frac {(b-a)^3}{6} $$
#
#
# <br/><i>Related name: </i> A possible area for more general parabolic sectors
#
#
#
# [Proof 3_3_12](#3_3_12)<br/>
# <i>Proposition:</i>
#
# Suppose $A=[a,a^2]$ and $B=[b,b^2]$ are points on a parabolic curve $y=x^2$ where $a$ and $b$ are integers and $a \gt b$. Note that signed area of the parabolic arc formed by the chord AB (also denoted $\subset AB$ is equivalent to:
# $$  s(\subset AB)\equiv \frac{(a-b)^3}{6}. $$ (Ref 3_3_10)
#
# Suppose $C=\big[\frac{a+b}{2},\frac{(a+b)^2}{4}\big]$ is also a point on the parabola.
#
# Note (from 3.1.4) that the oriented triangle ABC constructed from points A, B C has a maximum signed area and this is:
#
# $$  s(\widetilde{ABC})=\frac{(a-b)^3}{8}. $$
#
# Given the above, it must be the case that:
#
# $$  s(\subset AB)=\frac{4}{3}s(\widetilde{ABC})  $$
#
# <br/><i>Related name: </i> Archimedes' parabolic area formula (general)
#
#
#
#
#
#
# [Proof 3_3_13](#3_3_13)<br/>
#
# <i>Proposition:</i>
#
# REWRITE WHILE DOING PROOF
#
# <br/><i>Related name: </i> Parabolic area formula in terms of $\widetilde{OAB}$
#
#
#
# [Proof 3_3_15_i](#3_3_15_i)<br/>
#
# <i>Proposition:</i>
#
# Suppose  $y=x^3$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $a \ge 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola, which can be written as:
#
# $$ A_0=[0,0], \; A_1=\left[\frac an, \left(\frac an\right)^3\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^3\right], \;\ldots,\; A_n=[a,a^3]   $$
#
# Note that, in general, points can be denoted as:
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^3\right]  $$
#
# for $k=0,1,…,n$
#
# Given the above, it must be the case that the signed area constructed from points, $s(\overrightarrow{A_0 A_1 \cdots A_n})$ is:
#
# $$ \frac{a^4}{4}\left(1-\left(\frac{1}{n}\right)^2\right).  $$
#
# <br/><i>Related name: </i> A possible signed area of a cubic polygonal arc
#
#
#
# [Proof 3_3_15_ii](#3_3_15_ii)<br/>
#
# <i>Proposition:</i>
#
# Suppose  $y=x^3$ is a parabola  with a fixed domain from from $x=a$ to $x=b$ for some rational number $a \ge 0$.
#
# Let $A_0, A_1, A_2 \ldots A_n$ be points on this parabola, which can be written as:
#
# $$ A_0=[0,0], \; A_1=\left[\frac an, \left(\frac an\right)^3\right], A_2=\left[\frac {2a}{n}, \left(\frac {2a}{n}\right)^3\right], \;\ldots,\; A_n=[a,a^3]   $$
#
# Note that, in general, points can be denoted as:
#
# $$ A_k=\left[\frac {ka}{n},\left(\frac {ka}{n}\right)^3\right]  $$
#
# for $k=0,1,…,n$
#
# Given the above, the constant term in this expression, when regarded as a polynomial in $h=\frac{1}{n}$, is $\frac{a^4}{4}$.
#
# <br/><i>Related name: </i> A possible signed area of a cubic polygonal arc
#
#
# <hr/>

# %% [markdown]
# ### 3_3_3_i <a class="anchor" id="3_3_3_i"></a>
# <i>Proposition:</i>
# The sum of the first n triangular numbers is a pyramidal number and its value can be derived as:
#
# $$ T_0+T_1+T_2+\cdots+T_{n-1}=\frac{(n-1)n(n+1)}{6}=P_{n-1}.$$
#
# <br/><i>Related name: </i> Maximum of triangular signed area on a parabola
