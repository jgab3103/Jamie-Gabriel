# %%
import numpy as np
import sympy as sp
from IPython.display import HTML, IFrame
import ipywidgets as widgets
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
mpl.rcParams['legend.fontsize'] = 10
import pandas as pd
import itertools
from IPython.display import Image

# This is commented out
#%matplotlib widget

# function to print latex
def renderListToLatex(e):
    latex_rendering = []

    for i in range(len(e)):
        latex_rendering.append("$$" + sp.latex(e[i]) + "$$")
    
    return(HTML("".join(latex_rendering[0:])))

# %% [markdown]
# <hr/>
#
# <b>Aim</b> To provide an initial intuition around the construction of Affine space as an introduction to Linear Algebra.
#
#
# <hr/>

# %% [markdown]
# Observe: Linear Algebra can be thought of as the geometry of n-dim space, or the geometry of parallels
#
# Let $\text{WLA1_1}$ be a construction called an Affine Plane

# %%
Image(filename='./Images/WLA1_1.PNG', width=700, height=700)

# %% [markdown]
# Observe: WLA1_1 can be constructed with a straight edge and parallel lines.
#
# Observe: There is no notion of origin, angles, no measurements distance (however an origin can be arbitrarily placed)
#
# Observe: there is a notion of relative distance. Between each paralel line this is the same, however there is no known relationship between the points appearing in the respective parallel lines.
#
# Observe: It is possible to start at some point and count and obtain a sequential number system in in relation to the Affine Grid.
#
# Observe: It is possible to describe a point formed by incident lines on an Affine Plane if an arbitary point is chosen as an origin, 2 integers can be used.

# %% [markdown]
# Definition: <b>Vector</b>
#
# A vector is a pair of numbers $(a,b)$ where $a$ and $b$ are chosen from aribitrary starting point (e.g. $(2,3)$)

# %% [markdown]
# <hr/>
#
# <b>Aim</b>: Show an intuition for a a vector on a plane.
#
# <hr/>

# %% [markdown]
# Observe - can we consider other points,
# Obsere - we can subdive any into
#
# Observe - can cosntruct
#
# Note rule for equality
# $$\frac{a}{b}$$ where a, b are integres b != 0
#
# Observe - ad - bc = 0

# %% [markdown]
# Vector......
#
# Observe2 operations, mtiple and add vectors eg - 2e1 + 5e2
#
# Geometry....one follows aother idea, multiple.....do diagrams

# %% [markdown]
# Multiple grids.....

# %% [markdown]
# f1 = 3e1 + e2
# f2 = e1 + 2e2
#
# Can translate between vectors

# %% [markdown]
# Main problem of lineary algeba
#
# 3x1 + x2 = y1 <br/>
# x1 + 2x2 = y2
#
# Note this is a linear , no powers or products,

# %% [markdown]
# General case:
#
# ax1 = y1  ->    x1 = 1/a y1
#
# a != 0
#
#
#
# ax1 = bx2 = y1
#
# cx1 + dx2 = y2
#
#
# Solve for x1, x2 note tht ad - bc != 0

# %% [markdown]
# What is geometric meaning of delta / bob / rachale
#
# now generalise to 3 dims......

# %% [markdown]
# Homework at 43.00
