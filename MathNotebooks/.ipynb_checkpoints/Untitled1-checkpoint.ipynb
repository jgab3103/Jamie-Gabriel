# %% [markdown]
# # My Totes Faves Python Libraries of All Timez!!!

# %% [markdown]
# # C     vs. Python.... vs. R

# %% [markdown]
# # Library #1: Sympy

# %% [markdown]
# # Library #2: Matplotlib

# %% [markdown]
# # Library #3: Scikitlearn

# %% [markdown]
# # Library #4: Django

# %% [markdown]
# # Things you shouldn't use Python for.....and other languages you should check out!
#
#
# #### Like C++, Java, Haskell, Mathematica, Julia.....
