# %%
import numpy as np
import sympy as sp
from IPython.display import HTML, IFrame
import ipywidgets as widgets
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
mpl.rcParams['legend.fontsize'] = 10
import pandas as pd
import itertools
from IPython.display import Image
import math

# function to print latex
def renderListToLatex(e):
    latex_rendering = []

    for i in range(len(e)):
        latex_rendering.append("$$" + sp.latex(e[i]) + "$$<br/>")
    
    return(HTML("".join(latex_rendering[0:])))

# %% [markdown]
# #### Lecture 2: Appolonius and harmonic conjugates

# %%
# hyperbolic - is about geom of circle 

# recall - appolonious 

# start with null cirlce - startred with assumption of point A outside and tangents

# next deinition allows any point, to form quadrangle - meeting at 2 new diagonal points
# which determine polar line 

# construction is independent of line chice - polar independece theorem

# %%
# note we use same circle alot, the null cirlce

# Note you can start with line A and then get pole, or vice versa

# Apolloinus realised that this holds for general conic!

# workds for ellipse - 
# Polar Indepence holds
# Polar duality holds
# Pole of a line holds - try for different types of conics

# %%
# treat points oncircle as special
Image("./Images/UHG_10.PNG", width = 400)

# %%
# usually use greek leters to denote points on the circle

# how do you find polar of null point - 
# if you try and do this you get a degenerate quadrangle - can't construct
# this is limiting case

# to do this, look at 2 lines through gamma
# find thier poles
# join those poles (so above join a and b)

# also leads to the idea that we can create a tangent using a straight edge

# %%
# what about being able to contruct centre using only a straight edge 

# We kow we can find tangent - so maybe can we find perpendicular

# %% [markdown]
# #### Harmonic Conjugates
#
# Another of appolonius insights

# %%
Image("./Images/UHG_11.PNG", width = 400)

# %%
#Choose any tine through a bunch of lines from a,
# you get harmonic 
#so aove there is a relationship between a and and b and d - same ratio

# %% [markdown]
# Note that harmonic range belonds affine geometry and projetive
#
# Projective - just straight edge
# Affine - stragith edge and parralel ( no perpendicular)
# Euclidian - straight edge and compas (parralel and perpendicular)
#
# hypberbolic geom is projective with a distinguished circle
#
# impromtant to locate concepts of geom in heirachy - note polarity is in projective, harmonic conjugats in projectivee
