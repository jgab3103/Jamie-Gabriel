# %% [markdown]
# <i>Status: Draft</i>

# %%
import networkx as nx
import networkx.algorithms.community as nx_comm
import matplotlib.pyplot as plt
import numpy as np
import scipy as scp
import pandas as pd
import node2vec as n2v
import karateclub as kc
import random
import stellargraph as sp
from IPython.display import Image
from gem.embedding.gf import GraphFactorization
from pathlib import Path

from scipy.io import mmread
import pandas as pd
from snap import LoadEdgeList, PNGraph
Path("gem/intermediate").mkdir(parents=True, exist_ok=True)

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# <b>Observe</b>: There are a number of good sources of network data. These include:
#
# - <b>Ref</b>: https://ogb.stanford.edu/
# - <b>Ref</b>: https://networkrepository.com/
#
# <b>Observe</b>: The astrophysics dataset used in the latter part of this notebook was downloaded from the networkrepository site.

# %% [markdown]
# <hr/>
# <b>Aim</b>: Examined auto-generated graphs and graph transformations in networkx
#
# <hr/>

# %% [markdown]
# <b>Definition</b>:  a fully connected subgraph of $n$ nodes within larger graph is referred to as a <b>clique</b> of size $n$.
#
# <b>Observe</b>: The process of finding cliques of a given size $n$ in a larger graph is a nondeterministic polynomial time complete (NP-complete) problem

# %% [markdown]
# <b>Observe</b>: networkx has the capability of generating standard graph structures which can be characterised by the clique measure. These include:
#
# - <b>complete</b> graphs where all nodes are connected
# - <b>lollipop</b> graphs with a clique of size $n$ and branch of $m$ nodes
# - <b>barbell</b> graph with two cliques of size $m1$ and branch $m2$

# %% [markdown]
# <b>Let</b> $P1, P2$ and $P3$ be examples of a complete, lollipop and barbell graph.

# %%
P1 = nx.complete_graph(n = 7)
P2 = nx.lollipop_graph(m = 7, n = 3)
P3 = nx.barbell_graph(m1 = 7, m2 = 4)

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,3,1)
nx.draw(P1)
plt.title("Complete")
plt.subplot(1,3,2)
plt.title("Lollipop")
nx.draw(P2)
plt.subplot(1,3,3)
plt.title("Barbell")
nx.draw(P3)

# %% [markdown]
# <b>Observe</b>: It is possible to join nodes of different graphs using networkx
#
# <b>Let</b> $P4$ be a graph composed of $P1, P2$ and $P3$.

# %%
def get_random_node(graph):
    return np.random.choice(graph.nodes)

P4 = nx.compose_all([P1, P2, P3])
P4.add_edge(get_random_node(P2), get_random_node(P3))
P4.add_edge(get_random_node(P3), get_random_node(P1))
nx.draw(P4)

# %% [markdown]
# <b>Observe</b>: networkx can generate graphs via probabilistic models. Examples include the Watts and Strogatz (1998) or Barabasi-Albert (1999) graphs.

# %% [markdown]
# <b>Let</b> $P5$ be a Watts-Strogatz graph.

# %%
P5 = nx.watts_strogatz_graph(n = 20, k = 5, p= 0.2)
nx.draw(P5)

# %% [markdown]
# <b>Let</b> $P6$ be a Barabasi-Albert graph.

# %%
n = 100
P6 = nx.extended_barabasi_albert_graph(n,m=1,p=0,q=0)
nx.draw(P6)

# %% [markdown]
# <hr/>
#
# <b>Aim</b>: Import network data from network repository
#
# <hr/>

# %%
adjMatrix = mmread("../Data/AstroPhysicsNetwork/ca-AstroPh.mtx")
graph = nx.from_scipy_sparse_matrix(adjMatrix)

# %%
degrees = dict(nx.degree(graph))
ci = nx.clustering(graph)
centrality = nx.centrality.eigenvector_centrality(graph)

# %%
stats = pd.DataFrame({
    "centrality": centrality,
    "C_i": ci,
    "degree": degrees
})

# %%
neighbors = [n for n in nx.neighbors(graph, 6933)]

sampling = 0.1
nTop = round(len(neighbors)*sampling)

# %%
idx = {
    "random": stats.loc[neighbors].sort_index().index[:nTop], 
    "centrality": stats.loc[neighbors].sort_values("centrality", ascending=False).index[:nTop],
    "C_i": stats.loc[neighbors].sort_values("C_i", ascending=False).index[:nTop]
}

# %%
def plotSubgraph(graph, indices, center = 6933):
    draw_graph(
        nx.subgraph(graph, list(indices) + [center]),
        layout = nx.kamada_kawai_layout
    )

# %%
plt.figure(figsize=(15,6))
for ith, title in enumerate(["random", "centrality", "C_i"]):
    plt.subplot(1,3,ith+1)
    plotSubgraph(graph, idx[title])
    plt.title(title)

# %%
graph = LoadEdgeList(PNGraph, "../Data/AmazonData/com-amazon.ungraph.txt", 0, 1, '\t')

# %%
#

# %%
# draw a simple graph
def draw_graph(G, node_names={}, filename=None, node_size=50, layout = None):
    pos_nodes = nx.spring_layout(G) if layout is None else layout(G)
    nx.draw(G, pos_nodes, with_labels=False, node_size=node_size, edge_color='gray')
  
    pos_attrs = {}
    for node, coords in pos_nodes.items():
        pos_attrs[node] = (coords[0], coords[1] + 0.08)
  
    nx.draw_networkx_labels(G, pos_attrs, labels=node_names, font_family='serif')
  
    plt.axis('off')
    axis = plt.gca()
    axis.set_xlim([1.2*x for x in axis.get_xlim()])
    axis.set_ylim([1.2*y for y in axis.get_ylim()])
  
    if filename:
        plt.savefig(os.path.join(output_dir, filename), format="png")


# draw enhanced path on the graph
def draw_enhanced_path(G, path_to_enhance, node_names={}, filename=None, layout=None):
    path_edges = list(zip(path,path[1:]))
    pos_nodes = nx.spring_layout(G) if layout is None else layout(G)
    
    plt.figure(figsize=(5,5),dpi=300)
    pos_nodes = nx.spring_layout(G)
    nx.draw(G, pos_nodes, with_labels=False, node_size=50, edge_color='gray')
  
    pos_attrs = {}
    for node, coords in pos_nodes.items():
        pos_attrs[node] = (coords[0], coords[1] + 0.08)
  
    nx.draw_networkx_labels(G, pos_attrs, labels=node_names, font_family='serif')
    nx.draw_networkx_edges(G,pos_nodes,edgelist=path_edges, edge_color='#cc2f04', style='dashed', width=2.0)
  
    plt.axis('off')
    axis = plt.gca()
    axis.set_xlim([1.2*x for x in axis.get_xlim()])
    axis.set_ylim([1.2*y for y in axis.get_ylim()])
  
    if filename:
        plt.savefig(os.path.join(output_dir, filename), format="png")
