# %%
import numpy as np
import sympy as sp
from IPython.display import HTML, IFrame
import ipywidgets as widgets
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
mpl.rcParams['legend.fontsize'] = 10
import pandas as pd
import itertools
from IPython.display import Image

# This is commented out
#%matplotlib widget

# function to print latex
def renderListToLatex(e):
    latex_rendering = []

    for i in range(len(e)):
        latex_rendering.append("$$" + sp.latex(e[i]) + "$$")
    
    return(HTML("".join(latex_rendering[0:])))

# %%
# TRANSLATION

# possible to do geom without a grid - can we just great - geom withou 
# grid polane from reference just notino of vector 

# start BD
# point A
# construct par line f
# constru par line g
# create vector AC

# %%
Image(filename='./Images/WLA_2_1.png', width=400, height=400)

# %%
#Equally spaced points
Image(filename='./Images/WLA2_2.png', width=700, height=700)

# 3 poitns C D
# paralellines f, i
# line j
#parallel line k

# %%
# add to vectors

#Equally spaced points
Image(filename='./Images/WLA2_3.png', width=700, height=700)

# start with AB, AC, might need to translaed
# construct parallels
# join line

# %%
# bisecont


#Equally spaced points
Image(filename='./Images/WLA2_4.png', width=700, height=700)

# %%
# trisect a segmetn - and subract

# OPERATIONS OF VECTOR ARITHEMATIC  

# commutavie = U + V = V + U
# associative law = (U + V)  + W = (V + W)
# Distributive law = (alph + Bet)V = alphV + BetV
# also u - v = u + (-v)


# affine combinations

# %%
#Equally spaced points
Image(filename='./Images/WLA2_5.png', width=400, height=400)

# %%
# suppose tha d is midpoint of AB

# D = CA + 1/2(CB - CA)- note this value of 1/2 can change depending

# %% [markdown]
# $$ \vec{c} = \vec{a} + \frac{j}{k}(\vec{b} - \vec{a}) $$ where $\frac{j}{k}$ really represents the amount

# %%
# j/k does not have to be inbetween, can be outside

# %% [markdown]
# $$ \vec{c} = (1 - \lambda)\vec{a} + \lambda \vec{b} $$

# %%
# general affine combination - coefficietns add up to 1- createa  function, 

# test with values between 0 and 1

# %%
# speccial vector = 0 vector, starting point and env piont are the same 

# note = 0 + v = v
# 0 * v = v

# %%
# Linear independce

# linear independent if they are not multiples of each other.....

# linearly dependend are parallel....

# %% [markdown]
# Theorem: Diagonals of a parralelogram bisect each other

# %%
#29.17

# Note diagonals bisect each other possible proof fof this
